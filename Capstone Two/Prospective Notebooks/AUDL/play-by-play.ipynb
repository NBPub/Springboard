# %%
import requests
import json
import pandas as pd

# %% [markdown]
#  - query API to get list of relevant gameIDs in date range
#  - `https://www.backend.audlstats.com/api/v1/games`
#    - add date range parameter, `?date=<...>`
#
# > An inclusive date range. The full format is YYYY-MM-DD:YYYY-MM-DD, but you can exclude months or days and it will infer them. Examples:
# - > 2021-06:2021-07 => All games during June or July
# - > 2021 => All games during 2021
# - > 2021-07-10: => All games on or after July 10th, 2021
# - > :2012-05 => All games during or before May, 2012

# %%
URL = 'https://www.backend.audlstats.com/api/v1/games?'
parameters = 'date=2023-05-19:2023-05-19' # April and May 2023 games

# %%
URL = f'{URL}{parameters}'
games = requests.get(URL)
if games.status_code == 200:
    games = games.json()

# %%
games['data']
# Out:
# [{'gameID': '2023-05-19-LA-SLC',
#   'awayTeamID': 'aviators',
#   'homeTeamID': 'shred',
#   'awayScore': 13,
#   'homeScore': 25,
#   'status': 'Final',
#   'startTimestamp': '2023-05-19T19:00:00-06:00',
#   'startTimezone': 'MDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/los-angeles-at-salt-lake-5-19-2023',
#   'updateTimestamp': '2023-05-29T05:43:47.960Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-19-OAK-POR',
#   'awayTeamID': 'spiders',
#   'homeTeamID': 'nitro',
#   'awayScore': 24,
#   'homeScore': 23,
#   'status': 'Final',
#   'startTimestamp': '2023-05-19T19:30:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/oakland-at-portland-5-19-2023',
#   'updateTimestamp': '2023-05-23T18:42:42.617Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-19-SD-HTX',
#   'awayTeamID': 'growlers',
#   'homeTeamID': 'havoc',
#   'awayScore': 23,
#   'homeScore': 17,
#   'status': 'Final',
#   'startTimestamp': '2023-05-19T20:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/san-diego-at-houston-5-19-2023',
#   'updateTimestamp': '2023-05-24T02:37:51.337Z',
#   'week': 'week-4'}]

# %% [markdown]
# **Pick game and develop method to unpack events**
#
#  - do stats derived from events match game reported stats?

# %%
URL = 'https://www.backend.audlstats.com/api/v1/gameEvents?'
parameters = 'gameID=2023-05-19-OAK-POR'

# %%
URL = f'{URL}{parameters}'
r = requests.get(URL)
if r.status_code == 200:
    data = r.json()

# %%
r.json()
# Out:
# {'object': 'object',
#  'data': {'homeEvents': [{'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 0},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -16.1,
#     'throwerY': 7.22,
#     'receiver': 'jjohnson1',
#     'receiverX': -1.46,
#     'receiverY': 15.54},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -1.46,
#     'throwerY': 15.54,
#     'receiver': 'efriedman',
#     'receiverX': -17.13,
#     'receiverY': 21.22},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -17.13,
#     'throwerY': 21.22,
#     'receiver': 'jsnyder',
#     'receiverX': -17.45,
#     'receiverY': 94.7},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -17.45,
#     'throwerY': 94.7,
#     'receiver': 'rhayes',
#     'receiverX': -17.39,
#     'receiverY': 86.83},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -17.39,
#     'throwerY': 86.83,
#     'receiver': 'sfraner',
#     'receiverX': -17.06,
#     'receiverY': 74.83},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -17.06,
#     'throwerY': 74.83,
#     'receiver': 'efriedman',
#     'receiverX': 0.35,
#     'receiverY': 63.8},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0.35,
#     'throwerY': 63.8,
#     'receiver': 'isweeney',
#     'receiverX': -19.19,
#     'receiverY': 80.25},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -19.19,
#     'throwerY': 80.25,
#     'receiver': 'efriedman',
#     'receiverX': 2.67,
#     'receiverY': 74.58},
#    {'type': 22,
#     'thrower': 'efriedman',
#     'throwerX': 2.67,
#     'throwerY': 74.58,
#     'turnoverX': -13.71,
#     'turnoverY': 86.06},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -4.68,
#     'throwerY': 20,
#     'receiver': 'jjohnson1',
#     'receiverX': 17.12,
#     'receiverY': 18.12},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 17.12,
#     'throwerY': 18.12,
#     'receiver': 'isweeney',
#     'receiverX': -14.81,
#     'receiverY': 16.32},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -14.81,
#     'throwerY': 16.32,
#     'receiver': 'sfraner',
#     'receiverX': -23,
#     'receiverY': 34.96},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -23,
#     'throwerY': 34.96,
#     'receiver': 'rhayes',
#     'receiverX': -11.07,
#     'receiverY': 36},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -11.07,
#     'throwerY': 36,
#     'receiver': 'efriedman',
#     'receiverX': 2.03,
#     'receiverY': 36.32},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 2.03,
#     'throwerY': 36.32,
#     'receiver': 'tdoi',
#     'receiverX': 18.15,
#     'receiverY': 34.38},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 18.15,
#     'throwerY': 34.38,
#     'receiver': 'efriedman',
#     'receiverX': 9.31,
#     'receiverY': 30.9},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 9.31,
#     'throwerY': 30.9,
#     'receiver': 'isweeney',
#     'receiverX': -11.26,
#     'receiverY': 24.38},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -11.26,
#     'throwerY': 24.38,
#     'receiver': 'efriedman',
#     'receiverX': 11.51,
#     'receiverY': 30.77},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': 11.51,
#     'throwerY': 30.77,
#     'receiver': 'tdoi',
#     'receiverX': 10.54,
#     'receiverY': 108.45},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'llavoie',
#      'jlee',
#      'arueda',
#      'bstout',
#      'apetersch'],
#     'time': 115},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': 0.87,
#     'pullY': 94.96,
#     'pullMs': 3080},
#    {'type': 11, 'defender': 'sradlauer'},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 25.63,
#     'throwerY': 67.29,
#     'receiver': 'jlee',
#     'receiverX': 6.54,
#     'receiverY': 58.64},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': 6.54,
#     'throwerY': 58.64,
#     'receiver': 'jmoore1',
#     'receiverX': -18.67,
#     'receiverY': 53.61},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': -18.67,
#     'throwerY': 53.61,
#     'receiver': 'llavoie',
#     'receiverX': 11.18,
#     'receiverY': 59.93},
#    {'type': 22,
#     'thrower': 'llavoie',
#     'throwerX': 11.18,
#     'throwerY': 59.93,
#     'turnoverX': 20.79,
#     'turnoverY': 104.06},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': 24.86,
#     'throwerY': 45.03,
#     'receiver': 'jlee',
#     'receiverX': 22.47,
#     'receiverY': 30.32},
#    {'type': 22,
#     'thrower': 'jlee',
#     'throwerX': 22.47,
#     'throwerY': 30.32,
#     'turnoverX': 24.02,
#     'turnoverY': 50.64},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': 14.92,
#     'throwerY': 39.41,
#     'receiver': 'llavoie',
#     'receiverX': -0.42,
#     'receiverY': 46.51},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -0.42,
#     'throwerY': 46.51,
#     'receiver': 'jmoore1',
#     'receiverX': -18.74,
#     'receiverY': 56.45},
#    {'type': 22,
#     'thrower': 'jmoore1',
#     'throwerX': -18.74,
#     'throwerY': 56.45,
#     'turnoverX': -10.42,
#     'turnoverY': 106.64},
#    {'type': 15},
#    {'type': 2,
#     'line': ['efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney',
#      'qbuermeye'],
#     'time': 256},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -0.04,
#     'throwerY': 14.32,
#     'receiver': 'isweeney',
#     'receiverX': -6.1,
#     'receiverY': 19.35},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -6.1,
#     'throwerY': 19.35,
#     'receiver': 'efriedman',
#     'receiverX': -16.48,
#     'receiverY': 32.45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -16.48,
#     'throwerY': 32.45,
#     'receiver': 'qbuermeye',
#     'receiverX': -22.74,
#     'receiverY': 41.93},
#    {'type': 18,
#     'thrower': 'qbuermeye',
#     'throwerX': -22.74,
#     'throwerY': 41.93,
#     'receiver': 'sfraner',
#     'receiverX': -16.93,
#     'receiverY': 51.09},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -16.93,
#     'throwerY': 51.09,
#     'receiver': 'rhayes',
#     'receiverX': -23.19,
#     'receiverY': 60.77},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -23.19,
#     'throwerY': 60.77,
#     'receiver': 'efriedman',
#     'receiverX': -13.45,
#     'receiverY': 66.38},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -13.45,
#     'throwerY': 66.38,
#     'receiver': 'rhayes',
#     'receiverX': -25.58,
#     'receiverY': 72.58},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -25.58,
#     'throwerY': 72.58,
#     'receiver': 'efriedman',
#     'receiverX': -5.71,
#     'receiverY': 63.87},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -5.71,
#     'throwerY': 63.87,
#     'receiver': 'sfraner',
#     'receiverX': -17.84,
#     'receiverY': 80.06},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -17.84,
#     'throwerY': 80.06,
#     'receiver': 'jsnyder',
#     'receiverX': 0.93,
#     'receiverY': 70.9},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 0.93,
#     'throwerY': 70.9,
#     'receiver': 'rhayes',
#     'receiverX': 15.5,
#     'receiverY': 90.7},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 15.5,
#     'throwerY': 90.7,
#     'receiver': 'qbuermeye',
#     'receiverX': 14.28,
#     'receiverY': 104.58},
#    {'type': 1,
#     'line': ['jmoore1',
#      'apetersch',
#      'arueda',
#      'gnakano',
#      'bstout',
#      'slatarski',
#      'jlee'],
#     'time': 316},
#    {'type': 7,
#     'puller': 'bstout',
#     'pullX': 25.57,
#     'pullY': 105.54,
#     'pullMs': 6164},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 15.57,
#     'throwerY': 20,
#     'receiver': 'apetersch',
#     'receiverX': 18.41,
#     'receiverY': 32.06},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 18.41,
#     'throwerY': 32.06,
#     'receiver': 'gnakano',
#     'receiverX': 20.02,
#     'receiverY': 56.12},
#    {'type': 18,
#     'thrower': 'gnakano',
#     'throwerX': 20.02,
#     'throwerY': 56.12,
#     'receiver': 'slatarski',
#     'receiverX': 9.12,
#     'receiverY': 59.74},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 9.12,
#     'throwerY': 59.74,
#     'receiver': 'apetersch',
#     'receiverX': -10.1,
#     'receiverY': 57.93},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -10.1,
#     'throwerY': 57.93,
#     'receiver': 'jlee',
#     'receiverX': -8.81,
#     'receiverY': 72.64},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -8.81,
#     'throwerY': 72.64,
#     'receiver': 'apetersch',
#     'receiverX': -1.39,
#     'receiverY': 74.64},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -1.39,
#     'throwerY': 74.64,
#     'receiver': 'bstout',
#     'receiverX': 4.54,
#     'receiverY': 79.8},
#    {'type': 18,
#     'thrower': 'bstout',
#     'throwerX': 4.54,
#     'throwerY': 79.8,
#     'receiver': 'slatarski',
#     'receiverX': 0.09,
#     'receiverY': 70.7},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 0.09,
#     'throwerY': 70.7,
#     'receiver': 'jlee',
#     'receiverX': -16.35,
#     'receiverY': 71.67},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -16.35,
#     'throwerY': 71.67,
#     'receiver': 'apetersch',
#     'receiverX': -2.04,
#     'receiverY': 61.87},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -2.04,
#     'throwerY': 61.87,
#     'receiver': 'slatarski',
#     'receiverX': -18.16,
#     'receiverY': 78.9},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': -18.16,
#     'throwerY': 78.9,
#     'receiver': 'jlee',
#     'receiverX': -4.36,
#     'receiverY': 73.74},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -4.36,
#     'throwerY': 73.74,
#     'receiver': 'jmoore1',
#     'receiverX': 14.28,
#     'receiverY': 79.8},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': 14.28,
#     'throwerY': 79.8,
#     'receiver': 'jlee',
#     'receiverX': -1.59,
#     'receiverY': 74.96},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -1.59,
#     'throwerY': 74.96,
#     'receiver': 'jmoore1',
#     'receiverX': 8.22,
#     'receiverY': 75.09},
#    {'type': 3,
#     'line': ['bstout',
#      'rhayes',
#      'qbuermeye',
#      'apetersch',
#      'jlee',
#      'isweeney',
#      'jmoore1'],
#     'time': 403},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 15.7,
#     'throwerY': 84.25,
#     'receiver': 'rhayes',
#     'receiverX': 1.9,
#     'receiverY': 94.38},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 1.9,
#     'throwerY': 94.38,
#     'receiver': 'isweeney',
#     'receiverX': 24.15,
#     'receiverY': 104.38},
#    {'type': 1,
#     'line': ['cstillwel',
#      'ceustis',
#      'llavoie',
#      'sradlauer',
#      'slatarski',
#      'gnakano',
#      'jlee'],
#     'time': 411},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 1.7,
#     'pullY': 118.58,
#     'pullMs': 7161},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney'],
#     'time': 453},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 25.69,
#     'throwerY': 42.77,
#     'receiver': 'sfraner',
#     'receiverX': 11.57,
#     'receiverY': 47.09},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 11.57,
#     'throwerY': 47.09,
#     'receiver': 'isweeney',
#     'receiverX': 6.22,
#     'receiverY': 39.8},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 6.22,
#     'throwerY': 39.8,
#     'receiver': 'efriedman',
#     'receiverX': -1.46,
#     'receiverY': 95.03},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -1.46,
#     'throwerY': 95.03,
#     'receiver': 'sfraner',
#     'receiverX': -1.39,
#     'receiverY': 89.74},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -1.39,
#     'throwerY': 89.74,
#     'receiver': 'jsnyder',
#     'receiverX': -4.75,
#     'receiverY': 72.32},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -4.75,
#     'throwerY': 72.32,
#     'receiver': 'sfraner',
#     'receiverX': -2.23,
#     'receiverY': 81.48},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -2.23,
#     'throwerY': 81.48,
#     'receiver': 'rhayes',
#     'receiverX': 11.44,
#     'receiverY': 95.93},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 11.44,
#     'throwerY': 95.93,
#     'receiver': 'jsnyder',
#     'receiverX': 11.76,
#     'receiverY': 85.29},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 11.76,
#     'throwerY': 85.29,
#     'receiver': 'rhayes',
#     'receiverX': 15.31,
#     'receiverY': 94.77},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 15.31,
#     'throwerY': 94.77,
#     'receiver': 'efriedman',
#     'receiverX': 20.28,
#     'receiverY': 116},
#    {'type': 1,
#     'line': ['bstout',
#      'sradlauer',
#      'arueda',
#      'apetersch',
#      'qbuermeye',
#      'ceustis',
#      'llavoie'],
#     'time': 521},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -3.33,
#     'pullY': 116.19,
#     'pullMs': 6895},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney',
#      'cstillwel'],
#     'time': 568},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 13.31,
#     'throwerY': 25.61,
#     'receiver': 'rhayes',
#     'receiverX': 19.25,
#     'receiverY': 36.51},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 19.25,
#     'throwerY': 36.51,
#     'receiver': 'sfraner',
#     'receiverX': 26.21,
#     'receiverY': 50.77},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 26.21,
#     'throwerY': 50.77,
#     'receiver': 'cstillwel',
#     'receiverX': 24.79,
#     'receiverY': 66.7},
#    {'type': 18,
#     'thrower': 'cstillwel',
#     'throwerX': 24.79,
#     'throwerY': 66.7,
#     'receiver': 'isweeney',
#     'receiverX': 13.05,
#     'receiverY': 70.32},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 13.05,
#     'throwerY': 70.32,
#     'receiver': 'rhayes',
#     'receiverX': -13.58,
#     'receiverY': 69.67},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -13.58,
#     'throwerY': 69.67,
#     'receiver': 'sfraner',
#     'receiverX': 1.7,
#     'receiverY': 68.96},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 1.7,
#     'throwerY': 68.96,
#     'receiver': 'jjohnson1',
#     'receiverX': 24.66,
#     'receiverY': 85.67},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 24.66,
#     'throwerY': 85.67,
#     'receiver': 'sfraner',
#     'receiverX': 2.61,
#     'receiverY': 72.45},
#    {'type': 22,
#     'thrower': 'sfraner',
#     'throwerX': 2.61,
#     'throwerY': 72.45,
#     'turnoverX': 25.89,
#     'turnoverY': 89.8},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'tdoi',
#      'jmoore1',
#      'qbuermeye'],
#     'time': 625},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -8.81,
#     'throwerY': 21.87,
#     'receiver': 'efriedman',
#     'receiverX': 4.35,
#     'receiverY': 23.41},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 4.35,
#     'throwerY': 23.41,
#     'receiver': 'jsnyder',
#     'receiverX': -7.71,
#     'receiverY': 27.87},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -7.71,
#     'throwerY': 27.87,
#     'receiver': 'efriedman',
#     'receiverX': 0.93,
#     'receiverY': 19.48},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0.93,
#     'throwerY': 19.48,
#     'receiver': 'rhayes',
#     'receiverX': -1.71,
#     'receiverY': 92.45},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': -1.71,
#     'throwerY': 92.45,
#     'receiver': 'jmoore1',
#     'receiverX': -9.58,
#     'receiverY': 105.29},
#    {'type': 1,
#     'line': ['jlee',
#      'gnakano',
#      'sradlauer',
#      'slatarski',
#      'apetersch',
#      'isweeney',
#      'jmoore1'],
#     'time': 652},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': -25.77,
#     'pullY': 72.32,
#     'pullMs': 4212},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'bstout',
#      'cstillwel'],
#     'time': 697},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 18.92,
#     'throwerY': 26.25,
#     'receiver': 'efriedman',
#     'receiverX': 0.8,
#     'receiverY': 22.58},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0.8,
#     'throwerY': 22.58,
#     'receiver': 'isweeney',
#     'receiverX': -16.55,
#     'receiverY': 29.67},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -16.55,
#     'throwerY': 29.67,
#     'receiver': 'cstillwel',
#     'receiverX': -22.74,
#     'receiverY': 59.29},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'cstillwel',
#     'throwerX': -22.74,
#     'throwerY': 69.28999999999999,
#     'receiver': 'rhayes',
#     'receiverX': -20.67,
#     'receiverY': 82.06},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': -20.67,
#     'throwerY': 82.06,
#     'receiver': 'bstout',
#     'receiverX': 4.22,
#     'receiverY': 108.25},
#    {'type': 28},
#    {'type': 1,
#     'line': ['sradlauer',
#      'slatarski',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'bstout'],
#     'time': 0},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': -26.03,
#     'pullY': 70.19,
#     'pullMs': 19341},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -9.19,
#     'throwerY': 14.9,
#     'receiver': 'sfraner',
#     'receiverX': -22.74,
#     'receiverY': 41.35},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -22.74,
#     'throwerY': 41.35,
#     'receiver': 'rhayes',
#     'receiverX': 17.96,
#     'receiverY': 82.12},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 17.96,
#     'throwerY': 82.12,
#     'receiver': 'tdoi',
#     'receiverX': 12.93,
#     'receiverY': 119.22},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'ceustis',
#      'llavoie',
#      'arueda'],
#     'time': 67},
#    {'type': 7, 'puller': 'llavoie', 'pullX': 0, 'pullY': 80, 'pullMs': 5412},
#    {'type': 13},
#    {'type': 17},
#    {'type': 22,
#     'thrower': 'apetersch',
#     'throwerX': 0.16,
#     'throwerY': 96.25,
#     'turnoverX': 4.54,
#     'turnoverY': 82.77},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'qbuermeye'],
#     'time': 186},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -0.3,
#     'throwerY': 9.48,
#     'receiver': 'efriedman',
#     'receiverX': 1.38,
#     'receiverY': 17.48},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 1.38,
#     'throwerY': 17.48,
#     'receiver': 'jsnyder',
#     'receiverX': -5.84,
#     'receiverY': 20},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -5.84,
#     'throwerY': 20,
#     'receiver': 'efriedman',
#     'receiverX': 2.67,
#     'receiverY': 20},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 2.67,
#     'throwerY': 20,
#     'receiver': 'qbuermeye',
#     'receiverX': 18.34,
#     'receiverY': 20},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'qbuermeye',
#     'throwerX': 18.34,
#     'throwerY': 30,
#     'receiver': 'jjohnson1',
#     'receiverX': -4.75,
#     'receiverY': 30.51},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -4.75,
#     'throwerY': 30.51,
#     'receiver': 'rhayes',
#     'receiverX': 7.96,
#     'receiverY': 40.7},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 7.96,
#     'throwerY': 40.7,
#     'receiver': 'jjohnson1',
#     'receiverX': -10.48,
#     'receiverY': 42},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -10.48,
#     'throwerY': 42,
#     'receiver': 'sfraner',
#     'receiverX': 1.7,
#     'receiverY': 45.54},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 1.7,
#     'throwerY': 45.54,
#     'receiver': 'rhayes',
#     'receiverX': 19.76,
#     'receiverY': 48.32},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 19.76,
#     'throwerY': 48.32,
#     'receiver': 'jsnyder',
#     'receiverX': 23.05,
#     'receiverY': 63.16},
#    {'type': 16},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 23.05,
#     'throwerY': 53.16,
#     'receiver': 'sfraner',
#     'receiverX': 7.83,
#     'receiverY': 39.35},
#    {'type': 22,
#     'thrower': 'sfraner',
#     'throwerX': 7.83,
#     'throwerY': 39.35,
#     'turnoverX': -3.26,
#     'turnoverY': 69.16},
#    {'type': 15},
#    {'type': 2,
#     'line': ['efriedman',
#      'rhayes',
#      'sfraner',
#      'qbuermeye',
#      'tdoi',
#      'cstillwel',
#      'isweeney'],
#     'time': 285},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -0.17,
#     'throwerY': 65.48,
#     'receiver': 'rhayes',
#     'receiverX': -18.67,
#     'receiverY': 79.41},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -18.67,
#     'throwerY': 79.41,
#     'receiver': 'isweeney',
#     'receiverX': -3,
#     'receiverY': 71.29},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -3,
#     'throwerY': 71.29,
#     'receiver': 'sfraner',
#     'receiverX': -18.42,
#     'receiverY': 75.16},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -18.42,
#     'throwerY': 75.16,
#     'receiver': 'isweeney',
#     'receiverX': -9.65,
#     'receiverY': 70.64},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -9.65,
#     'throwerY': 70.64,
#     'receiver': 'rhayes',
#     'receiverX': -16.61,
#     'receiverY': 79.74},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -16.61,
#     'throwerY': 79.74,
#     'receiver': 'efriedman',
#     'receiverX': 3.83,
#     'receiverY': 88.51},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': 3.83,
#     'throwerY': 88.51,
#     'receiver': 'tdoi',
#     'receiverX': 17.31,
#     'receiverY': 104.06},
#    {'type': 1,
#     'line': ['sradlauer',
#      'slatarski',
#      'jmoore1',
#      'apetersch',
#      'bstout',
#      'llavoie',
#      'arueda'],
#     'time': 347},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -26.41,
#     'pullY': 71.8,
#     'pullMs': 17575},
#    {'type': 11, 'defender': 'sradlauer'},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 15.38,
#     'throwerY': 69.16,
#     'receiver': 'apetersch',
#     'receiverX': 7.7,
#     'receiverY': 65.54},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 7.7,
#     'throwerY': 65.54,
#     'receiver': 'sradlauer',
#     'receiverX': 15.25,
#     'receiverY': 75.67},
#    {'type': 22,
#     'thrower': 'sradlauer',
#     'throwerX': 15.25,
#     'throwerY': 75.67,
#     'turnoverX': -17.58,
#     'turnoverY': 89.67},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'qbuermeye',
#      'isweeney'],
#     'time': 402},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'rhayes',
#     'receiverX': -21.51,
#     'receiverY': 52.7},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -21.51,
#     'throwerY': 52.7,
#     'receiver': 'efriedman',
#     'receiverX': -11.13,
#     'receiverY': 45.22},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -11.13,
#     'throwerY': 45.22,
#     'receiver': 'jjohnson1',
#     'receiverX': 3.19,
#     'receiverY': 47.67},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 3.19,
#     'throwerY': 47.67,
#     'receiver': 'rhayes',
#     'receiverX': 11.44,
#     'receiverY': 54.25},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 11.44,
#     'throwerY': 54.25,
#     'receiver': 'jsnyder',
#     'receiverX': 0.16,
#     'receiverY': 45.67},
#    {'type': 22,
#     'thrower': 'jsnyder',
#     'throwerX': 0.16,
#     'throwerY': 45.67,
#     'turnoverX': -7.39,
#     'turnoverY': 109.61},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -0.23,
#     'throwerY': 29.8,
#     'receiver': 'isweeney',
#     'receiverX': -18.16,
#     'receiverY': 38.38},
#    {'type': 20,
#     'thrower': 'isweeney',
#     'throwerX': -18.16,
#     'throwerY': 38.38,
#     'receiver': 'efriedman',
#     'receiverX': 3.06,
#     'receiverY': 42.64},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'cstillwel',
#      'llavoie',
#      'isweeney'],
#     'time': 550},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 16.6,
#     'throwerY': 66.64,
#     'receiver': 'tdoi',
#     'receiverX': 17.25,
#     'receiverY': 90},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 17.25,
#     'throwerY': 90,
#     'receiver': 'sfraner',
#     'receiverX': 19.18,
#     'receiverY': 79.16},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 19.18,
#     'throwerY': 79.16,
#     'receiver': 'llavoie',
#     'receiverX': -4.1,
#     'receiverY': 83.48},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -4.1,
#     'throwerY': 83.48,
#     'receiver': 'sfraner',
#     'receiverX': 12.02,
#     'receiverY': 81.41},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 12.02,
#     'throwerY': 81.41,
#     'receiver': 'isweeney',
#     'receiverX': -5,
#     'receiverY': 82},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -5,
#     'throwerY': 82,
#     'turnoverX': -21.45,
#     'turnoverY': 96.7},
#    {'type': 5,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'bstout',
#      'apetersch',
#      'qbuermeye'],
#     'time': 610},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney'],
#     'time': 642},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 10.99,
#     'throwerY': 4.19,
#     'receiver': 'jjohnson1',
#     'receiverX': -16.35,
#     'receiverY': 14.38},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -16.35,
#     'throwerY': 14.38,
#     'receiver': 'rhayes',
#     'receiverX': -19,
#     'receiverY': 27.67},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -19,
#     'throwerY': 27.67,
#     'receiver': 'efriedman',
#     'receiverX': -18.42,
#     'receiverY': 21.41},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -18.42,
#     'throwerY': 21.41,
#     'receiver': 'jjohnson1',
#     'receiverX': 10.22,
#     'receiverY': 16.64},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 10.22,
#     'throwerY': 16.64,
#     'receiver': 'jsnyder',
#     'receiverX': 19.25,
#     'receiverY': 18.51},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 19.25,
#     'throwerY': 18.51,
#     'receiver': 'sfraner',
#     'receiverX': -18.93,
#     'receiverY': 16.06},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -18.93,
#     'throwerY': 16.06,
#     'receiver': 'jjohnson1',
#     'receiverX': 2.99,
#     'receiverY': 14.51},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 2.99,
#     'throwerY': 14.51,
#     'receiver': 'isweeney',
#     'receiverX': 0.99,
#     'receiverY': 6},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 0.99,
#     'throwerY': 6,
#     'receiver': 'rhayes',
#     'receiverX': 13.44,
#     'receiverY': 13.48},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 13.44,
#     'throwerY': 13.48,
#     'receiver': 'tdoi',
#     'receiverX': 0.09,
#     'receiverY': 32.25},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 0.09,
#     'throwerY': 32.25,
#     'receiver': 'efriedman',
#     'receiverX': -17.77,
#     'receiverY': 45.41},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': -17.77,
#     'throwerY': 45.41,
#     'receiver': 'sfraner',
#     'receiverX': -11.97,
#     'receiverY': 113.16},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'rhayes',
#      'bstout',
#      'apetersch',
#      'ceustis',
#      'llavoie'],
#     'time': 697},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -6.1,
#     'pullY': 115.61,
#     'pullMs': 6812},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'bstout',
#      'cstillwel'],
#     'time': 717},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -9.97,
#     'throwerY': 12.7,
#     'turnoverX': 2.8,
#     'turnoverY': 94.7},
#    {'type': 29},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 0},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 11.44,
#     'throwerY': 3.54,
#     'receiver': 'efriedman',
#     'receiverX': -5.33,
#     'receiverY': 12.45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -5.33,
#     'throwerY': 12.45,
#     'receiver': 'jsnyder',
#     'receiverX': 15.25,
#     'receiverY': 18},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 15.25,
#     'throwerY': 18,
#     'receiver': 'rhayes',
#     'receiverX': -0.88,
#     'receiverY': 29.74},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -0.88,
#     'throwerY': 29.74,
#     'receiver': 'tdoi',
#     'receiverX': -9.52,
#     'receiverY': 73.03},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': -9.52,
#     'throwerY': 73.03,
#     'receiver': 'efriedman',
#     'receiverX': -19.06,
#     'receiverY': 71.61},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': -19.06,
#     'throwerY': 71.61,
#     'receiver': 'rhayes',
#     'receiverX': -18.67,
#     'receiverY': 111.87},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'apetersch',
#      'bstout',
#      'llavoie',
#      'ceustis'],
#     'time': 33},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 22.53,
#     'pullY': 109.8,
#     'pullMs': 6744},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'rhayes',
#      'sfraner',
#      'qbuermeye',
#      'tdoi',
#      'isweeney'],
#     'time': 59},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'rhayes',
#     'receiverX': -20.16,
#     'receiverY': 61.41},
#    {'type': 22,
#     'thrower': 'rhayes',
#     'throwerX': -20.16,
#     'throwerY': 61.41,
#     'turnoverX': -2.75,
#     'turnoverY': 113.29},
#    {'type': 17},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'sfraner',
#      'cstillwel',
#      'llavoie',
#      'tdoi'],
#     'time': 166},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -0.36,
#     'throwerY': 62.64,
#     'receiver': 'jsnyder',
#     'receiverX': -14.16,
#     'receiverY': 60.77},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -14.16,
#     'throwerY': 70.77000000000001,
#     'receiver': 'llavoie',
#     'receiverX': -2.36,
#     'receiverY': 100},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': 0,
#     'throwerY': 100,
#     'receiver': 'jsnyder',
#     'receiverX': -4.68,
#     'receiverY': 88.64},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -4.68,
#     'throwerY': 88.64,
#     'receiver': 'llavoie',
#     'receiverX': 17.63,
#     'receiverY': 84.9},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': 17.63,
#     'throwerY': 84.9,
#     'receiver': 'tdoi',
#     'receiverX': 0.35,
#     'receiverY': 89.8},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 0.35,
#     'throwerY': 89.8,
#     'receiver': 'sfraner',
#     'receiverX': 6.15,
#     'receiverY': 84.77},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 6.15,
#     'throwerY': 84.77,
#     'receiver': 'tdoi',
#     'receiverX': 21.76,
#     'receiverY': 89.09},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 21.76,
#     'throwerY': 89.09,
#     'receiver': 'sfraner',
#     'receiverX': 21.82,
#     'receiverY': 84.7},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 21.82,
#     'throwerY': 84.7,
#     'receiver': 'llavoie',
#     'receiverX': 0.54,
#     'receiverY': 90.32},
#    {'type': 19,
#     'thrower': 'llavoie',
#     'throwerX': 0.54,
#     'throwerY': 90.32,
#     'receiver': 'efriedman',
#     'receiverX': 25.24,
#     'receiverY': 113.93},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'arueda',
#      'bstout'],
#     'time': 259},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': -25.19,
#     'pullY': 80.58,
#     'pullMs': 11693},
#    {'type': 25,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'arueda',
#      'bstout'],
#     'time': 291},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'qbuermeye',
#      'tdoi',
#      'isweeney'],
#     'time': 295},
#    {'type': 22,
#     'thrower': 'efriedman',
#     'throwerX': 0.8,
#     'throwerY': 1.22,
#     'turnoverX': -26.03,
#     'turnoverY': 31.48},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -17.9,
#     'throwerY': 19.8,
#     'receiver': 'efriedman',
#     'receiverX': -21.32,
#     'receiverY': 37.87},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -21.32,
#     'throwerY': 37.87,
#     'receiver': 'rhayes',
#     'receiverX': -10.81,
#     'receiverY': 50.51},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -10.81,
#     'throwerY': 50.51,
#     'receiver': 'efriedman',
#     'receiverX': -19.32,
#     'receiverY': 48.45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -19.32,
#     'throwerY': 48.45,
#     'receiver': 'tdoi',
#     'receiverX': 9.12,
#     'receiverY': 92.7},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 9.12,
#     'throwerY': 92.7,
#     'receiver': 'jsnyder',
#     'receiverX': 1.83,
#     'receiverY': 80.83},
#    {'type': 19,
#     'thrower': 'jsnyder',
#     'throwerX': 1.83,
#     'throwerY': 80.83,
#     'receiver': 'tdoi',
#     'receiverX': -24.41,
#     'receiverY': 105.61},
#    {'type': 1,
#     'line': ['sradlauer',
#      'slatarski',
#      'jmoore1',
#      'gnakano',
#      'apetersch',
#      'llavoie',
#      'arueda'],
#     'time': 353},
#    {'type': 7,
#     'puller': 'slatarski',
#     'pullX': 6.73,
#     'pullY': 92.77,
#     'pullMs': 7543},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'cstillwel'],
#     'time': 394},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -9.39,
#     'throwerY': 7.61,
#     'receiver': 'jsnyder',
#     'receiverX': 0.54,
#     'receiverY': 14.38},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 0.54,
#     'throwerY': 14.38,
#     'receiver': 'rhayes',
#     'receiverX': 10.15,
#     'receiverY': 22.06},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 10.15,
#     'throwerY': 22.06,
#     'receiver': 'sfraner',
#     'receiverX': 3.83,
#     'receiverY': 30.96},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 3.83,
#     'throwerY': 30.96,
#     'receiver': 'jjohnson1',
#     'receiverX': -17.71,
#     'receiverY': 32.51},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -17.71,
#     'throwerY': 32.51,
#     'receiver': 'jsnyder',
#     'receiverX': -19.06,
#     'receiverY': 52.32},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -19.06,
#     'throwerY': 52.32,
#     'receiver': 'isweeney',
#     'receiverX': -11.19,
#     'receiverY': 63.03},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -11.19,
#     'throwerY': 63.03,
#     'turnoverX': -18.35,
#     'turnoverY': 110.9},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'rhayes',
#      'qbuermeye',
#      'llavoie',
#      'tdoi',
#      'isweeney'],
#     'time': 471},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -22.67,
#     'throwerY': 10.12,
#     'receiver': 'efriedman',
#     'receiverX': -13.39,
#     'receiverY': 24.38},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -13.39,
#     'throwerY': 24.38,
#     'receiver': 'qbuermeye',
#     'receiverX': -9.9,
#     'receiverY': 91.48},
#    {'type': 22,
#     'thrower': 'qbuermeye',
#     'throwerX': -9.9,
#     'throwerY': 91.48,
#     'turnoverX': -4.29,
#     'turnoverY': 85.61},
#    {'type': 11, 'defender': 'rhayes'},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -24.67,
#     'throwerY': 63.09,
#     'receiver': 'jjohnson1',
#     'receiverX': -23.51,
#     'receiverY': 45.48},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -23.51,
#     'throwerY': 45.48,
#     'receiver': 'isweeney',
#     'receiverX': -9.58,
#     'receiverY': 49.22},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -9.58,
#     'throwerY': 49.22,
#     'receiver': 'tdoi',
#     'receiverX': 8.86,
#     'receiverY': 56.45},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 8.86,
#     'throwerY': 56.45,
#     'receiver': 'isweeney',
#     'receiverX': -7,
#     'receiverY': 54.7},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -7,
#     'throwerY': 54.7,
#     'receiver': 'rhayes',
#     'receiverX': 14.86,
#     'receiverY': 60.77},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 14.86,
#     'throwerY': 60.77,
#     'receiver': 'qbuermeye',
#     'receiverX': 24.47,
#     'receiverY': 76.06},
#    {'type': 18,
#     'thrower': 'qbuermeye',
#     'throwerX': 24.47,
#     'throwerY': 76.06,
#     'receiver': 'rhayes',
#     'receiverX': 4.74,
#     'receiverY': 74.51},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 4.74,
#     'throwerY': 74.51,
#     'receiver': 'qbuermeye',
#     'receiverX': 25.18,
#     'receiverY': 111.61},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'bstout',
#      'ceustis'],
#     'time': 545},
#    {'type': 8, 'puller': 'jmoore1'},
#    {'type': 11, 'defender': 'gnakano'},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -4.55,
#     'throwerY': 69.74,
#     'receiver': 'jlee',
#     'receiverX': 13.51,
#     'receiverY': 77.09},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': 13.51,
#     'throwerY': 77.09,
#     'receiver': 'bstout',
#     'receiverX': 24.53,
#     'receiverY': 87.16},
#    {'type': 18,
#     'thrower': 'bstout',
#     'throwerX': 24.53,
#     'throwerY': 87.16,
#     'receiver': 'jmoore1',
#     'receiverX': -6.55,
#     'receiverY': 80.32},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': -6.55,
#     'throwerY': 80.32,
#     'receiver': 'apetersch',
#     'receiverX': -25.7,
#     'receiverY': 91.67},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -25.7,
#     'throwerY': 91.67,
#     'receiver': 'ceustis',
#     'receiverX': -11.26,
#     'receiverY': 97.41},
#    {'type': 19,
#     'thrower': 'ceustis',
#     'throwerX': -11.26,
#     'throwerY': 97.41,
#     'receiver': 'sradlauer',
#     'receiverX': -3.71,
#     'receiverY': 104.77},
#    {'type': 1,
#     'line': ['slatarski',
#      'jmoore1',
#      'gnakano',
#      'apetersch',
#      'ceustis',
#      'arueda',
#      'llavoie'],
#     'time': 618},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 0.87,
#     'pullY': 116.7,
#     'pullMs': 0},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 651},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -20.29,
#     'throwerY': 22.96,
#     'receiver': 'sfraner',
#     'receiverX': -12.23,
#     'receiverY': 29.41},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -12.23,
#     'throwerY': 29.41,
#     'receiver': 'jjohnson1',
#     'receiverX': 5.9,
#     'receiverY': 27.41},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 5.9,
#     'throwerY': 27.41,
#     'receiver': 'tdoi',
#     'receiverX': 11.89,
#     'receiverY': 40.19},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 11.89,
#     'throwerY': 40.19,
#     'receiver': 'rhayes',
#     'receiverX': 6.15,
#     'receiverY': 52.7},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 6.15,
#     'throwerY': 52.7,
#     'receiver': 'sfraner',
#     'receiverX': 14.54,
#     'receiverY': 63.67},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 14.54,
#     'throwerY': 63.67,
#     'receiver': 'jjohnson1',
#     'receiverX': 19.89,
#     'receiverY': 98.96},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 19.89,
#     'throwerY': 98.96,
#     'receiver': 'efriedman',
#     'receiverX': 15.5,
#     'receiverY': 98.32},
#    {'type': 3,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'qbuermeye'],
#     'time': 698},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 15.5,
#     'throwerY': 98.32,
#     'receiver': 'rhayes',
#     'receiverX': 16.79,
#     'receiverY': 89.8},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 16.79,
#     'throwerY': 89.8,
#     'receiver': 'isweeney',
#     'receiverX': 24.66,
#     'receiverY': 92.77},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 24.66,
#     'throwerY': 92.77,
#     'receiver': 'rhayes',
#     'receiverX': 6.41,
#     'receiverY': 85.22},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 6.41,
#     'throwerY': 85.22,
#     'receiver': 'jjohnson1',
#     'receiverX': 23.18,
#     'receiverY': 110.25},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'rhayes',
#      'bstout',
#      'apetersch',
#      'cstillwel',
#      'llavoie'],
#     'time': 712},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -0.88,
#     'pullY': 116.12,
#     'pullMs': 7877},
#    {'type': 30},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'llavoie',
#      'arueda',
#      'ceustis'],
#     'time': 0},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -26.22,
#     'pullY': 67.8,
#     'pullMs': 16025},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'qbuermeye'],
#     'time': 45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 12.02,
#     'throwerY': 20,
#     'receiver': 'jsnyder',
#     'receiverX': -2.87,
#     'receiverY': 23.16},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -2.87,
#     'throwerY': 23.16,
#     'receiver': 'isweeney',
#     'receiverX': -17.77,
#     'receiverY': 30.38},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -17.77,
#     'throwerY': 30.38,
#     'turnoverX': -17,
#     'turnoverY': 100.58},
#    {'type': 11, 'defender': 'efriedman'},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 14.99,
#     'throwerY': 74.77,
#     'receiver': 'jsnyder',
#     'receiverX': 4.28,
#     'receiverY': 84.64},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 4.28,
#     'throwerY': 84.64,
#     'receiver': 'efriedman',
#     'receiverX': -5.45,
#     'receiverY': 76.51},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -5.45,
#     'throwerY': 76.51,
#     'receiver': 'jsnyder',
#     'receiverX': 12.28,
#     'receiverY': 69.61},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 12.28,
#     'throwerY': 69.61,
#     'receiver': 'sfraner',
#     'receiverX': 13.96,
#     'receiverY': 85.67},
#    {'type': 25,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'qbuermeye',
#      'tdoi'],
#     'time': 121},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': 0.41,
#     'throwerY': 98.32,
#     'receiver': 'tdoi',
#     'receiverX': -4.04,
#     'receiverY': 102},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'gnakano',
#      'apetersch',
#      'llavoie',
#      'bstout',
#      'arueda'],
#     'time': 126},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -23.51,
#     'pullY': 78.58,
#     'pullMs': 18591},
#    {'type': 11, 'defender': 'sradlauer'},
#    {'type': 18,
#     'thrower': 'gnakano',
#     'throwerX': 11.44,
#     'throwerY': 83.74,
#     'receiver': 'arueda',
#     'receiverX': 12.22,
#     'receiverY': 76.83},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': 12.22,
#     'throwerY': 76.83,
#     'receiver': 'llavoie',
#     'receiverX': -3.52,
#     'receiverY': 74.51},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -3.52,
#     'throwerY': 74.51,
#     'receiver': 'arueda',
#     'receiverX': 12.73,
#     'receiverY': 68.9},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': 12.73,
#     'throwerY': 68.9,
#     'receiver': 'apetersch',
#     'receiverX': 24.15,
#     'receiverY': 78.7},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 24.15,
#     'throwerY': 78.7,
#     'receiver': 'sradlauer',
#     'receiverX': 9.25,
#     'receiverY': 93.41},
#    {'type': 17},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'sradlauer',
#     'throwerX': 0,
#     'throwerY': 100,
#     'receiver': 'arueda',
#     'receiverX': -1.2,
#     'receiverY': 90.9},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': -1.2,
#     'throwerY': 90.9,
#     'receiver': 'sradlauer',
#     'receiverX': -8.03,
#     'receiverY': 97.03},
#    {'type': 18,
#     'thrower': 'sradlauer',
#     'throwerX': -8.03,
#     'throwerY': 97.03,
#     'receiver': 'arueda',
#     'receiverX': 2.8,
#     'receiverY': 90.77},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': 2.8,
#     'throwerY': 90.77,
#     'receiver': 'jmoore1',
#     'receiverX': -9.39,
#     'receiverY': 90.06},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': -9.39,
#     'throwerY': 90.06,
#     'receiver': 'arueda',
#     'receiverX': -11,
#     'receiverY': 97.54},
#    {'type': 19,
#     'thrower': 'arueda',
#     'throwerX': -11,
#     'throwerY': 97.54,
#     'receiver': 'gnakano',
#     'receiverX': -12.1,
#     'receiverY': 103.87},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'ceustis',
#      'llavoie',
#      'jlee',
#      'apetersch',
#      'qbuermeye'],
#     'time': 170},
#    {'type': 7,
#     'puller': 'jmoore1',
#     'pullX': -25.32,
#     'pullY': 75.93,
#     'pullMs': 11413},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 221},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 3.64,
#     'throwerY': 13.67,
#     'receiver': 'isweeney',
#     'receiverX': 1.12,
#     'receiverY': 25.54},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 1.12,
#     'throwerY': 25.54,
#     'receiver': 'jjohnson1',
#     'receiverX': 20.54,
#     'receiverY': 28.12},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 20.54,
#     'throwerY': 28.12,
#     'receiver': 'rhayes',
#     'receiverX': 4.28,
#     'receiverY': 36.12},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 4.28,
#     'throwerY': 36.12,
#     'receiver': 'isweeney',
#     'receiverX': 8.09,
#     'receiverY': 28.96},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 8.09,
#     'throwerY': 28.96,
#     'receiver': 'efriedman',
#     'receiverX': -19.06,
#     'receiverY': 39.74},
#    {'type': 17},
#    {'type': 16},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -19.06,
#     'throwerY': 39.74,
#     'receiver': 'isweeney',
#     'receiverX': -24.22,
#     'receiverY': 60.32},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -24.22,
#     'throwerY': 60.32,
#     'receiver': 'jjohnson1',
#     'receiverX': 17.25,
#     'receiverY': 62.25},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 17.25,
#     'throwerY': 62.25,
#     'receiver': 'rhayes',
#     'receiverX': 7.12,
#     'receiverY': 79.48},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 7.12,
#     'throwerY': 79.48,
#     'receiver': 'tdoi',
#     'receiverX': 18.15,
#     'receiverY': 92.19},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 18.15,
#     'throwerY': 92.19,
#     'receiver': 'isweeney',
#     'receiverX': 0.8,
#     'receiverY': 82.19},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 0.8,
#     'throwerY': 82.19,
#     'receiver': 'rhayes',
#     'receiverX': 17.96,
#     'receiverY': 91.67},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 17.96,
#     'throwerY': 91.67,
#     'receiver': 'jjohnson1',
#     'receiverX': 24.79,
#     'receiverY': 114.19},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'apetersch',
#      'llavoie',
#      'arueda',
#      'ceustis'],
#     'time': 299},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 10.15,
#     'pullY': 112.25,
#     'pullMs': 7662},
#    {'type': 16},
#    {'type': 11, 'defender': 'llavoie'},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -8.1,
#     'throwerY': 43.03,
#     'receiver': 'jlee',
#     'receiverX': 11.31,
#     'receiverY': 50},
#    {'type': 22,
#     'thrower': 'jlee',
#     'throwerX': 11.31,
#     'throwerY': 50,
#     'turnoverX': 12.34,
#     'turnoverY': 82.06},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'cstillwel',
#      'tdoi'],
#     'time': 377},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 10.22,
#     'throwerY': 17.93,
#     'receiver': 'efriedman',
#     'receiverX': 0.03,
#     'receiverY': 32.64},
#    {'type': 18,
# ...
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': -9.83,
#     'throwerY': 21,
#     'receiver': 'mkissmann',
#     'receiverX': 7.29,
#     'receiverY': 21.47},
#    {'type': 18,
#     'thrower': 'mkissmann',
#     'throwerX': 7.29,
#     'throwerY': 21.47,
#     'receiver': 'wberreman',
#     'receiverX': 0.06,
#     'receiverY': 26.59},
#    {'type': 18,
#     'thrower': 'wberreman',
#     'throwerX': 0.06,
#     'throwerY': 26.59,
#     'receiver': 'gmay',
#     'receiverX': -18.28,
#     'receiverY': 31.22},
#    {'type': 18,
#     'thrower': 'gmay',
#     'throwerX': -18.28,
#     'throwerY': 31.22,
#     'receiver': 'mcrawford',
#     'receiverX': 3.81,
#     'receiverY': 30.81},
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': 3.81,
#     'throwerY': 30.81,
#     'receiver': 'gmay',
#     'receiverX': -2.05,
#     'receiverY': 28.77},
#    {'type': 22,
#     'thrower': 'gmay',
#     'throwerX': -2.05,
#     'throwerY': 28.77,
#     'turnoverX': 16.3,
#     'turnoverY': 37.15},
#    {'type': 16},
#    {'type': 25,
#     'line': ['gmay',
#      'mcrawford',
#      'kkhangaon',
#      'msommer',
#      'mkissmann',
#      'wberreman',
#      'rmendoza'],
#     'time': 121},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 126},
#    {'type': 20,
#     'thrower': 'mhecht',
#     'throwerX': 25.98,
#     'throwerY': 53.72,
#     'receiver': 'dclyburn',
#     'receiverX': 1.09,
#     'receiverY': 50.59},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 170},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': -26.67,
#     'throwerY': 41.59,
#     'receiver': 'wfrankenb',
#     'receiverX': -19.31,
#     'receiverY': 32.45},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -19.31,
#     'throwerY': 32.45,
#     'receiver': 'emagsig',
#     'receiverX': 0.54,
#     'receiverY': 30.95},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 0.54,
#     'throwerY': 30.95,
#     'receiver': 'wfrankenb',
#     'receiverX': -21.62,
#     'receiverY': 39.88},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -21.62,
#     'throwerY': 39.88,
#     'receiver': 'emagsig',
#     'receiverX': -22.85,
#     'receiverY': 45.95},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -22.85,
#     'throwerY': 45.95,
#     'receiver': 'mhecht',
#     'receiverX': 0.47,
#     'receiverY': 43.77},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 0.47,
#     'throwerY': 43.77,
#     'receiver': 'mwilliams',
#     'receiverX': 16.84,
#     'receiverY': 49.77},
#    {'type': 18,
#     'thrower': 'mwilliams',
#     'throwerX': 16.84,
#     'throwerY': 49.77,
#     'receiver': 'mhecht',
#     'receiverX': 23.05,
#     'receiverY': 48.61},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 23.05,
#     'throwerY': 48.61,
#     'receiver': 'klaurence',
#     'receiverX': 2.38,
#     'receiverY': 56.86},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': 2.38,
#     'throwerY': 56.86,
#     'receiver': 'mwilliams',
#     'receiverX': -19.1,
#     'receiverY': 56.79},
#    {'type': 18,
#     'thrower': 'mwilliams',
#     'throwerX': -19.1,
#     'throwerY': 56.79,
#     'receiver': 'klaurence',
#     'receiverX': -22.78,
#     'receiverY': 61.36},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -22.78,
#     'throwerY': 61.36,
#     'receiver': 'wfrankenb',
#     'receiverX': -23.13,
#     'receiverY': 68.79},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -23.13,
#     'throwerY': 68.79,
#     'receiver': 'dclyburn',
#     'receiverX': -20.87,
#     'receiverY': 74.04},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': -20.87,
#     'throwerY': 74.04,
#     'receiver': 'mhecht',
#     'receiverX': -24.63,
#     'receiverY': 86.38},
#    {'type': 19,
#     'thrower': 'mhecht',
#     'throwerX': -24.63,
#     'throwerY': 86.38,
#     'receiver': 'clung',
#     'receiverX': -23.4,
#     'receiverY': 108.2},
#    {'type': 1,
#     'line': ['rvickersb',
#      'pxu',
#      'jdecampos',
#      'mburke1',
#      'cbauman',
#      'rmendoza',
#      'wberreman'],
#     'time': 221},
#    {'type': 7,
#     'puller': 'cbauman',
#     'pullX': -2.05,
#     'pullY': 110.59,
#     'pullMs': 0},
#    {'type': 16},
#    {'type': 17},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 289},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -22.37,
#     'throwerY': 18.06,
#     'receiver': 'clung',
#     'receiverX': 2.59,
#     'receiverY': 23.59},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 2.59,
#     'throwerY': 33.59,
#     'receiver': 'wfrankenb',
#     'receiverX': 19.5,
#     'receiverY': 34.84},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 19.5,
#     'throwerY': 34.84,
#     'receiver': 'clung',
#     'receiverX': 11.18,
#     'receiverY': 37.77},
#    {'type': 22,
#     'thrower': 'clung',
#     'throwerX': 11.18,
#     'throwerY': 37.77,
#     'turnoverX': -21.9,
#     'turnoverY': 75.68},
#    {'type': 11, 'defender': 'klaurence'},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'wfrankenb',
#     'receiverX': -17.87,
#     'receiverY': 52.36},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -17.87,
#     'throwerY': 52.36,
#     'receiver': 'klaurence',
#     'receiverX': -14.74,
#     'receiverY': 58.63},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -14.74,
#     'throwerY': 58.63,
#     'receiver': 'wfrankenb',
#     'receiverX': -21.35,
#     'receiverY': 71.31},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -21.35,
#     'throwerY': 71.31,
#     'receiver': 'klaurence',
#     'receiverX': 1.22,
#     'receiverY': 64.9},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': 1.22,
#     'throwerY': 64.9,
#     'receiver': 'dclyburn',
#     'receiverX': 18.89,
#     'receiverY': 80.31},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 18.89,
#     'throwerY': 80.31,
#     'receiver': 'mwilliams',
#     'receiverX': 23.46,
#     'receiverY': 89.52},
#    {'type': 18,
#     'thrower': 'mwilliams',
#     'throwerX': 23.46,
#     'throwerY': 89.52,
#     'receiver': 'mhecht',
#     'receiverX': 22.77,
#     'receiverY': 81.27},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 22.77,
#     'throwerY': 81.27,
#     'receiver': 'emagsig',
#     'receiverX': -1.51,
#     'receiverY': 79.22},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -1.51,
#     'throwerY': 79.22,
#     'receiver': 'mhecht',
#     'receiverX': -14.33,
#     'receiverY': 84.27},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': -14.33,
#     'throwerY': 84.27,
#     'receiver': 'emagsig',
#     'receiverX': -0.21,
#     'receiverY': 79.29},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -0.21,
#     'throwerY': 79.29,
#     'receiver': 'mhecht',
#     'receiverX': 12,
#     'receiverY': 81},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 12,
#     'throwerY': 81,
#     'receiver': 'emagsig',
#     'receiverX': 0.75,
#     'receiverY': 81.68},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 0.75,
#     'throwerY': 81.68,
#     'receiver': 'dclyburn',
#     'receiverX': -21.56,
#     'receiverY': 90.13},
#    {'type': 19,
#     'thrower': 'dclyburn',
#     'throwerX': -21.56,
#     'throwerY': 90.13,
#     'receiver': 'emagsig',
#     'receiverX': -18.01,
#     'receiverY': 109.97},
#    {'type': 1,
#     'line': ['gmay',
#      'rcastro',
#      'mcrawford',
#      'kkhangaon',
#      'msommer',
#      'mkissmann',
#      'mburke1'],
#     'time': 377},
#    {'type': 7,
#     'puller': 'mkissmann',
#     'pullX': 2.25,
#     'pullY': 107.38,
#     'pullMs': 6913},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 413},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': -6.14,
#     'throwerY': 11.52,
#     'receiver': 'wfrankenb',
#     'receiverX': 2.52,
#     'receiverY': 19.9},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 2.52,
#     'throwerY': 19.9,
#     'receiver': 'clung',
#     'receiverX': 19.16,
#     'receiverY': 28.43},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 19.16,
#     'throwerY': 28.43,
#     'receiver': 'wfrankenb',
#     'receiverX': 23.32,
#     'receiverY': 35.04},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 23.32,
#     'throwerY': 35.04,
#     'receiver': 'clung',
#     'receiverX': 23.93,
#     'receiverY': 40.15},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 23.93,
#     'throwerY': 40.15,
#     'receiver': 'dclyburn',
#     'receiverX': 24.68,
#     'receiverY': 49.36},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 24.68,
#     'throwerY': 49.36,
#     'receiver': 'clung',
#     'receiverX': 15.48,
#     'receiverY': 53.86},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 15.48,
#     'throwerY': 53.86,
#     'receiver': 'dclyburn',
#     'receiverX': 20.8,
#     'receiverY': 64.56},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 20.8,
#     'throwerY': 64.56,
#     'receiver': 'clung',
#     'receiverX': 17.59,
#     'receiverY': 74.11},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 17.59,
#     'throwerY': 74.11,
#     'receiver': 'mhecht',
#     'receiverX': 3.27,
#     'receiverY': 82.77},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 3.27,
#     'throwerY': 82.77,
#     'receiver': 'emagsig',
#     'receiverX': 21.96,
#     'receiverY': 91.15},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 21.96,
#     'throwerY': 91.15,
#     'receiver': 'mhecht',
#     'receiverX': 24.48,
#     'receiverY': 94.7},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 24.48,
#     'throwerY': 100,
#     'receiver': 'wfrankenb',
#     'receiverX': 19.98,
#     'receiverY': 98.11},
#    {'type': 19,
#     'thrower': 'wfrankenb',
#     'throwerX': 19.98,
#     'throwerY': 98.11,
#     'receiver': 'dclyburn',
#     'receiverX': 7.36,
#     'receiverY': 104.72},
#    {'type': 1,
#     'line': ['rvickersb',
#      'pxu',
#      'jdecampos',
#      'mburke1',
#      'cbauman',
#      'rmendoza',
#      'wberreman'],
#     'time': 478},
#    {'type': 7,
#     'puller': 'cbauman',
#     'pullX': 0.13,
#     'pullY': 106.09,
#     'pullMs': 3832},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 507},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'emagsig',
#     'receiverX': -3.35,
#     'receiverY': 38.86},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -3.35,
#     'throwerY': 38.86,
#     'receiver': 'klaurence',
#     'receiverX': -16.71,
#     'receiverY': 43.09},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -16.71,
#     'throwerY': 43.09,
#     'receiver': 'mhecht',
#     'receiverX': -17.26,
#     'receiverY': 57.54},
#    {'type': 22,
#     'thrower': 'mhecht',
#     'throwerX': -17.26,
#     'throwerY': 57.54,
#     'turnoverX': -14.8,
#     'turnoverY': 63.75},
#    {'type': 15},
#    {'type': 2,
#     'line': ['gmay',
#      'rcastro',
#      'mcrawford',
#      'kkhangaon',
#      'msommer',
#      'mkissmann',
#      'mhecht'],
#     'time': 545},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 26.66,
#     'throwerY': 49.22,
#     'receiver': 'kkhangaon',
#     'receiverX': 19.84,
#     'receiverY': 63.88},
#    {'type': 18,
#     'thrower': 'kkhangaon',
#     'throwerX': 19.84,
#     'throwerY': 63.88,
#     'receiver': 'mcrawford',
#     'receiverX': 1.09,
#     'receiverY': 56.38},
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': 1.09,
#     'throwerY': 56.38,
#     'receiver': 'mhecht',
#     'receiverX': 7.91,
#     'receiverY': 55.36},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 7.91,
#     'throwerY': 55.36,
#     'receiver': 'mkissmann',
#     'receiverX': 22.71,
#     'receiverY': 66.34},
#    {'type': 18,
#     'thrower': 'mkissmann',
#     'throwerX': 22.71,
#     'throwerY': 66.34,
#     'receiver': 'mhecht',
#     'receiverX': 4.5,
#     'receiverY': 72.06},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 4.5,
#     'throwerY': 72.06,
#     'receiver': 'mcrawford',
#     'receiverX': -16.65,
#     'receiverY': 77.86},
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': -16.65,
#     'throwerY': 77.86,
#     'receiver': 'msommer',
#     'receiverX': -23.19,
#     'receiverY': 92.86},
#    {'type': 18,
#     'thrower': 'msommer',
#     'throwerX': -23.19,
#     'throwerY': 92.86,
#     'receiver': 'mhecht',
#     'receiverX': -4.44,
#     'receiverY': 90.27},
#    {'type': 19,
#     'thrower': 'mhecht',
#     'throwerX': -4.44,
#     'throwerY': 90.27,
#     'receiver': 'msommer',
#     'receiverX': -0.69,
#     'receiverY': 104.04},
#    {'type': 1,
#     'line': ['rvickersb',
#      'pxu',
#      'jdecampos',
#      'mburke1',
#      'cbauman',
#      'rmendoza',
#      'wberreman'],
#     'time': 584},
#    {'type': 7,
#     'puller': 'cbauman',
#     'pullX': 22.84,
#     'pullY': 112.97,
#     'pullMs': 6245},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 608},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 26.66,
#     'throwerY': 54.61,
#     'receiver': 'dclyburn',
#     'receiverX': 4.5,
#     'receiverY': 38.45},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 4.5,
#     'throwerY': 38.45,
#     'receiver': 'wfrankenb',
#     'receiverX': 12.48,
#     'receiverY': 40.97},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 12.48,
#     'throwerY': 40.97,
#     'receiver': 'mhecht',
#     'receiverX': 2.11,
#     'receiverY': 36.95},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 2.11,
#     'throwerY': 36.95,
#     'receiver': 'klaurence',
#     'receiverX': -17.74,
#     'receiverY': 38.11},
#    {'type': 22,
#     'thrower': 'klaurence',
#     'throwerX': -17.74,
#     'throwerY': 38.11,
#     'turnoverX': -4.85,
#     'turnoverY': 29.38},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 659},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 25.5,
#     'throwerY': 55.09,
#     'receiver': 'klaurence',
#     'receiverX': -7.64,
#     'receiverY': 66.2},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -7.64,
#     'throwerY': 66.2,
#     'receiver': 'emagsig',
#     'receiverX': -4.37,
#     'receiverY': 71.25},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -4.37,
#     'throwerY': 71.25,
#     'receiver': 'klaurence',
#     'receiverX': -13.71,
#     'receiverY': 71.18},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -13.71,
#     'throwerY': 71.18,
#     'receiver': 'wfrankenb',
#     'receiverX': -23.74,
#     'receiverY': 82.36},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -23.74,
#     'throwerY': 82.36,
#     'receiver': 'emagsig',
#     'receiverX': -24.08,
#     'receiverY': 91.43},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -24.08,
#     'throwerY': 91.43,
#     'receiver': 'wfrankenb',
#     'receiverX': -6.42,
#     'receiverY': 86.86},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -6.42,
#     'throwerY': 86.86,
#     'receiver': 'emagsig',
#     'receiverX': 5.66,
#     'receiverY': 91.09},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 5.66,
#     'throwerY': 91.09,
#     'receiver': 'mhecht',
#     'receiverX': -4.92,
#     'receiverY': 95.31},
#    {'type': 19,
#     'thrower': 'mhecht',
#     'throwerX': -4.92,
#     'throwerY': 95.31,
#     'receiver': 'clung',
#     'receiverX': 5.59,
#     'receiverY': 103.7},
#    {'type': 1,
#     'line': ['gmay',
#      'wberreman',
#      'emagsig',
#      'dclyburn',
#      'rmendoza',
#      'rvickersb',
#      'mburke1'],
#     'time': 687},
#    {'type': 8, 'puller': 'emagsig'},
#    {'type': 13},
#    {'type': 3,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 718},
#    {'type': 31}]}}

# %%
len(data['data']['homeEvents'])
# Out:
# 406

# %%
len(data['data']['awayEvents'])
# Out:
# 418

# %%
data.keys()
# Out:
# dict_keys(['object', 'data'])

# %%
data['data']['homeEvents'][0:50]
# Out:
# [{'type': 2,
#   'line': ['jjohnson1',
#    'efriedman',
#    'jsnyder',
#    'rhayes',
#    'sfraner',
#    'isweeney',
#    'tdoi'],
#   'time': 0,
#   'desc': 'O_line'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -16.1,
#   'throwerY': 7.22,
#   'receiver': 'jjohnson1',
#   'receiverX': -1.46,
#   'receiverY': 15.54,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': -1.46,
#   'throwerY': 15.54,
#   'receiver': 'efriedman',
#   'receiverX': -17.13,
#   'receiverY': 21.22,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -17.13,
#   'throwerY': 21.22,
#   'receiver': 'jsnyder',
#   'receiverX': -17.45,
#   'receiverY': 94.7,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': -17.45,
#   'throwerY': 94.7,
#   'receiver': 'rhayes',
#   'receiverX': -17.39,
#   'receiverY': 86.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -17.39,
#   'throwerY': 86.83,
#   'receiver': 'sfraner',
#   'receiverX': -17.06,
#   'receiverY': 74.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -17.06,
#   'throwerY': 74.83,
#   'receiver': 'efriedman',
#   'receiverX': 0.35,
#   'receiverY': 63.8,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 0.35,
#   'throwerY': 63.8,
#   'receiver': 'isweeney',
#   'receiverX': -19.19,
#   'receiverY': 80.25,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -19.19,
#   'throwerY': 80.25,
#   'receiver': 'efriedman',
#   'receiverX': 2.67,
#   'receiverY': 74.58,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'efriedman',
#   'throwerX': 2.67,
#   'throwerY': 74.58,
#   'turnoverX': -13.71,
#   'turnoverY': 86.06,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -4.68,
#   'throwerY': 20,
#   'receiver': 'jjohnson1',
#   'receiverX': 17.12,
#   'receiverY': 18.12,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': 17.12,
#   'throwerY': 18.12,
#   'receiver': 'isweeney',
#   'receiverX': -14.81,
#   'receiverY': 16.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -14.81,
#   'throwerY': 16.32,
#   'receiver': 'sfraner',
#   'receiverX': -23,
#   'receiverY': 34.96,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -23,
#   'throwerY': 34.96,
#   'receiver': 'rhayes',
#   'receiverX': -11.07,
#   'receiverY': 36,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -11.07,
#   'throwerY': 36,
#   'receiver': 'efriedman',
#   'receiverX': 2.03,
#   'receiverY': 36.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 2.03,
#   'throwerY': 36.32,
#   'receiver': 'tdoi',
#   'receiverX': 18.15,
#   'receiverY': 34.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'tdoi',
#   'throwerX': 18.15,
#   'throwerY': 34.38,
#   'receiver': 'efriedman',
#   'receiverX': 9.31,
#   'receiverY': 30.9,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 9.31,
#   'throwerY': 30.9,
#   'receiver': 'isweeney',
#   'receiverX': -11.26,
#   'receiverY': 24.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -11.26,
#   'throwerY': 24.38,
#   'receiver': 'efriedman',
#   'receiverX': 11.51,
#   'receiverY': 30.77,
#   'desc': 'Pass'},
#  {'type': 19,
#   'thrower': 'efriedman',
#   'throwerX': 11.51,
#   'throwerY': 30.77,
#   'receiver': 'tdoi',
#   'receiverX': 10.54,
#   'receiverY': 108.45,
#   'desc': 'Goal'},
#  {'type': 1,
#   'line': ['sradlauer',
#    'jmoore1',
#    'llavoie',
#    'jlee',
#    'arueda',
#    'bstout',
#    'apetersch'],
#   'time': 115,
#   'desc': 'D_line'},
#  {'type': 7,
#   'puller': 'sradlauer',
#   'pullX': 0.87,
#   'pullY': 94.96,
#   'pullMs': 3080,
#   'desc': 'Pull_in'},
#  {'type': 11, 'defender': 'sradlauer', 'desc': 'Block'},
#  {'type': 18,
#   'thrower': 'apetersch',
#   'throwerX': 25.63,
#   'throwerY': 67.29,
#   'receiver': 'jlee',
#   'receiverX': 6.54,
#   'receiverY': 58.64,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jlee',
#   'throwerX': 6.54,
#   'throwerY': 58.64,
#   'receiver': 'jmoore1',
#   'receiverX': -18.67,
#   'receiverY': 53.61,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jmoore1',
#   'throwerX': -18.67,
#   'throwerY': 53.61,
#   'receiver': 'llavoie',
#   'receiverX': 11.18,
#   'receiverY': 59.93,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'llavoie',
#   'throwerX': 11.18,
#   'throwerY': 59.93,
#   'turnoverX': 20.79,
#   'turnoverY': 104.06,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'llavoie',
#   'throwerX': 24.86,
#   'throwerY': 45.03,
#   'receiver': 'jlee',
#   'receiverX': 22.47,
#   'receiverY': 30.32,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'jlee',
#   'throwerX': 22.47,
#   'throwerY': 30.32,
#   'turnoverX': 24.02,
#   'turnoverY': 50.64,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'jlee',
#   'throwerX': 14.92,
#   'throwerY': 39.41,
#   'receiver': 'llavoie',
#   'receiverX': -0.42,
#   'receiverY': 46.51,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'llavoie',
#   'throwerX': -0.42,
#   'throwerY': 46.51,
#   'receiver': 'jmoore1',
#   'receiverX': -18.74,
#   'receiverY': 56.45,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'jmoore1',
#   'throwerX': -18.74,
#   'throwerY': 56.45,
#   'turnoverX': -10.42,
#   'turnoverY': 106.64,
#   'desc': 'Throwaway_own'},
#  {'type': 15, 'desc': 'Score_opp'},
#  {'type': 2,
#   'line': ['efriedman',
#    'jsnyder',
#    'rhayes',
#    'sfraner',
#    'tdoi',
#    'isweeney',
#    'qbuermeye'],
#   'time': 256,
#   'desc': 'O_line'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': -0.04,
#   'throwerY': 14.32,
#   'receiver': 'isweeney',
#   'receiverX': -6.1,
#   'receiverY': 19.35,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -6.1,
#   'throwerY': 19.35,
#   'receiver': 'efriedman',
#   'receiverX': -16.48,
#   'receiverY': 32.45,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -16.48,
#   'throwerY': 32.45,
#   'receiver': 'qbuermeye',
#   'receiverX': -22.74,
#   'receiverY': 41.93,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'qbuermeye',
#   'throwerX': -22.74,
#   'throwerY': 41.93,
#   'receiver': 'sfraner',
#   'receiverX': -16.93,
#   'receiverY': 51.09,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -16.93,
#   'throwerY': 51.09,
#   'receiver': 'rhayes',
#   'receiverX': -23.19,
#   'receiverY': 60.77,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -23.19,
#   'throwerY': 60.77,
#   'receiver': 'efriedman',
#   'receiverX': -13.45,
#   'receiverY': 66.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -13.45,
#   'throwerY': 66.38,
#   'receiver': 'rhayes',
#   'receiverX': -25.58,
#   'receiverY': 72.58,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -25.58,
#   'throwerY': 72.58,
#   'receiver': 'efriedman',
#   'receiverX': -5.71,
#   'receiverY': 63.87,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -5.71,
#   'throwerY': 63.87,
#   'receiver': 'sfraner',
#   'receiverX': -17.84,
#   'receiverY': 80.06,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -17.84,
#   'throwerY': 80.06,
#   'receiver': 'jsnyder',
#   'receiverX': 0.93,
#   'receiverY': 70.9,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': 0.93,
#   'throwerY': 70.9,
#   'receiver': 'rhayes',
#   'receiverX': 15.5,
#   'receiverY': 90.7,
#   'desc': 'Pass'},
#  {'type': 19,
#   'thrower': 'rhayes',
#   'throwerX': 15.5,
#   'throwerY': 90.7,
#   'receiver': 'qbuermeye',
#   'receiverX': 14.28,
#   'receiverY': 104.58,
#   'desc': 'Goal'},
#  {'type': 1,
#   'line': ['jmoore1',
#    'apetersch',
#    'arueda',
#    'gnakano',
#    'bstout',
#    'slatarski',
#    'jlee'],
#   'time': 316,
#   'desc': 'D_line'}]

# %%
# https://www.docs.audlstats.com/events

events = [
    'D_line',
    'O_line',
    'Timeout_own_line',
    'Timeout_own',
    'Timeout_opp_line',
    'Timeout_opp',
    'Pull_in',
    'Pull_out',
    'Offsides_own',
    'Offsides_opp',
    'Block',
    'Callahan_opp',
    'Throwaway_opp',
    'Stall_opp',
    'Score_opp',
    'Penalty_own',
    'Penalty_opp',
    'Pass',
    'Goal',
    'Drop',
    'Drop_pull',
    'Throwaway_own',
    'Callahan_own',
    'Stall_own',
    'Injury_line',
    'Player_misconduct',
    'Player_ejection',
    'End_Q1',
    'End_Q2',
    'End_Q3',
    'End_Q4',
    'End_OT1',
    'End_OT2',
    'Delayed',
    'Postponed',
]

# %%
event_keys = {}
for i,val in enumerate(events):
    event_keys[i+1]=val

# %%
for etype in ['homeEvents','awayEvents']:
    for event in data['data'][etype]:
        event['desc'] = event_keys[event['type']]

# %%
event_keys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11168\2857502148.py in <module>
# ----> 1 event_keys
#
# NameError: name 'event_keys' is not defined

# %% [markdown]
# **Go through home or away events, see if I can split by each score/timeout/injury**
#
#  - should probably characterize by O/D eventually
#  - would have to cross reference home/away events to get complete information about turnovers
#
# Possible Data's
#
#  - line info
#  - time, starts at 0 every quarter up to 720s (12 mins)
#  - playerID (line arrays, puller, thrower, receiver, defender, misconduct foul, ejected)
#  - pull info (`X`,`Y` for where it was brought into play, hangtime `Ms`)
#  - player coordinates (thrower, receiver, turnover)

# %%
# line substitutions within a point, injury or timeout
for i,event in enumerate(data['data']['homeEvents']):
    if event['type'] in [3,5,25]:
        print(i,event_keys[event['type']],event)
for i,event in enumerate(data['data']['awayEvents']):
    if event['type'] in [3,5,25]:
        print(i,event_keys[event['type']],event)
# Out:
# 67 Timeout_own_line {'type': 3, 'line': ['bstout', 'rhayes', 'qbuermeye', 'apetersch', 'jlee', 'isweeney', 'jmoore1'], 'time': 403}
# 177 Timeout_opp_line {'type': 5, 'line': ['sradlauer', 'jmoore1', 'jlee', 'gnakano', 'bstout', 'apetersch', 'qbuermeye'], 'time': 610}
# 228 Injury_line {'type': 25, 'line': ['sradlauer', 'jmoore1', 'jlee', 'gnakano', 'apetersch', 'arueda', 'bstout'], 'time': 291}
# 284 Timeout_own_line {'type': 3, 'line': ['jjohnson1', 'efriedman', 'jsnyder', 'rhayes', 'sfraner', 'isweeney', 'qbuermeye'], 'time': 698}
# 304 Injury_line {'type': 25, 'line': ['jjohnson1', 'efriedman', 'jsnyder', 'rhayes', 'isweeney', 'qbuermeye', 'tdoi'], 'time': 121}
# 404 Timeout_opp_line {'type': 5, 'line': ['sradlauer', 'rhayes', 'cstillwel', 'isweeney', 'bstout', 'jsnyder', 'slatarski'], 'time': 718}
# 36 Timeout_opp_line {'type': 5, 'line': ['rvickersb', 'pxu', 'jdecampos', 'mburke1', 'cbauman', 'rmendoza', 'wberreman'], 'time': 403}
# 157 Timeout_opp_line {'type': 5, 'line': ['gmay', 'rcastro', 'rvickersb', 'kkhangaon', 'jdecampos', 'mburke1', 'wberreman'], 'time': 576}
# 159 Timeout_own_line {'type': 3, 'line': ['wfrankenb', 'dclyburn', 'clung', 'emagsig', 'klaurence', 'mhecht', 'mwilliams'], 'time': 611}
# 225 Injury_line {'type': 25, 'line': ['wfrankenb', 'dclyburn', 'emagsig', 'klaurence', 'mhecht', 'mwilliams', 'gmay'], 'time': 291}
# 283 Timeout_opp_line {'type': 5, 'line': ['rvickersb', 'pxu', 'jdecampos', 'mburke1', 'cbauman', 'rmendoza', 'wberreman'], 'time': 699}
# 310 Injury_line {'type': 25, 'line': ['gmay', 'mcrawford', 'kkhangaon', 'msommer', 'mkissmann', 'wberreman', 'rmendoza'], 'time': 121}
# 416 Timeout_own_line {'type': 3, 'line': ['wfrankenb', 'dclyburn', 'clung', 'emagsig', 'klaurence', 'mhecht', 'mwilliams'], 'time': 718}

# %% [markdown]
# ### Flow of a Point
#
# *can always use point start to split points*
#
#  1. Start point with `O_line` or `D_line`, note players on the field.
#    a. adjustments needed if event type in 3,5,25. All players can be subbed on timeouts.
#  2. Series of events from 7-27 (excepting Callahans), starting with 7 or 8 `Pull_in` or `Pull_out`
#  3. Point ends with quarter (28-33) or some type of score (

# %%
# count points for home and away to check
pointcounter = {'homeEvents':{'O':0,'D':0},
                'awayEvents':{'O':0,'D':0}
               }

for etype in ['homeEvents','awayEvents']:
    for event in data['data'][etype]:
        if event['type'] < 3:
            if event['type'] == 2:
                pointcounter[etype]['O'] += 1 
            else:
                pointcounter[etype]['D'] += 1

# %%
pointcounter
# Out:
# {'homeEvents': {'O': 26, 'D': 24}, 'awayEvents': {'O': 24, 'D': 26}}

# %%
# attempt to number the groups of events by points for cross referencing

from collections import defaultdict

# %%
home_points = defaultdict(list)
k = 0

for event in data['data']['homeEvents']:
    if event['type'] < 3:
        k+=1
    home_points[k].append(event)

# %%
away_points = defaultdict(list)
k = 0

for event in data['data']['awayEvents']:
    if event['type'] < 3:
        k+=1
    away_points[k].append(event)

# %%
k
# Out:
# 50

# %% [markdown]
# ### Flow of Point, considering everything
#
#  1. Start with D, pull
#    - pull in both lines
#    - find which team is pulling
#  2. Then go to O,
#  3. Switch teams with any kind of turnover
#    - turnovers (offensive perspective): 20,21,22,23\*,24
#    - Drop, Dropped pull, throwaway, Callahan\*, Stall
#    - How to handle "Blocks", 11?

# %%
home_points[1]
# Out:
# [{'type': 2,
#   'line': ['jjohnson1',
#    'efriedman',
#    'jsnyder',
#    'rhayes',
#    'sfraner',
#    'isweeney',
#    'tdoi'],
#   'time': 0,
#   'desc': 'O_line'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -16.1,
#   'throwerY': 7.22,
#   'receiver': 'jjohnson1',
#   'receiverX': -1.46,
#   'receiverY': 15.54,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': -1.46,
#   'throwerY': 15.54,
#   'receiver': 'efriedman',
#   'receiverX': -17.13,
#   'receiverY': 21.22,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -17.13,
#   'throwerY': 21.22,
#   'receiver': 'jsnyder',
#   'receiverX': -17.45,
#   'receiverY': 94.7,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': -17.45,
#   'throwerY': 94.7,
#   'receiver': 'rhayes',
#   'receiverX': -17.39,
#   'receiverY': 86.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -17.39,
#   'throwerY': 86.83,
#   'receiver': 'sfraner',
#   'receiverX': -17.06,
#   'receiverY': 74.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -17.06,
#   'throwerY': 74.83,
#   'receiver': 'efriedman',
#   'receiverX': 0.35,
#   'receiverY': 63.8,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 0.35,
#   'throwerY': 63.8,
#   'receiver': 'isweeney',
#   'receiverX': -19.19,
#   'receiverY': 80.25,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -19.19,
#   'throwerY': 80.25,
#   'receiver': 'efriedman',
#   'receiverX': 2.67,
#   'receiverY': 74.58,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'efriedman',
#   'throwerX': 2.67,
#   'throwerY': 74.58,
#   'turnoverX': -13.71,
#   'turnoverY': 86.06,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -4.68,
#   'throwerY': 20,
#   'receiver': 'jjohnson1',
#   'receiverX': 17.12,
#   'receiverY': 18.12,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': 17.12,
#   'throwerY': 18.12,
#   'receiver': 'isweeney',
#   'receiverX': -14.81,
#   'receiverY': 16.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -14.81,
#   'throwerY': 16.32,
#   'receiver': 'sfraner',
#   'receiverX': -23,
#   'receiverY': 34.96,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -23,
#   'throwerY': 34.96,
#   'receiver': 'rhayes',
#   'receiverX': -11.07,
#   'receiverY': 36,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -11.07,
#   'throwerY': 36,
#   'receiver': 'efriedman',
#   'receiverX': 2.03,
#   'receiverY': 36.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 2.03,
#   'throwerY': 36.32,
#   'receiver': 'tdoi',
#   'receiverX': 18.15,
#   'receiverY': 34.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'tdoi',
#   'throwerX': 18.15,
#   'throwerY': 34.38,
#   'receiver': 'efriedman',
#   'receiverX': 9.31,
#   'receiverY': 30.9,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 9.31,
#   'throwerY': 30.9,
#   'receiver': 'isweeney',
#   'receiverX': -11.26,
#   'receiverY': 24.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -11.26,
#   'throwerY': 24.38,
#   'receiver': 'efriedman',
#   'receiverX': 11.51,
#   'receiverY': 30.77,
#   'desc': 'Pass'},
#  {'type': 19,
#   'thrower': 'efriedman',
#   'throwerX': 11.51,
#   'throwerY': 30.77,
#   'receiver': 'tdoi',
#   'receiverX': 10.54,
#   'receiverY': 108.45,
#   'desc': 'Goal'}]

# %% [markdown]
# ### Field Description Notes
#
#  - home/away score is for end of event
#  - quarter and time are for start of event
#    - time is time left in the period (s)
#  - event cols are booleans
#  - team cols are home/away
#  - `pullMs` is a float for inbounds pull, None for OB pull
#    - same with X/Y
#    - *are dropped pull coordinates (X,Y for receiver) needed in addition to pull X/Y?*

# %%
data
# Out:
# {'object': 'object',
#  'data': {'homeEvents': [{'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 0},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -16.1,
#     'throwerY': 7.22,
#     'receiver': 'jjohnson1',
#     'receiverX': -1.46,
#     'receiverY': 15.54},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -1.46,
#     'throwerY': 15.54,
#     'receiver': 'efriedman',
#     'receiverX': -17.13,
#     'receiverY': 21.22},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -17.13,
#     'throwerY': 21.22,
#     'receiver': 'jsnyder',
#     'receiverX': -17.45,
#     'receiverY': 94.7},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -17.45,
#     'throwerY': 94.7,
#     'receiver': 'rhayes',
#     'receiverX': -17.39,
#     'receiverY': 86.83},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -17.39,
#     'throwerY': 86.83,
#     'receiver': 'sfraner',
#     'receiverX': -17.06,
#     'receiverY': 74.83},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -17.06,
#     'throwerY': 74.83,
#     'receiver': 'efriedman',
#     'receiverX': 0.35,
#     'receiverY': 63.8},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0.35,
#     'throwerY': 63.8,
#     'receiver': 'isweeney',
#     'receiverX': -19.19,
#     'receiverY': 80.25},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -19.19,
#     'throwerY': 80.25,
#     'receiver': 'efriedman',
#     'receiverX': 2.67,
#     'receiverY': 74.58},
#    {'type': 22,
#     'thrower': 'efriedman',
#     'throwerX': 2.67,
#     'throwerY': 74.58,
#     'turnoverX': -13.71,
#     'turnoverY': 86.06},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -4.68,
#     'throwerY': 20,
#     'receiver': 'jjohnson1',
#     'receiverX': 17.12,
#     'receiverY': 18.12},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 17.12,
#     'throwerY': 18.12,
#     'receiver': 'isweeney',
#     'receiverX': -14.81,
#     'receiverY': 16.32},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -14.81,
#     'throwerY': 16.32,
#     'receiver': 'sfraner',
#     'receiverX': -23,
#     'receiverY': 34.96},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -23,
#     'throwerY': 34.96,
#     'receiver': 'rhayes',
#     'receiverX': -11.07,
#     'receiverY': 36},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -11.07,
#     'throwerY': 36,
#     'receiver': 'efriedman',
#     'receiverX': 2.03,
#     'receiverY': 36.32},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 2.03,
#     'throwerY': 36.32,
#     'receiver': 'tdoi',
#     'receiverX': 18.15,
#     'receiverY': 34.38},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 18.15,
#     'throwerY': 34.38,
#     'receiver': 'efriedman',
#     'receiverX': 9.31,
#     'receiverY': 30.9},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 9.31,
#     'throwerY': 30.9,
#     'receiver': 'isweeney',
#     'receiverX': -11.26,
#     'receiverY': 24.38},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -11.26,
#     'throwerY': 24.38,
#     'receiver': 'efriedman',
#     'receiverX': 11.51,
#     'receiverY': 30.77},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': 11.51,
#     'throwerY': 30.77,
#     'receiver': 'tdoi',
#     'receiverX': 10.54,
#     'receiverY': 108.45},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'llavoie',
#      'jlee',
#      'arueda',
#      'bstout',
#      'apetersch'],
#     'time': 115},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': 0.87,
#     'pullY': 94.96,
#     'pullMs': 3080},
#    {'type': 11, 'defender': 'sradlauer'},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 25.63,
#     'throwerY': 67.29,
#     'receiver': 'jlee',
#     'receiverX': 6.54,
#     'receiverY': 58.64},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': 6.54,
#     'throwerY': 58.64,
#     'receiver': 'jmoore1',
#     'receiverX': -18.67,
#     'receiverY': 53.61},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': -18.67,
#     'throwerY': 53.61,
#     'receiver': 'llavoie',
#     'receiverX': 11.18,
#     'receiverY': 59.93},
#    {'type': 22,
#     'thrower': 'llavoie',
#     'throwerX': 11.18,
#     'throwerY': 59.93,
#     'turnoverX': 20.79,
#     'turnoverY': 104.06},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': 24.86,
#     'throwerY': 45.03,
#     'receiver': 'jlee',
#     'receiverX': 22.47,
#     'receiverY': 30.32},
#    {'type': 22,
#     'thrower': 'jlee',
#     'throwerX': 22.47,
#     'throwerY': 30.32,
#     'turnoverX': 24.02,
#     'turnoverY': 50.64},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': 14.92,
#     'throwerY': 39.41,
#     'receiver': 'llavoie',
#     'receiverX': -0.42,
#     'receiverY': 46.51},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -0.42,
#     'throwerY': 46.51,
#     'receiver': 'jmoore1',
#     'receiverX': -18.74,
#     'receiverY': 56.45},
#    {'type': 22,
#     'thrower': 'jmoore1',
#     'throwerX': -18.74,
#     'throwerY': 56.45,
#     'turnoverX': -10.42,
#     'turnoverY': 106.64},
#    {'type': 15},
#    {'type': 2,
#     'line': ['efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney',
#      'qbuermeye'],
#     'time': 256},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -0.04,
#     'throwerY': 14.32,
#     'receiver': 'isweeney',
#     'receiverX': -6.1,
#     'receiverY': 19.35},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -6.1,
#     'throwerY': 19.35,
#     'receiver': 'efriedman',
#     'receiverX': -16.48,
#     'receiverY': 32.45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -16.48,
#     'throwerY': 32.45,
#     'receiver': 'qbuermeye',
#     'receiverX': -22.74,
#     'receiverY': 41.93},
#    {'type': 18,
#     'thrower': 'qbuermeye',
#     'throwerX': -22.74,
#     'throwerY': 41.93,
#     'receiver': 'sfraner',
#     'receiverX': -16.93,
#     'receiverY': 51.09},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -16.93,
#     'throwerY': 51.09,
#     'receiver': 'rhayes',
#     'receiverX': -23.19,
#     'receiverY': 60.77},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -23.19,
#     'throwerY': 60.77,
#     'receiver': 'efriedman',
#     'receiverX': -13.45,
#     'receiverY': 66.38},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -13.45,
#     'throwerY': 66.38,
#     'receiver': 'rhayes',
#     'receiverX': -25.58,
#     'receiverY': 72.58},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -25.58,
#     'throwerY': 72.58,
#     'receiver': 'efriedman',
#     'receiverX': -5.71,
#     'receiverY': 63.87},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -5.71,
#     'throwerY': 63.87,
#     'receiver': 'sfraner',
#     'receiverX': -17.84,
#     'receiverY': 80.06},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -17.84,
#     'throwerY': 80.06,
#     'receiver': 'jsnyder',
#     'receiverX': 0.93,
#     'receiverY': 70.9},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 0.93,
#     'throwerY': 70.9,
#     'receiver': 'rhayes',
#     'receiverX': 15.5,
#     'receiverY': 90.7},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 15.5,
#     'throwerY': 90.7,
#     'receiver': 'qbuermeye',
#     'receiverX': 14.28,
#     'receiverY': 104.58},
#    {'type': 1,
#     'line': ['jmoore1',
#      'apetersch',
#      'arueda',
#      'gnakano',
#      'bstout',
#      'slatarski',
#      'jlee'],
#     'time': 316},
#    {'type': 7,
#     'puller': 'bstout',
#     'pullX': 25.57,
#     'pullY': 105.54,
#     'pullMs': 6164},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 15.57,
#     'throwerY': 20,
#     'receiver': 'apetersch',
#     'receiverX': 18.41,
#     'receiverY': 32.06},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 18.41,
#     'throwerY': 32.06,
#     'receiver': 'gnakano',
#     'receiverX': 20.02,
#     'receiverY': 56.12},
#    {'type': 18,
#     'thrower': 'gnakano',
#     'throwerX': 20.02,
#     'throwerY': 56.12,
#     'receiver': 'slatarski',
#     'receiverX': 9.12,
#     'receiverY': 59.74},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 9.12,
#     'throwerY': 59.74,
#     'receiver': 'apetersch',
#     'receiverX': -10.1,
#     'receiverY': 57.93},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -10.1,
#     'throwerY': 57.93,
#     'receiver': 'jlee',
#     'receiverX': -8.81,
#     'receiverY': 72.64},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -8.81,
#     'throwerY': 72.64,
#     'receiver': 'apetersch',
#     'receiverX': -1.39,
#     'receiverY': 74.64},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -1.39,
#     'throwerY': 74.64,
#     'receiver': 'bstout',
#     'receiverX': 4.54,
#     'receiverY': 79.8},
#    {'type': 18,
#     'thrower': 'bstout',
#     'throwerX': 4.54,
#     'throwerY': 79.8,
#     'receiver': 'slatarski',
#     'receiverX': 0.09,
#     'receiverY': 70.7},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 0.09,
#     'throwerY': 70.7,
#     'receiver': 'jlee',
#     'receiverX': -16.35,
#     'receiverY': 71.67},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -16.35,
#     'throwerY': 71.67,
#     'receiver': 'apetersch',
#     'receiverX': -2.04,
#     'receiverY': 61.87},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -2.04,
#     'throwerY': 61.87,
#     'receiver': 'slatarski',
#     'receiverX': -18.16,
#     'receiverY': 78.9},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': -18.16,
#     'throwerY': 78.9,
#     'receiver': 'jlee',
#     'receiverX': -4.36,
#     'receiverY': 73.74},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -4.36,
#     'throwerY': 73.74,
#     'receiver': 'jmoore1',
#     'receiverX': 14.28,
#     'receiverY': 79.8},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': 14.28,
#     'throwerY': 79.8,
#     'receiver': 'jlee',
#     'receiverX': -1.59,
#     'receiverY': 74.96},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': -1.59,
#     'throwerY': 74.96,
#     'receiver': 'jmoore1',
#     'receiverX': 8.22,
#     'receiverY': 75.09},
#    {'type': 3,
#     'line': ['bstout',
#      'rhayes',
#      'qbuermeye',
#      'apetersch',
#      'jlee',
#      'isweeney',
#      'jmoore1'],
#     'time': 403},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 15.7,
#     'throwerY': 84.25,
#     'receiver': 'rhayes',
#     'receiverX': 1.9,
#     'receiverY': 94.38},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 1.9,
#     'throwerY': 94.38,
#     'receiver': 'isweeney',
#     'receiverX': 24.15,
#     'receiverY': 104.38},
#    {'type': 1,
#     'line': ['cstillwel',
#      'ceustis',
#      'llavoie',
#      'sradlauer',
#      'slatarski',
#      'gnakano',
#      'jlee'],
#     'time': 411},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 1.7,
#     'pullY': 118.58,
#     'pullMs': 7161},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney'],
#     'time': 453},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 25.69,
#     'throwerY': 42.77,
#     'receiver': 'sfraner',
#     'receiverX': 11.57,
#     'receiverY': 47.09},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 11.57,
#     'throwerY': 47.09,
#     'receiver': 'isweeney',
#     'receiverX': 6.22,
#     'receiverY': 39.8},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 6.22,
#     'throwerY': 39.8,
#     'receiver': 'efriedman',
#     'receiverX': -1.46,
#     'receiverY': 95.03},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -1.46,
#     'throwerY': 95.03,
#     'receiver': 'sfraner',
#     'receiverX': -1.39,
#     'receiverY': 89.74},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -1.39,
#     'throwerY': 89.74,
#     'receiver': 'jsnyder',
#     'receiverX': -4.75,
#     'receiverY': 72.32},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -4.75,
#     'throwerY': 72.32,
#     'receiver': 'sfraner',
#     'receiverX': -2.23,
#     'receiverY': 81.48},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -2.23,
#     'throwerY': 81.48,
#     'receiver': 'rhayes',
#     'receiverX': 11.44,
#     'receiverY': 95.93},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 11.44,
#     'throwerY': 95.93,
#     'receiver': 'jsnyder',
#     'receiverX': 11.76,
#     'receiverY': 85.29},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 11.76,
#     'throwerY': 85.29,
#     'receiver': 'rhayes',
#     'receiverX': 15.31,
#     'receiverY': 94.77},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 15.31,
#     'throwerY': 94.77,
#     'receiver': 'efriedman',
#     'receiverX': 20.28,
#     'receiverY': 116},
#    {'type': 1,
#     'line': ['bstout',
#      'sradlauer',
#      'arueda',
#      'apetersch',
#      'qbuermeye',
#      'ceustis',
#      'llavoie'],
#     'time': 521},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -3.33,
#     'pullY': 116.19,
#     'pullMs': 6895},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney',
#      'cstillwel'],
#     'time': 568},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 13.31,
#     'throwerY': 25.61,
#     'receiver': 'rhayes',
#     'receiverX': 19.25,
#     'receiverY': 36.51},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 19.25,
#     'throwerY': 36.51,
#     'receiver': 'sfraner',
#     'receiverX': 26.21,
#     'receiverY': 50.77},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 26.21,
#     'throwerY': 50.77,
#     'receiver': 'cstillwel',
#     'receiverX': 24.79,
#     'receiverY': 66.7},
#    {'type': 18,
#     'thrower': 'cstillwel',
#     'throwerX': 24.79,
#     'throwerY': 66.7,
#     'receiver': 'isweeney',
#     'receiverX': 13.05,
#     'receiverY': 70.32},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 13.05,
#     'throwerY': 70.32,
#     'receiver': 'rhayes',
#     'receiverX': -13.58,
#     'receiverY': 69.67},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -13.58,
#     'throwerY': 69.67,
#     'receiver': 'sfraner',
#     'receiverX': 1.7,
#     'receiverY': 68.96},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 1.7,
#     'throwerY': 68.96,
#     'receiver': 'jjohnson1',
#     'receiverX': 24.66,
#     'receiverY': 85.67},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 24.66,
#     'throwerY': 85.67,
#     'receiver': 'sfraner',
#     'receiverX': 2.61,
#     'receiverY': 72.45},
#    {'type': 22,
#     'thrower': 'sfraner',
#     'throwerX': 2.61,
#     'throwerY': 72.45,
#     'turnoverX': 25.89,
#     'turnoverY': 89.8},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'tdoi',
#      'jmoore1',
#      'qbuermeye'],
#     'time': 625},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -8.81,
#     'throwerY': 21.87,
#     'receiver': 'efriedman',
#     'receiverX': 4.35,
#     'receiverY': 23.41},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 4.35,
#     'throwerY': 23.41,
#     'receiver': 'jsnyder',
#     'receiverX': -7.71,
#     'receiverY': 27.87},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -7.71,
#     'throwerY': 27.87,
#     'receiver': 'efriedman',
#     'receiverX': 0.93,
#     'receiverY': 19.48},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0.93,
#     'throwerY': 19.48,
#     'receiver': 'rhayes',
#     'receiverX': -1.71,
#     'receiverY': 92.45},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': -1.71,
#     'throwerY': 92.45,
#     'receiver': 'jmoore1',
#     'receiverX': -9.58,
#     'receiverY': 105.29},
#    {'type': 1,
#     'line': ['jlee',
#      'gnakano',
#      'sradlauer',
#      'slatarski',
#      'apetersch',
#      'isweeney',
#      'jmoore1'],
#     'time': 652},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': -25.77,
#     'pullY': 72.32,
#     'pullMs': 4212},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'bstout',
#      'cstillwel'],
#     'time': 697},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 18.92,
#     'throwerY': 26.25,
#     'receiver': 'efriedman',
#     'receiverX': 0.8,
#     'receiverY': 22.58},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0.8,
#     'throwerY': 22.58,
#     'receiver': 'isweeney',
#     'receiverX': -16.55,
#     'receiverY': 29.67},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -16.55,
#     'throwerY': 29.67,
#     'receiver': 'cstillwel',
#     'receiverX': -22.74,
#     'receiverY': 59.29},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'cstillwel',
#     'throwerX': -22.74,
#     'throwerY': 69.28999999999999,
#     'receiver': 'rhayes',
#     'receiverX': -20.67,
#     'receiverY': 82.06},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': -20.67,
#     'throwerY': 82.06,
#     'receiver': 'bstout',
#     'receiverX': 4.22,
#     'receiverY': 108.25},
#    {'type': 28},
#    {'type': 1,
#     'line': ['sradlauer',
#      'slatarski',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'bstout'],
#     'time': 0},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': -26.03,
#     'pullY': 70.19,
#     'pullMs': 19341},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -9.19,
#     'throwerY': 14.9,
#     'receiver': 'sfraner',
#     'receiverX': -22.74,
#     'receiverY': 41.35},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -22.74,
#     'throwerY': 41.35,
#     'receiver': 'rhayes',
#     'receiverX': 17.96,
#     'receiverY': 82.12},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 17.96,
#     'throwerY': 82.12,
#     'receiver': 'tdoi',
#     'receiverX': 12.93,
#     'receiverY': 119.22},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'ceustis',
#      'llavoie',
#      'arueda'],
#     'time': 67},
#    {'type': 7, 'puller': 'llavoie', 'pullX': 0, 'pullY': 80, 'pullMs': 5412},
#    {'type': 13},
#    {'type': 17},
#    {'type': 22,
#     'thrower': 'apetersch',
#     'throwerX': 0.16,
#     'throwerY': 96.25,
#     'turnoverX': 4.54,
#     'turnoverY': 82.77},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'qbuermeye'],
#     'time': 186},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -0.3,
#     'throwerY': 9.48,
#     'receiver': 'efriedman',
#     'receiverX': 1.38,
#     'receiverY': 17.48},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 1.38,
#     'throwerY': 17.48,
#     'receiver': 'jsnyder',
#     'receiverX': -5.84,
#     'receiverY': 20},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -5.84,
#     'throwerY': 20,
#     'receiver': 'efriedman',
#     'receiverX': 2.67,
#     'receiverY': 20},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 2.67,
#     'throwerY': 20,
#     'receiver': 'qbuermeye',
#     'receiverX': 18.34,
#     'receiverY': 20},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'qbuermeye',
#     'throwerX': 18.34,
#     'throwerY': 30,
#     'receiver': 'jjohnson1',
#     'receiverX': -4.75,
#     'receiverY': 30.51},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -4.75,
#     'throwerY': 30.51,
#     'receiver': 'rhayes',
#     'receiverX': 7.96,
#     'receiverY': 40.7},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 7.96,
#     'throwerY': 40.7,
#     'receiver': 'jjohnson1',
#     'receiverX': -10.48,
#     'receiverY': 42},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -10.48,
#     'throwerY': 42,
#     'receiver': 'sfraner',
#     'receiverX': 1.7,
#     'receiverY': 45.54},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 1.7,
#     'throwerY': 45.54,
#     'receiver': 'rhayes',
#     'receiverX': 19.76,
#     'receiverY': 48.32},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 19.76,
#     'throwerY': 48.32,
#     'receiver': 'jsnyder',
#     'receiverX': 23.05,
#     'receiverY': 63.16},
#    {'type': 16},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 23.05,
#     'throwerY': 53.16,
#     'receiver': 'sfraner',
#     'receiverX': 7.83,
#     'receiverY': 39.35},
#    {'type': 22,
#     'thrower': 'sfraner',
#     'throwerX': 7.83,
#     'throwerY': 39.35,
#     'turnoverX': -3.26,
#     'turnoverY': 69.16},
#    {'type': 15},
#    {'type': 2,
#     'line': ['efriedman',
#      'rhayes',
#      'sfraner',
#      'qbuermeye',
#      'tdoi',
#      'cstillwel',
#      'isweeney'],
#     'time': 285},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -0.17,
#     'throwerY': 65.48,
#     'receiver': 'rhayes',
#     'receiverX': -18.67,
#     'receiverY': 79.41},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -18.67,
#     'throwerY': 79.41,
#     'receiver': 'isweeney',
#     'receiverX': -3,
#     'receiverY': 71.29},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -3,
#     'throwerY': 71.29,
#     'receiver': 'sfraner',
#     'receiverX': -18.42,
#     'receiverY': 75.16},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -18.42,
#     'throwerY': 75.16,
#     'receiver': 'isweeney',
#     'receiverX': -9.65,
#     'receiverY': 70.64},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -9.65,
#     'throwerY': 70.64,
#     'receiver': 'rhayes',
#     'receiverX': -16.61,
#     'receiverY': 79.74},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -16.61,
#     'throwerY': 79.74,
#     'receiver': 'efriedman',
#     'receiverX': 3.83,
#     'receiverY': 88.51},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': 3.83,
#     'throwerY': 88.51,
#     'receiver': 'tdoi',
#     'receiverX': 17.31,
#     'receiverY': 104.06},
#    {'type': 1,
#     'line': ['sradlauer',
#      'slatarski',
#      'jmoore1',
#      'apetersch',
#      'bstout',
#      'llavoie',
#      'arueda'],
#     'time': 347},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -26.41,
#     'pullY': 71.8,
#     'pullMs': 17575},
#    {'type': 11, 'defender': 'sradlauer'},
#    {'type': 18,
#     'thrower': 'slatarski',
#     'throwerX': 15.38,
#     'throwerY': 69.16,
#     'receiver': 'apetersch',
#     'receiverX': 7.7,
#     'receiverY': 65.54},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 7.7,
#     'throwerY': 65.54,
#     'receiver': 'sradlauer',
#     'receiverX': 15.25,
#     'receiverY': 75.67},
#    {'type': 22,
#     'thrower': 'sradlauer',
#     'throwerX': 15.25,
#     'throwerY': 75.67,
#     'turnoverX': -17.58,
#     'turnoverY': 89.67},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'qbuermeye',
#      'isweeney'],
#     'time': 402},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'rhayes',
#     'receiverX': -21.51,
#     'receiverY': 52.7},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -21.51,
#     'throwerY': 52.7,
#     'receiver': 'efriedman',
#     'receiverX': -11.13,
#     'receiverY': 45.22},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -11.13,
#     'throwerY': 45.22,
#     'receiver': 'jjohnson1',
#     'receiverX': 3.19,
#     'receiverY': 47.67},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 3.19,
#     'throwerY': 47.67,
#     'receiver': 'rhayes',
#     'receiverX': 11.44,
#     'receiverY': 54.25},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 11.44,
#     'throwerY': 54.25,
#     'receiver': 'jsnyder',
#     'receiverX': 0.16,
#     'receiverY': 45.67},
#    {'type': 22,
#     'thrower': 'jsnyder',
#     'throwerX': 0.16,
#     'throwerY': 45.67,
#     'turnoverX': -7.39,
#     'turnoverY': 109.61},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -0.23,
#     'throwerY': 29.8,
#     'receiver': 'isweeney',
#     'receiverX': -18.16,
#     'receiverY': 38.38},
#    {'type': 20,
#     'thrower': 'isweeney',
#     'throwerX': -18.16,
#     'throwerY': 38.38,
#     'receiver': 'efriedman',
#     'receiverX': 3.06,
#     'receiverY': 42.64},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'cstillwel',
#      'llavoie',
#      'isweeney'],
#     'time': 550},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 16.6,
#     'throwerY': 66.64,
#     'receiver': 'tdoi',
#     'receiverX': 17.25,
#     'receiverY': 90},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 17.25,
#     'throwerY': 90,
#     'receiver': 'sfraner',
#     'receiverX': 19.18,
#     'receiverY': 79.16},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 19.18,
#     'throwerY': 79.16,
#     'receiver': 'llavoie',
#     'receiverX': -4.1,
#     'receiverY': 83.48},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -4.1,
#     'throwerY': 83.48,
#     'receiver': 'sfraner',
#     'receiverX': 12.02,
#     'receiverY': 81.41},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 12.02,
#     'throwerY': 81.41,
#     'receiver': 'isweeney',
#     'receiverX': -5,
#     'receiverY': 82},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -5,
#     'throwerY': 82,
#     'turnoverX': -21.45,
#     'turnoverY': 96.7},
#    {'type': 5,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'bstout',
#      'apetersch',
#      'qbuermeye'],
#     'time': 610},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'tdoi',
#      'isweeney'],
#     'time': 642},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 10.99,
#     'throwerY': 4.19,
#     'receiver': 'jjohnson1',
#     'receiverX': -16.35,
#     'receiverY': 14.38},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -16.35,
#     'throwerY': 14.38,
#     'receiver': 'rhayes',
#     'receiverX': -19,
#     'receiverY': 27.67},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -19,
#     'throwerY': 27.67,
#     'receiver': 'efriedman',
#     'receiverX': -18.42,
#     'receiverY': 21.41},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -18.42,
#     'throwerY': 21.41,
#     'receiver': 'jjohnson1',
#     'receiverX': 10.22,
#     'receiverY': 16.64},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 10.22,
#     'throwerY': 16.64,
#     'receiver': 'jsnyder',
#     'receiverX': 19.25,
#     'receiverY': 18.51},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 19.25,
#     'throwerY': 18.51,
#     'receiver': 'sfraner',
#     'receiverX': -18.93,
#     'receiverY': 16.06},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -18.93,
#     'throwerY': 16.06,
#     'receiver': 'jjohnson1',
#     'receiverX': 2.99,
#     'receiverY': 14.51},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 2.99,
#     'throwerY': 14.51,
#     'receiver': 'isweeney',
#     'receiverX': 0.99,
#     'receiverY': 6},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 0.99,
#     'throwerY': 6,
#     'receiver': 'rhayes',
#     'receiverX': 13.44,
#     'receiverY': 13.48},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 13.44,
#     'throwerY': 13.48,
#     'receiver': 'tdoi',
#     'receiverX': 0.09,
#     'receiverY': 32.25},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 0.09,
#     'throwerY': 32.25,
#     'receiver': 'efriedman',
#     'receiverX': -17.77,
#     'receiverY': 45.41},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': -17.77,
#     'throwerY': 45.41,
#     'receiver': 'sfraner',
#     'receiverX': -11.97,
#     'receiverY': 113.16},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'rhayes',
#      'bstout',
#      'apetersch',
#      'ceustis',
#      'llavoie'],
#     'time': 697},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -6.1,
#     'pullY': 115.61,
#     'pullMs': 6812},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'bstout',
#      'cstillwel'],
#     'time': 717},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -9.97,
#     'throwerY': 12.7,
#     'turnoverX': 2.8,
#     'turnoverY': 94.7},
#    {'type': 29},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 0},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 11.44,
#     'throwerY': 3.54,
#     'receiver': 'efriedman',
#     'receiverX': -5.33,
#     'receiverY': 12.45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -5.33,
#     'throwerY': 12.45,
#     'receiver': 'jsnyder',
#     'receiverX': 15.25,
#     'receiverY': 18},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 15.25,
#     'throwerY': 18,
#     'receiver': 'rhayes',
#     'receiverX': -0.88,
#     'receiverY': 29.74},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -0.88,
#     'throwerY': 29.74,
#     'receiver': 'tdoi',
#     'receiverX': -9.52,
#     'receiverY': 73.03},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': -9.52,
#     'throwerY': 73.03,
#     'receiver': 'efriedman',
#     'receiverX': -19.06,
#     'receiverY': 71.61},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': -19.06,
#     'throwerY': 71.61,
#     'receiver': 'rhayes',
#     'receiverX': -18.67,
#     'receiverY': 111.87},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'apetersch',
#      'bstout',
#      'llavoie',
#      'ceustis'],
#     'time': 33},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 22.53,
#     'pullY': 109.8,
#     'pullMs': 6744},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'rhayes',
#      'sfraner',
#      'qbuermeye',
#      'tdoi',
#      'isweeney'],
#     'time': 59},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'rhayes',
#     'receiverX': -20.16,
#     'receiverY': 61.41},
#    {'type': 22,
#     'thrower': 'rhayes',
#     'throwerX': -20.16,
#     'throwerY': 61.41,
#     'turnoverX': -2.75,
#     'turnoverY': 113.29},
#    {'type': 17},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'sfraner',
#      'cstillwel',
#      'llavoie',
#      'tdoi'],
#     'time': 166},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -0.36,
#     'throwerY': 62.64,
#     'receiver': 'jsnyder',
#     'receiverX': -14.16,
#     'receiverY': 60.77},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -14.16,
#     'throwerY': 70.77000000000001,
#     'receiver': 'llavoie',
#     'receiverX': -2.36,
#     'receiverY': 100},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': 0,
#     'throwerY': 100,
#     'receiver': 'jsnyder',
#     'receiverX': -4.68,
#     'receiverY': 88.64},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -4.68,
#     'throwerY': 88.64,
#     'receiver': 'llavoie',
#     'receiverX': 17.63,
#     'receiverY': 84.9},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': 17.63,
#     'throwerY': 84.9,
#     'receiver': 'tdoi',
#     'receiverX': 0.35,
#     'receiverY': 89.8},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 0.35,
#     'throwerY': 89.8,
#     'receiver': 'sfraner',
#     'receiverX': 6.15,
#     'receiverY': 84.77},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 6.15,
#     'throwerY': 84.77,
#     'receiver': 'tdoi',
#     'receiverX': 21.76,
#     'receiverY': 89.09},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 21.76,
#     'throwerY': 89.09,
#     'receiver': 'sfraner',
#     'receiverX': 21.82,
#     'receiverY': 84.7},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 21.82,
#     'throwerY': 84.7,
#     'receiver': 'llavoie',
#     'receiverX': 0.54,
#     'receiverY': 90.32},
#    {'type': 19,
#     'thrower': 'llavoie',
#     'throwerX': 0.54,
#     'throwerY': 90.32,
#     'receiver': 'efriedman',
#     'receiverX': 25.24,
#     'receiverY': 113.93},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'arueda',
#      'bstout'],
#     'time': 259},
#    {'type': 7,
#     'puller': 'sradlauer',
#     'pullX': -25.19,
#     'pullY': 80.58,
#     'pullMs': 11693},
#    {'type': 25,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'arueda',
#      'bstout'],
#     'time': 291},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'qbuermeye',
#      'tdoi',
#      'isweeney'],
#     'time': 295},
#    {'type': 22,
#     'thrower': 'efriedman',
#     'throwerX': 0.8,
#     'throwerY': 1.22,
#     'turnoverX': -26.03,
#     'turnoverY': 31.48},
#    {'type': 13},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -17.9,
#     'throwerY': 19.8,
#     'receiver': 'efriedman',
#     'receiverX': -21.32,
#     'receiverY': 37.87},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -21.32,
#     'throwerY': 37.87,
#     'receiver': 'rhayes',
#     'receiverX': -10.81,
#     'receiverY': 50.51},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -10.81,
#     'throwerY': 50.51,
#     'receiver': 'efriedman',
#     'receiverX': -19.32,
#     'receiverY': 48.45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -19.32,
#     'throwerY': 48.45,
#     'receiver': 'tdoi',
#     'receiverX': 9.12,
#     'receiverY': 92.7},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 9.12,
#     'throwerY': 92.7,
#     'receiver': 'jsnyder',
#     'receiverX': 1.83,
#     'receiverY': 80.83},
#    {'type': 19,
#     'thrower': 'jsnyder',
#     'throwerX': 1.83,
#     'throwerY': 80.83,
#     'receiver': 'tdoi',
#     'receiverX': -24.41,
#     'receiverY': 105.61},
#    {'type': 1,
#     'line': ['sradlauer',
#      'slatarski',
#      'jmoore1',
#      'gnakano',
#      'apetersch',
#      'llavoie',
#      'arueda'],
#     'time': 353},
#    {'type': 7,
#     'puller': 'slatarski',
#     'pullX': 6.73,
#     'pullY': 92.77,
#     'pullMs': 7543},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'cstillwel'],
#     'time': 394},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -9.39,
#     'throwerY': 7.61,
#     'receiver': 'jsnyder',
#     'receiverX': 0.54,
#     'receiverY': 14.38},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 0.54,
#     'throwerY': 14.38,
#     'receiver': 'rhayes',
#     'receiverX': 10.15,
#     'receiverY': 22.06},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 10.15,
#     'throwerY': 22.06,
#     'receiver': 'sfraner',
#     'receiverX': 3.83,
#     'receiverY': 30.96},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 3.83,
#     'throwerY': 30.96,
#     'receiver': 'jjohnson1',
#     'receiverX': -17.71,
#     'receiverY': 32.51},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -17.71,
#     'throwerY': 32.51,
#     'receiver': 'jsnyder',
#     'receiverX': -19.06,
#     'receiverY': 52.32},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -19.06,
#     'throwerY': 52.32,
#     'receiver': 'isweeney',
#     'receiverX': -11.19,
#     'receiverY': 63.03},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -11.19,
#     'throwerY': 63.03,
#     'turnoverX': -18.35,
#     'turnoverY': 110.9},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'rhayes',
#      'qbuermeye',
#      'llavoie',
#      'tdoi',
#      'isweeney'],
#     'time': 471},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -22.67,
#     'throwerY': 10.12,
#     'receiver': 'efriedman',
#     'receiverX': -13.39,
#     'receiverY': 24.38},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -13.39,
#     'throwerY': 24.38,
#     'receiver': 'qbuermeye',
#     'receiverX': -9.9,
#     'receiverY': 91.48},
#    {'type': 22,
#     'thrower': 'qbuermeye',
#     'throwerX': -9.9,
#     'throwerY': 91.48,
#     'turnoverX': -4.29,
#     'turnoverY': 85.61},
#    {'type': 11, 'defender': 'rhayes'},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': -24.67,
#     'throwerY': 63.09,
#     'receiver': 'jjohnson1',
#     'receiverX': -23.51,
#     'receiverY': 45.48},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': -23.51,
#     'throwerY': 45.48,
#     'receiver': 'isweeney',
#     'receiverX': -9.58,
#     'receiverY': 49.22},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -9.58,
#     'throwerY': 49.22,
#     'receiver': 'tdoi',
#     'receiverX': 8.86,
#     'receiverY': 56.45},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 8.86,
#     'throwerY': 56.45,
#     'receiver': 'isweeney',
#     'receiverX': -7,
#     'receiverY': 54.7},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -7,
#     'throwerY': 54.7,
#     'receiver': 'rhayes',
#     'receiverX': 14.86,
#     'receiverY': 60.77},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 14.86,
#     'throwerY': 60.77,
#     'receiver': 'qbuermeye',
#     'receiverX': 24.47,
#     'receiverY': 76.06},
#    {'type': 18,
#     'thrower': 'qbuermeye',
#     'throwerX': 24.47,
#     'throwerY': 76.06,
#     'receiver': 'rhayes',
#     'receiverX': 4.74,
#     'receiverY': 74.51},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 4.74,
#     'throwerY': 74.51,
#     'receiver': 'qbuermeye',
#     'receiverX': 25.18,
#     'receiverY': 111.61},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'bstout',
#      'ceustis'],
#     'time': 545},
#    {'type': 8, 'puller': 'jmoore1'},
#    {'type': 11, 'defender': 'gnakano'},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -4.55,
#     'throwerY': 69.74,
#     'receiver': 'jlee',
#     'receiverX': 13.51,
#     'receiverY': 77.09},
#    {'type': 18,
#     'thrower': 'jlee',
#     'throwerX': 13.51,
#     'throwerY': 77.09,
#     'receiver': 'bstout',
#     'receiverX': 24.53,
#     'receiverY': 87.16},
#    {'type': 18,
#     'thrower': 'bstout',
#     'throwerX': 24.53,
#     'throwerY': 87.16,
#     'receiver': 'jmoore1',
#     'receiverX': -6.55,
#     'receiverY': 80.32},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': -6.55,
#     'throwerY': 80.32,
#     'receiver': 'apetersch',
#     'receiverX': -25.7,
#     'receiverY': 91.67},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': -25.7,
#     'throwerY': 91.67,
#     'receiver': 'ceustis',
#     'receiverX': -11.26,
#     'receiverY': 97.41},
#    {'type': 19,
#     'thrower': 'ceustis',
#     'throwerX': -11.26,
#     'throwerY': 97.41,
#     'receiver': 'sradlauer',
#     'receiverX': -3.71,
#     'receiverY': 104.77},
#    {'type': 1,
#     'line': ['slatarski',
#      'jmoore1',
#      'gnakano',
#      'apetersch',
#      'ceustis',
#      'arueda',
#      'llavoie'],
#     'time': 618},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 0.87,
#     'pullY': 116.7,
#     'pullMs': 0},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 651},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -20.29,
#     'throwerY': 22.96,
#     'receiver': 'sfraner',
#     'receiverX': -12.23,
#     'receiverY': 29.41},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': -12.23,
#     'throwerY': 29.41,
#     'receiver': 'jjohnson1',
#     'receiverX': 5.9,
#     'receiverY': 27.41},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 5.9,
#     'throwerY': 27.41,
#     'receiver': 'tdoi',
#     'receiverX': 11.89,
#     'receiverY': 40.19},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 11.89,
#     'throwerY': 40.19,
#     'receiver': 'rhayes',
#     'receiverX': 6.15,
#     'receiverY': 52.7},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 6.15,
#     'throwerY': 52.7,
#     'receiver': 'sfraner',
#     'receiverX': 14.54,
#     'receiverY': 63.67},
#    {'type': 18,
#     'thrower': 'sfraner',
#     'throwerX': 14.54,
#     'throwerY': 63.67,
#     'receiver': 'jjohnson1',
#     'receiverX': 19.89,
#     'receiverY': 98.96},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 19.89,
#     'throwerY': 98.96,
#     'receiver': 'efriedman',
#     'receiverX': 15.5,
#     'receiverY': 98.32},
#    {'type': 3,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'qbuermeye'],
#     'time': 698},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 15.5,
#     'throwerY': 98.32,
#     'receiver': 'rhayes',
#     'receiverX': 16.79,
#     'receiverY': 89.8},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 16.79,
#     'throwerY': 89.8,
#     'receiver': 'isweeney',
#     'receiverX': 24.66,
#     'receiverY': 92.77},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 24.66,
#     'throwerY': 92.77,
#     'receiver': 'rhayes',
#     'receiverX': 6.41,
#     'receiverY': 85.22},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 6.41,
#     'throwerY': 85.22,
#     'receiver': 'jjohnson1',
#     'receiverX': 23.18,
#     'receiverY': 110.25},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'rhayes',
#      'bstout',
#      'apetersch',
#      'cstillwel',
#      'llavoie'],
#     'time': 712},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -0.88,
#     'pullY': 116.12,
#     'pullMs': 7877},
#    {'type': 30},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jlee',
#      'gnakano',
#      'apetersch',
#      'llavoie',
#      'arueda',
#      'ceustis'],
#     'time': 0},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -26.22,
#     'pullY': 67.8,
#     'pullMs': 16025},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'qbuermeye'],
#     'time': 45},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 12.02,
#     'throwerY': 20,
#     'receiver': 'jsnyder',
#     'receiverX': -2.87,
#     'receiverY': 23.16},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': -2.87,
#     'throwerY': 23.16,
#     'receiver': 'isweeney',
#     'receiverX': -17.77,
#     'receiverY': 30.38},
#    {'type': 22,
#     'thrower': 'isweeney',
#     'throwerX': -17.77,
#     'throwerY': 30.38,
#     'turnoverX': -17,
#     'turnoverY': 100.58},
#    {'type': 11, 'defender': 'efriedman'},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': 14.99,
#     'throwerY': 74.77,
#     'receiver': 'jsnyder',
#     'receiverX': 4.28,
#     'receiverY': 84.64},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 4.28,
#     'throwerY': 84.64,
#     'receiver': 'efriedman',
#     'receiverX': -5.45,
#     'receiverY': 76.51},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -5.45,
#     'throwerY': 76.51,
#     'receiver': 'jsnyder',
#     'receiverX': 12.28,
#     'receiverY': 69.61},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 12.28,
#     'throwerY': 69.61,
#     'receiver': 'sfraner',
#     'receiverX': 13.96,
#     'receiverY': 85.67},
#    {'type': 25,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'qbuermeye',
#      'tdoi'],
#     'time': 121},
#    {'type': 19,
#     'thrower': 'efriedman',
#     'throwerX': 0.41,
#     'throwerY': 98.32,
#     'receiver': 'tdoi',
#     'receiverX': -4.04,
#     'receiverY': 102},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'gnakano',
#      'apetersch',
#      'llavoie',
#      'bstout',
#      'arueda'],
#     'time': 126},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': -23.51,
#     'pullY': 78.58,
#     'pullMs': 18591},
#    {'type': 11, 'defender': 'sradlauer'},
#    {'type': 18,
#     'thrower': 'gnakano',
#     'throwerX': 11.44,
#     'throwerY': 83.74,
#     'receiver': 'arueda',
#     'receiverX': 12.22,
#     'receiverY': 76.83},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': 12.22,
#     'throwerY': 76.83,
#     'receiver': 'llavoie',
#     'receiverX': -3.52,
#     'receiverY': 74.51},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -3.52,
#     'throwerY': 74.51,
#     'receiver': 'arueda',
#     'receiverX': 12.73,
#     'receiverY': 68.9},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': 12.73,
#     'throwerY': 68.9,
#     'receiver': 'apetersch',
#     'receiverX': 24.15,
#     'receiverY': 78.7},
#    {'type': 18,
#     'thrower': 'apetersch',
#     'throwerX': 24.15,
#     'throwerY': 78.7,
#     'receiver': 'sradlauer',
#     'receiverX': 9.25,
#     'receiverY': 93.41},
#    {'type': 17},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'sradlauer',
#     'throwerX': 0,
#     'throwerY': 100,
#     'receiver': 'arueda',
#     'receiverX': -1.2,
#     'receiverY': 90.9},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': -1.2,
#     'throwerY': 90.9,
#     'receiver': 'sradlauer',
#     'receiverX': -8.03,
#     'receiverY': 97.03},
#    {'type': 18,
#     'thrower': 'sradlauer',
#     'throwerX': -8.03,
#     'throwerY': 97.03,
#     'receiver': 'arueda',
#     'receiverX': 2.8,
#     'receiverY': 90.77},
#    {'type': 18,
#     'thrower': 'arueda',
#     'throwerX': 2.8,
#     'throwerY': 90.77,
#     'receiver': 'jmoore1',
#     'receiverX': -9.39,
#     'receiverY': 90.06},
#    {'type': 18,
#     'thrower': 'jmoore1',
#     'throwerX': -9.39,
#     'throwerY': 90.06,
#     'receiver': 'arueda',
#     'receiverX': -11,
#     'receiverY': 97.54},
#    {'type': 19,
#     'thrower': 'arueda',
#     'throwerX': -11,
#     'throwerY': 97.54,
#     'receiver': 'gnakano',
#     'receiverX': -12.1,
#     'receiverY': 103.87},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'ceustis',
#      'llavoie',
#      'jlee',
#      'apetersch',
#      'qbuermeye'],
#     'time': 170},
#    {'type': 7,
#     'puller': 'jmoore1',
#     'pullX': -25.32,
#     'pullY': 75.93,
#     'pullMs': 11413},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'sfraner',
#      'isweeney',
#      'tdoi'],
#     'time': 221},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 3.64,
#     'throwerY': 13.67,
#     'receiver': 'isweeney',
#     'receiverX': 1.12,
#     'receiverY': 25.54},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 1.12,
#     'throwerY': 25.54,
#     'receiver': 'jjohnson1',
#     'receiverX': 20.54,
#     'receiverY': 28.12},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 20.54,
#     'throwerY': 28.12,
#     'receiver': 'rhayes',
#     'receiverX': 4.28,
#     'receiverY': 36.12},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 4.28,
#     'throwerY': 36.12,
#     'receiver': 'isweeney',
#     'receiverX': 8.09,
#     'receiverY': 28.96},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 8.09,
#     'throwerY': 28.96,
#     'receiver': 'efriedman',
#     'receiverX': -19.06,
#     'receiverY': 39.74},
#    {'type': 17},
#    {'type': 16},
#    {'type': 18,
#     'thrower': 'efriedman',
#     'throwerX': -19.06,
#     'throwerY': 39.74,
#     'receiver': 'isweeney',
#     'receiverX': -24.22,
#     'receiverY': 60.32},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': -24.22,
#     'throwerY': 60.32,
#     'receiver': 'jjohnson1',
#     'receiverX': 17.25,
#     'receiverY': 62.25},
#    {'type': 18,
#     'thrower': 'jjohnson1',
#     'throwerX': 17.25,
#     'throwerY': 62.25,
#     'receiver': 'rhayes',
#     'receiverX': 7.12,
#     'receiverY': 79.48},
#    {'type': 18,
#     'thrower': 'rhayes',
#     'throwerX': 7.12,
#     'throwerY': 79.48,
#     'receiver': 'tdoi',
#     'receiverX': 18.15,
#     'receiverY': 92.19},
#    {'type': 18,
#     'thrower': 'tdoi',
#     'throwerX': 18.15,
#     'throwerY': 92.19,
#     'receiver': 'isweeney',
#     'receiverX': 0.8,
#     'receiverY': 82.19},
#    {'type': 18,
#     'thrower': 'isweeney',
#     'throwerX': 0.8,
#     'throwerY': 82.19,
#     'receiver': 'rhayes',
#     'receiverX': 17.96,
#     'receiverY': 91.67},
#    {'type': 19,
#     'thrower': 'rhayes',
#     'throwerX': 17.96,
#     'throwerY': 91.67,
#     'receiver': 'jjohnson1',
#     'receiverX': 24.79,
#     'receiverY': 114.19},
#    {'type': 1,
#     'line': ['sradlauer',
#      'jmoore1',
#      'jlee',
#      'apetersch',
#      'llavoie',
#      'arueda',
#      'ceustis'],
#     'time': 299},
#    {'type': 7,
#     'puller': 'llavoie',
#     'pullX': 10.15,
#     'pullY': 112.25,
#     'pullMs': 7662},
#    {'type': 16},
#    {'type': 11, 'defender': 'llavoie'},
#    {'type': 18,
#     'thrower': 'llavoie',
#     'throwerX': -8.1,
#     'throwerY': 43.03,
#     'receiver': 'jlee',
#     'receiverX': 11.31,
#     'receiverY': 50},
#    {'type': 22,
#     'thrower': 'jlee',
#     'throwerX': 11.31,
#     'throwerY': 50,
#     'turnoverX': 12.34,
#     'turnoverY': 82.06},
#    {'type': 15},
#    {'type': 2,
#     'line': ['jjohnson1',
#      'efriedman',
#      'jsnyder',
#      'rhayes',
#      'isweeney',
#      'cstillwel',
#      'tdoi'],
#     'time': 377},
#    {'type': 18,
#     'thrower': 'jsnyder',
#     'throwerX': 10.22,
#     'throwerY': 17.93,
#     'receiver': 'efriedman',
#     'receiverX': 0.03,
#     'receiverY': 32.64},
#    {'type': 18,
# ...
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': -9.83,
#     'throwerY': 21,
#     'receiver': 'mkissmann',
#     'receiverX': 7.29,
#     'receiverY': 21.47},
#    {'type': 18,
#     'thrower': 'mkissmann',
#     'throwerX': 7.29,
#     'throwerY': 21.47,
#     'receiver': 'wberreman',
#     'receiverX': 0.06,
#     'receiverY': 26.59},
#    {'type': 18,
#     'thrower': 'wberreman',
#     'throwerX': 0.06,
#     'throwerY': 26.59,
#     'receiver': 'gmay',
#     'receiverX': -18.28,
#     'receiverY': 31.22},
#    {'type': 18,
#     'thrower': 'gmay',
#     'throwerX': -18.28,
#     'throwerY': 31.22,
#     'receiver': 'mcrawford',
#     'receiverX': 3.81,
#     'receiverY': 30.81},
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': 3.81,
#     'throwerY': 30.81,
#     'receiver': 'gmay',
#     'receiverX': -2.05,
#     'receiverY': 28.77},
#    {'type': 22,
#     'thrower': 'gmay',
#     'throwerX': -2.05,
#     'throwerY': 28.77,
#     'turnoverX': 16.3,
#     'turnoverY': 37.15},
#    {'type': 16},
#    {'type': 25,
#     'line': ['gmay',
#      'mcrawford',
#      'kkhangaon',
#      'msommer',
#      'mkissmann',
#      'wberreman',
#      'rmendoza'],
#     'time': 121},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 126},
#    {'type': 20,
#     'thrower': 'mhecht',
#     'throwerX': 25.98,
#     'throwerY': 53.72,
#     'receiver': 'dclyburn',
#     'receiverX': 1.09,
#     'receiverY': 50.59},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 170},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': -26.67,
#     'throwerY': 41.59,
#     'receiver': 'wfrankenb',
#     'receiverX': -19.31,
#     'receiverY': 32.45},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -19.31,
#     'throwerY': 32.45,
#     'receiver': 'emagsig',
#     'receiverX': 0.54,
#     'receiverY': 30.95},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 0.54,
#     'throwerY': 30.95,
#     'receiver': 'wfrankenb',
#     'receiverX': -21.62,
#     'receiverY': 39.88},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -21.62,
#     'throwerY': 39.88,
#     'receiver': 'emagsig',
#     'receiverX': -22.85,
#     'receiverY': 45.95},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -22.85,
#     'throwerY': 45.95,
#     'receiver': 'mhecht',
#     'receiverX': 0.47,
#     'receiverY': 43.77},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 0.47,
#     'throwerY': 43.77,
#     'receiver': 'mwilliams',
#     'receiverX': 16.84,
#     'receiverY': 49.77},
#    {'type': 18,
#     'thrower': 'mwilliams',
#     'throwerX': 16.84,
#     'throwerY': 49.77,
#     'receiver': 'mhecht',
#     'receiverX': 23.05,
#     'receiverY': 48.61},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 23.05,
#     'throwerY': 48.61,
#     'receiver': 'klaurence',
#     'receiverX': 2.38,
#     'receiverY': 56.86},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': 2.38,
#     'throwerY': 56.86,
#     'receiver': 'mwilliams',
#     'receiverX': -19.1,
#     'receiverY': 56.79},
#    {'type': 18,
#     'thrower': 'mwilliams',
#     'throwerX': -19.1,
#     'throwerY': 56.79,
#     'receiver': 'klaurence',
#     'receiverX': -22.78,
#     'receiverY': 61.36},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -22.78,
#     'throwerY': 61.36,
#     'receiver': 'wfrankenb',
#     'receiverX': -23.13,
#     'receiverY': 68.79},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -23.13,
#     'throwerY': 68.79,
#     'receiver': 'dclyburn',
#     'receiverX': -20.87,
#     'receiverY': 74.04},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': -20.87,
#     'throwerY': 74.04,
#     'receiver': 'mhecht',
#     'receiverX': -24.63,
#     'receiverY': 86.38},
#    {'type': 19,
#     'thrower': 'mhecht',
#     'throwerX': -24.63,
#     'throwerY': 86.38,
#     'receiver': 'clung',
#     'receiverX': -23.4,
#     'receiverY': 108.2},
#    {'type': 1,
#     'line': ['rvickersb',
#      'pxu',
#      'jdecampos',
#      'mburke1',
#      'cbauman',
#      'rmendoza',
#      'wberreman'],
#     'time': 221},
#    {'type': 7,
#     'puller': 'cbauman',
#     'pullX': -2.05,
#     'pullY': 110.59,
#     'pullMs': 0},
#    {'type': 16},
#    {'type': 17},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 289},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -22.37,
#     'throwerY': 18.06,
#     'receiver': 'clung',
#     'receiverX': 2.59,
#     'receiverY': 23.59},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 2.59,
#     'throwerY': 33.59,
#     'receiver': 'wfrankenb',
#     'receiverX': 19.5,
#     'receiverY': 34.84},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 19.5,
#     'throwerY': 34.84,
#     'receiver': 'clung',
#     'receiverX': 11.18,
#     'receiverY': 37.77},
#    {'type': 22,
#     'thrower': 'clung',
#     'throwerX': 11.18,
#     'throwerY': 37.77,
#     'turnoverX': -21.9,
#     'turnoverY': 75.68},
#    {'type': 11, 'defender': 'klaurence'},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'wfrankenb',
#     'receiverX': -17.87,
#     'receiverY': 52.36},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -17.87,
#     'throwerY': 52.36,
#     'receiver': 'klaurence',
#     'receiverX': -14.74,
#     'receiverY': 58.63},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -14.74,
#     'throwerY': 58.63,
#     'receiver': 'wfrankenb',
#     'receiverX': -21.35,
#     'receiverY': 71.31},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -21.35,
#     'throwerY': 71.31,
#     'receiver': 'klaurence',
#     'receiverX': 1.22,
#     'receiverY': 64.9},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': 1.22,
#     'throwerY': 64.9,
#     'receiver': 'dclyburn',
#     'receiverX': 18.89,
#     'receiverY': 80.31},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 18.89,
#     'throwerY': 80.31,
#     'receiver': 'mwilliams',
#     'receiverX': 23.46,
#     'receiverY': 89.52},
#    {'type': 18,
#     'thrower': 'mwilliams',
#     'throwerX': 23.46,
#     'throwerY': 89.52,
#     'receiver': 'mhecht',
#     'receiverX': 22.77,
#     'receiverY': 81.27},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 22.77,
#     'throwerY': 81.27,
#     'receiver': 'emagsig',
#     'receiverX': -1.51,
#     'receiverY': 79.22},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -1.51,
#     'throwerY': 79.22,
#     'receiver': 'mhecht',
#     'receiverX': -14.33,
#     'receiverY': 84.27},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': -14.33,
#     'throwerY': 84.27,
#     'receiver': 'emagsig',
#     'receiverX': -0.21,
#     'receiverY': 79.29},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -0.21,
#     'throwerY': 79.29,
#     'receiver': 'mhecht',
#     'receiverX': 12,
#     'receiverY': 81},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 12,
#     'throwerY': 81,
#     'receiver': 'emagsig',
#     'receiverX': 0.75,
#     'receiverY': 81.68},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 0.75,
#     'throwerY': 81.68,
#     'receiver': 'dclyburn',
#     'receiverX': -21.56,
#     'receiverY': 90.13},
#    {'type': 19,
#     'thrower': 'dclyburn',
#     'throwerX': -21.56,
#     'throwerY': 90.13,
#     'receiver': 'emagsig',
#     'receiverX': -18.01,
#     'receiverY': 109.97},
#    {'type': 1,
#     'line': ['gmay',
#      'rcastro',
#      'mcrawford',
#      'kkhangaon',
#      'msommer',
#      'mkissmann',
#      'mburke1'],
#     'time': 377},
#    {'type': 7,
#     'puller': 'mkissmann',
#     'pullX': 2.25,
#     'pullY': 107.38,
#     'pullMs': 6913},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 413},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': -6.14,
#     'throwerY': 11.52,
#     'receiver': 'wfrankenb',
#     'receiverX': 2.52,
#     'receiverY': 19.9},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 2.52,
#     'throwerY': 19.9,
#     'receiver': 'clung',
#     'receiverX': 19.16,
#     'receiverY': 28.43},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 19.16,
#     'throwerY': 28.43,
#     'receiver': 'wfrankenb',
#     'receiverX': 23.32,
#     'receiverY': 35.04},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 23.32,
#     'throwerY': 35.04,
#     'receiver': 'clung',
#     'receiverX': 23.93,
#     'receiverY': 40.15},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 23.93,
#     'throwerY': 40.15,
#     'receiver': 'dclyburn',
#     'receiverX': 24.68,
#     'receiverY': 49.36},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 24.68,
#     'throwerY': 49.36,
#     'receiver': 'clung',
#     'receiverX': 15.48,
#     'receiverY': 53.86},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 15.48,
#     'throwerY': 53.86,
#     'receiver': 'dclyburn',
#     'receiverX': 20.8,
#     'receiverY': 64.56},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 20.8,
#     'throwerY': 64.56,
#     'receiver': 'clung',
#     'receiverX': 17.59,
#     'receiverY': 74.11},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 17.59,
#     'throwerY': 74.11,
#     'receiver': 'mhecht',
#     'receiverX': 3.27,
#     'receiverY': 82.77},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 3.27,
#     'throwerY': 82.77,
#     'receiver': 'emagsig',
#     'receiverX': 21.96,
#     'receiverY': 91.15},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 21.96,
#     'throwerY': 91.15,
#     'receiver': 'mhecht',
#     'receiverX': 24.48,
#     'receiverY': 94.7},
#    {'type': 17},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 24.48,
#     'throwerY': 100,
#     'receiver': 'wfrankenb',
#     'receiverX': 19.98,
#     'receiverY': 98.11},
#    {'type': 19,
#     'thrower': 'wfrankenb',
#     'throwerX': 19.98,
#     'throwerY': 98.11,
#     'receiver': 'dclyburn',
#     'receiverX': 7.36,
#     'receiverY': 104.72},
#    {'type': 1,
#     'line': ['rvickersb',
#      'pxu',
#      'jdecampos',
#      'mburke1',
#      'cbauman',
#      'rmendoza',
#      'wberreman'],
#     'time': 478},
#    {'type': 7,
#     'puller': 'cbauman',
#     'pullX': 0.13,
#     'pullY': 106.09,
#     'pullMs': 3832},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 507},
#    {'type': 18,
#     'thrower': 'clung',
#     'throwerX': 0,
#     'throwerY': 40,
#     'receiver': 'emagsig',
#     'receiverX': -3.35,
#     'receiverY': 38.86},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -3.35,
#     'throwerY': 38.86,
#     'receiver': 'klaurence',
#     'receiverX': -16.71,
#     'receiverY': 43.09},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -16.71,
#     'throwerY': 43.09,
#     'receiver': 'mhecht',
#     'receiverX': -17.26,
#     'receiverY': 57.54},
#    {'type': 22,
#     'thrower': 'mhecht',
#     'throwerX': -17.26,
#     'throwerY': 57.54,
#     'turnoverX': -14.8,
#     'turnoverY': 63.75},
#    {'type': 15},
#    {'type': 2,
#     'line': ['gmay',
#      'rcastro',
#      'mcrawford',
#      'kkhangaon',
#      'msommer',
#      'mkissmann',
#      'mhecht'],
#     'time': 545},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 26.66,
#     'throwerY': 49.22,
#     'receiver': 'kkhangaon',
#     'receiverX': 19.84,
#     'receiverY': 63.88},
#    {'type': 18,
#     'thrower': 'kkhangaon',
#     'throwerX': 19.84,
#     'throwerY': 63.88,
#     'receiver': 'mcrawford',
#     'receiverX': 1.09,
#     'receiverY': 56.38},
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': 1.09,
#     'throwerY': 56.38,
#     'receiver': 'mhecht',
#     'receiverX': 7.91,
#     'receiverY': 55.36},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 7.91,
#     'throwerY': 55.36,
#     'receiver': 'mkissmann',
#     'receiverX': 22.71,
#     'receiverY': 66.34},
#    {'type': 18,
#     'thrower': 'mkissmann',
#     'throwerX': 22.71,
#     'throwerY': 66.34,
#     'receiver': 'mhecht',
#     'receiverX': 4.5,
#     'receiverY': 72.06},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 4.5,
#     'throwerY': 72.06,
#     'receiver': 'mcrawford',
#     'receiverX': -16.65,
#     'receiverY': 77.86},
#    {'type': 18,
#     'thrower': 'mcrawford',
#     'throwerX': -16.65,
#     'throwerY': 77.86,
#     'receiver': 'msommer',
#     'receiverX': -23.19,
#     'receiverY': 92.86},
#    {'type': 18,
#     'thrower': 'msommer',
#     'throwerX': -23.19,
#     'throwerY': 92.86,
#     'receiver': 'mhecht',
#     'receiverX': -4.44,
#     'receiverY': 90.27},
#    {'type': 19,
#     'thrower': 'mhecht',
#     'throwerX': -4.44,
#     'throwerY': 90.27,
#     'receiver': 'msommer',
#     'receiverX': -0.69,
#     'receiverY': 104.04},
#    {'type': 1,
#     'line': ['rvickersb',
#      'pxu',
#      'jdecampos',
#      'mburke1',
#      'cbauman',
#      'rmendoza',
#      'wberreman'],
#     'time': 584},
#    {'type': 7,
#     'puller': 'cbauman',
#     'pullX': 22.84,
#     'pullY': 112.97,
#     'pullMs': 6245},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 608},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 26.66,
#     'throwerY': 54.61,
#     'receiver': 'dclyburn',
#     'receiverX': 4.5,
#     'receiverY': 38.45},
#    {'type': 18,
#     'thrower': 'dclyburn',
#     'throwerX': 4.5,
#     'throwerY': 38.45,
#     'receiver': 'wfrankenb',
#     'receiverX': 12.48,
#     'receiverY': 40.97},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': 12.48,
#     'throwerY': 40.97,
#     'receiver': 'mhecht',
#     'receiverX': 2.11,
#     'receiverY': 36.95},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 2.11,
#     'throwerY': 36.95,
#     'receiver': 'klaurence',
#     'receiverX': -17.74,
#     'receiverY': 38.11},
#    {'type': 22,
#     'thrower': 'klaurence',
#     'throwerX': -17.74,
#     'throwerY': 38.11,
#     'turnoverX': -4.85,
#     'turnoverY': 29.38},
#    {'type': 15},
#    {'type': 2,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 659},
#    {'type': 18,
#     'thrower': 'mhecht',
#     'throwerX': 25.5,
#     'throwerY': 55.09,
#     'receiver': 'klaurence',
#     'receiverX': -7.64,
#     'receiverY': 66.2},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -7.64,
#     'throwerY': 66.2,
#     'receiver': 'emagsig',
#     'receiverX': -4.37,
#     'receiverY': 71.25},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -4.37,
#     'throwerY': 71.25,
#     'receiver': 'klaurence',
#     'receiverX': -13.71,
#     'receiverY': 71.18},
#    {'type': 18,
#     'thrower': 'klaurence',
#     'throwerX': -13.71,
#     'throwerY': 71.18,
#     'receiver': 'wfrankenb',
#     'receiverX': -23.74,
#     'receiverY': 82.36},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -23.74,
#     'throwerY': 82.36,
#     'receiver': 'emagsig',
#     'receiverX': -24.08,
#     'receiverY': 91.43},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': -24.08,
#     'throwerY': 91.43,
#     'receiver': 'wfrankenb',
#     'receiverX': -6.42,
#     'receiverY': 86.86},
#    {'type': 18,
#     'thrower': 'wfrankenb',
#     'throwerX': -6.42,
#     'throwerY': 86.86,
#     'receiver': 'emagsig',
#     'receiverX': 5.66,
#     'receiverY': 91.09},
#    {'type': 18,
#     'thrower': 'emagsig',
#     'throwerX': 5.66,
#     'throwerY': 91.09,
#     'receiver': 'mhecht',
#     'receiverX': -4.92,
#     'receiverY': 95.31},
#    {'type': 19,
#     'thrower': 'mhecht',
#     'throwerX': -4.92,
#     'throwerY': 95.31,
#     'receiver': 'clung',
#     'receiverX': 5.59,
#     'receiverY': 103.7},
#    {'type': 1,
#     'line': ['gmay',
#      'wberreman',
#      'emagsig',
#      'dclyburn',
#      'rmendoza',
#      'rvickersb',
#      'mburke1'],
#     'time': 687},
#    {'type': 8, 'puller': 'emagsig'},
#    {'type': 13},
#    {'type': 3,
#     'line': ['wfrankenb',
#      'dclyburn',
#      'clung',
#      'emagsig',
#      'klaurence',
#      'mhecht',
#      'mwilliams'],
#     'time': 718},
#    {'type': 31}]}}

# %%
data = data['data']

# %%
# initialize stuff
game_length = len(data['homeEvents']) + len(data['awayEvents'])
game_events = [val for val in range(game_length)]

table = pd.DataFrame(index = game_events,
        columns = 
    ['home_team','away_team', # other info that won't change during a game
    'home_score','away_score','quarter','time', 'point',# score / time stuff
    'pull','drop_pull','offsides','pass','drop','throwaway','stall','block','callahan', #event booleans
    'penalty','goal','injury','Q1_end','Q2_end','Q3_end','Q4_end','OT1_end','OT2_end', #events cont'd
    'game_delay','game_postponed', 'player_misconduct','player_ejected','substitutions','timeout', #events cont'd
    'team_off','team_def','team_score', 'team_penalty', 'team_timeout',  # team ID for events, infer most from O/D
    'thrower','receiver','defender','pullMs','deltaX','deltaY',]) # player ID for events, disc movement for events

table.loc[game_events,'home_team'] = 'POR'
table.loc[game_events,'away_team'] = 'OAK'
table.loc[0,'home_score'] = 0
table.loc[0,'away_score'] = 0
table.loc[0,'quarter'] = 1
table.loc[0,'point'] = 1
table.loc[0,'time'] = 720
#table.loc[0,'pull'] = True

# %%
homes = data['homeEvents']
aways = data['awayEvents']

for home in homes[0:10]:
    print(event_keys[home['type']], home)
print()
for home in aways[0:3]:
    print(event_keys[home['type']], home)
# Out:
# O_line {'type': 2, 'line': ['jjohnson1', 'efriedman', 'jsnyder', 'rhayes', 'sfraner', 'isweeney', 'tdoi'], 'time': 0}
# Pass {'type': 18, 'thrower': 'efriedman', 'throwerX': -16.1, 'throwerY': 7.22, 'receiver': 'jjohnson1', 'receiverX': -1.46, 'receiverY': 15.54}
# Pass {'type': 18, 'thrower': 'jjohnson1', 'throwerX': -1.46, 'throwerY': 15.54, 'receiver': 'efriedman', 'receiverX': -17.13, 'receiverY': 21.22}
# Pass {'type': 18, 'thrower': 'efriedman', 'throwerX': -17.13, 'throwerY': 21.22, 'receiver': 'jsnyder', 'receiverX': -17.45, 'receiverY': 94.7}
# Pass {'type': 18, 'thrower': 'jsnyder', 'throwerX': -17.45, 'throwerY': 94.7, 'receiver': 'rhayes', 'receiverX': -17.39, 'receiverY': 86.83}
# Pass {'type': 18, 'thrower': 'rhayes', 'throwerX': -17.39, 'throwerY': 86.83, 'receiver': 'sfraner', 'receiverX': -17.06, 'receiverY': 74.83}
# Pass {'type': 18, 'thrower': 'sfraner', 'throwerX': -17.06, 'throwerY': 74.83, 'receiver': 'efriedman', 'receiverX': 0.35, 'receiverY': 63.8}
# Pass {'type': 18, 'thrower': 'efriedman', 'throwerX': 0.35, 'throwerY': 63.8, 'receiver': 'isweeney', 'receiverX': -19.19, 'receiverY': 80.25}
# Pass {'type': 18, 'thrower': 'isweeney', 'throwerX': -19.19, 'throwerY': 80.25, 'receiver': 'efriedman', 'receiverX': 2.67, 'receiverY': 74.58}
# Throwaway_own {'type': 22, 'thrower': 'efriedman', 'throwerX': 2.67, 'throwerY': 74.58, 'turnoverX': -13.71, 'turnoverY': 86.06}
#
# D_line {'type': 1, 'line': ['rvickersb', 'pxu', 'jdecampos', 'mburke1', 'cbauman', 'rmendoza', 'wberreman'], 'time': 0}
# Pull_in {'type': 7, 'puller': 'cbauman', 'pullX': -19.58, 'pullY': 110.93, 'pullMs': 3879}
# Block {'type': 11, 'defender': 'rvickersb'}

# %%
    ['home_team','away_team', # other info that won't change during a game, initialize before looping through events
    'home_score','away_score','quarter','time', 'point',# score / time stuff
    'pull','drop_pull','offsides','pass','drop','throwaway','stall','block','callahan', #event booleans
    'penalty','goal','injury','Q1_end','Q2_end','Q3_end','Q4_end','OT1_end','OT2_end', #events cont'd
    'game_delay','game_postponed', 'player_misconduct','player_ejected','substitutions','timeout', #events cont'd
    'team_off','team_def','team_score', 'team_penalty', 'team_timeout',  # team ID for events, infer most from O/D
    'thrower','receiver','defender','X','Y', # player ID for events, disc movement for events
    'pullMs','deltaX','deltaY']) # player ID for events, disc movement for events

# %%
table.head()
# Out:
#   home_team away_team home_score away_score quarter time point pull drop_pull  \
# 0       POR       OAK          0          0       1  720     1  NaN       NaN
# 1       POR       OAK        NaN        NaN     NaN  NaN   NaN  NaN       NaN
# 2       POR       OAK        NaN        NaN     NaN  NaN   NaN  NaN       NaN
# 3       POR       OAK        NaN        NaN     NaN  NaN   NaN  NaN       NaN
# 4       POR       OAK        NaN        NaN     NaN  NaN   NaN  NaN       NaN
#
#   offsides  ... team_def team_score team_penalty team_timeout thrower  \
# 0      NaN  ...      NaN        NaN          NaN          NaN     NaN
# 1      NaN  ...      NaN        NaN          NaN          NaN     NaN
# 2      NaN  ...      NaN        NaN          NaN          NaN     NaN
# 3      NaN  ...      NaN        NaN          NaN          NaN     NaN
# 4      NaN  ...      NaN        NaN          NaN          NaN     NaN
#
#   receiver defender pullMs deltaX deltaY
# 0      NaN      NaN    NaN    NaN    NaN
# 1      NaN      NaN    NaN    NaN    NaN
# 2      NaN      NaN    NaN    NaN    NaN
# 3      NaN      NaN    NaN    NaN    NaN
# 4      NaN      NaN    NaN    NaN    NaN
#
# [5 rows x 42 columns]

# %%
home_team = 'POR'
away_team = 'OAK'
team_list = [home_team, away_team]

# %%
# bring events into lists, to be popped
event_lists = {home_team: data['homeEvents'], away_team: data['awayEvents']}
pos_team = None
puller = None
def_team = None

# pull
for i in game_events[0:]:
    
    home_type = event_lists[home_team][0]['type']
    away_type = event_lists[away_team][0]['type']
    
    # period start: O/D line classification
    if not pos_team:
        if home_type == 2:
            table.loc[i,'team_off'] = home_team
            table.loc[i,'team_def'] = away_team
            puller = away_team
            pos_team = home_team
        else:
            table.loc[i,'team_off'] = away_team
            table.loc[i,'team_def'] = home_team
            puller = home_team
            pos_team = away_team
        for val in team_list:
            event_lists[val].pop(0)
    
    # pull
    if puller:
        # pull stats
        table.loc[i,'pull'] = True
        pull = event_lists[puller].pop(0)
        table.loc[i,'thrower'] = pull.get('puller')
        table.loc[i,'pullMs'] = pull.get('pullMs')
        table.loc[i,'deltaX'] = pull.get('pullX')
        table.loc[i,'deltaY'] = pull.get('pullY')
        puller = None
        
        # offsides check should happen
        
        # dropped pull?
        if event_lists[pos_team][0]['type'] == 21:
            print('dropped pull should do stuff!!!')
            break
            
        def_team = away_team
        continue
        
    # turnover keys, score keys, callahan keys
    # 11, 13, 14, 20, 22, 24
    # 15, 19
    # 12, 23, 
    
    # period stoppage, timeout, other
    # 28,29,30,31,32,33
    # 3,4,5,6
    # 34,35

# %%
event_keys
# Out:
# {1: 'D_line',
#  2: 'O_line',
#  3: 'Timeout_own_line',
#  4: 'Timeout_own',
#  5: 'Timeout_opp_line',
#  6: 'Timeout_opp',
#  7: 'Pull_in',
#  8: 'Pull_out',
#  9: 'Offsides_own',
#  10: 'Offsides_opp',
#  11: 'Block',
#  12: 'Callahan_opp',
#  13: 'Throwaway_opp',
#  14: 'Stall_opp',
#  15: 'Score_opp',
#  16: 'Penalty_own',
#  17: 'Penalty_opp',
#  18: 'Pass',
#  19: 'Goal',
#  20: 'Drop',
#  21: 'Drop_pull',
#  22: 'Throwaway_own',
#  23: 'Callahan_own',
#  24: 'Stall_own',
#  25: 'Injury_line',
#  26: 'Player_misconduct',
#  27: 'Player_ejection',
#  28: 'End_Q1',
#  29: 'End_Q2',
#  30: 'End_Q3',
#  31: 'End_Q4',
#  32: 'End_OT1',
#  33: 'End_OT2',
#  34: 'Delayed',
#  35: 'Postponed'}

# %%
x = [0,1]

# %% [markdown]
# ## Event Classifer Class
# #### initialize with: gameinfo (home,away), event lists, eventually big-scheme index
# #### Based on event key . . .
# #### add certain stuff to table from home/away events
# #### setup things for next event
# #### continue through loop

# %%
games['data'][1:2]
# Out:
# [{'gameID': '2023-05-19-OAK-POR',
#   'awayTeamID': 'spiders',
#   'homeTeamID': 'nitro',
#   'awayScore': 24,
#   'homeScore': 23,
#   'status': 'Final',
#   'startTimestamp': '2023-05-19T19:30:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/oakland-at-portland-5-19-2023',
#   'updateTimestamp': '2023-05-23T18:42:42.617Z',
#   'week': 'week-4'}]

# %%
sum([len(testgame.gamedata[val]) for val in testgame.gamedata.keys()])
# Out:
# 824

# %%
testgame.gamedata[testgame.away][1]
# Out:
# {'type': 7,
#  'puller': 'cbauman',
#  'pullX': -19.58,
#  'pullY': 110.93,
#  'pullMs': 3879}

# %%
testgame.gamedata[testgame.home][0:5]
# Out:
# [{'type': 2,
#   'line': ['jjohnson1',
#    'efriedman',
#    'jsnyder',
#    'rhayes',
#    'sfraner',
#    'isweeney',
#    'tdoi'],
#   'time': 0},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -16.1,
#   'throwerY': 7.22,
#   'receiver': 'jjohnson1',
#   'receiverX': -1.46,
#   'receiverY': 15.54},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': -1.46,
#   'throwerY': 15.54,
#   'receiver': 'efriedman',
#   'receiverX': -17.13,
#   'receiverY': 21.22},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -17.13,
#   'throwerY': 21.22,
#   'receiver': 'jsnyder',
#   'receiverX': -17.45,
#   'receiverY': 94.7},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': -17.45,
#   'throwerY': 94.7,
#   'receiver': 'rhayes',
#   'receiverX': -17.39,
#   'receiverY': 86.83}]

# %% [markdown]
# #### Rules Notes, [link](https://theaudl.com/sites/default/files/AUDLRuleBook2023.pdf)
#  - flip determines starting O/D and sides of field
#    - 4 quarters, 12 mins, 2 timeouts per half with subs allowed
#  - decisions reverse at the start of each quarter
#  - additional flip for overtime, decsisions revers if 2nd overtime needed
#    - OT1 is 5 mins, OT2 is sudden death without time
#    - 1 timeout per overtime
#  - see **17 Glossary** for definitions of events

# %%
pd.DataFrame(testgame.table.iloc[0,4:]).T
# Out:
#   away_team home_score away_score quarter time point pull drop_pull offsides  \
# 0       OAK          0          0       1  720     1  NaN       NaN      NaN
#
#   pass  ... team_score team_penalty team_timeout penalty_player thrower  \
# 0  NaN  ...        NaN          NaN          NaN            NaN     NaN
#
#   receiver defender pullMs deltaX deltaY
# 0      NaN      NaN    NaN    NaN    NaN
#
# [1 rows x 42 columns]

# %%
class Parser:
    def __init__(self, gameinfo, gamedata): # provide game metadata, and gamedata['data']
        
        self.gameinfo = gameinfo
        game_length = len(gamedata['homeEvents']) + len(gamedata['awayEvents']) # prepopulate index with max events
        
        # use team abbreviations
        away_team = gameinfo['gameID'].split('-')[-2]
        self.away = away_team
        home_team = gameinfo['gameID'].split('-')[-1]
        self.home = home_team

        # gather home and away events into lists, to be popped
        self.gamedata = {home_team: gamedata['homeEvents'], away_team: gamedata['awayEvents']}

        # intialize table
        table = pd.DataFrame(index = [val for val in range(game_length)],
                columns = 
            ['gameID','date','week','home_team','away_team', # flat attributes for the game
            'home_score','away_score','quarter','time', 'point', # score / time
            'pull','drop_pull','offsides','pass','drop','throwaway','stall','block','callahan', #event booleans
            'penalty','goal','injury','Q1_end','Q2_end','Q3_end','Q4_end','OT1_end','OT2_end', #events cont'd
            'game_delay','game_postponed', 'player_misconduct','player_ejected','substitutions','timeout', #events cont'd
            'team_off','team_def','team_score', 'team_penalty', 'team_timeout',  # team ID for events, infer most from O/D
            'penalty_player','thrower','receiver','defender', # player ID for events
            'pullMs','deltaX','deltaY','X','Y',]) # disc movement, player position for events

        table.loc[:,'gameID'] = gameinfo['gameID']
        table.loc[:,'date'] = f"{gameinfo['startTimestamp']}_{gameinfo['startTimezone']}"
        table.loc[:,'week'] = gameinfo['week'].replace('week-','').replace('-weekend','')     
        table.loc[:,'home_team'] = home_team
        table.loc[:,'away_team'] = away_team
        
        table.loc[0,'home_score'] = 0
        table.loc[0,'away_score'] = 0
        table.loc[0,'quarter'] = 1
        table.loc[0,'point'] = 1
        table.loc[0,'time'] = 720
        
        self.table = table
        self.ind = 0
        
    
    def pos_change(pos_team):
        return self.home if pos_team != self.home else self.away
    
    def parse_events(self):

        # start of game, determine starting team
        event_home = self.gamedata[self.home].pop(0)
        home_line = event_home['line']
        event_away = self.gamedata[self.away].pop(0)
        away_line = event_away['line']
        
        # write first record, collect "startO" for quarter changes
        if event_home['type'] == 2: # 2 is starting O line, 1 is starting D line
            self.table.loc[0,'team_off'] = home_team
            self.table.loc[0,'team_def'] = away_team
            pos_team = self.home
            startO = self.home
        else:
            self.table.loc[0,'team_off'] = away_team
            self.table.loc[0,'team_def'] = home_team
            pos_team = self.away
            startO = self.away


        # go through all events in list
        while sum([len(self.gamedata[val]) for val in self.gamedata.keys()]) > 0:

            if self.ind != 0:
                # get lines again           
                home_line = ...
                away_line = ...
            
            # pull
            event = self.gamedata[pos_change(pos_team)].pop(0) # pop
            
            if event['type'] not in [7,8]: # check
                print('NOT A PULLER !!!', event)
                break 
            
            self.table.loc[self.ind,'pull'] = 1
            self.table.loc[self.ind,'thrower'] = event['puller']
            if event['type'] == 7:
                self.table.loc[self.ind,'pullMs'] = event['pullMs']
                self.table.loc[self.ind,'deltaX'] = event['pullX']
                self.table.loc[self.ind,'deltaY'] = event['pullY']
            
            self.ind += 1 # new event
            
            # pull reception
            event = self.gamedata[pos_team][0]
            
            # OFFSIDES CHECK ???
            
            if event['type'] == 21: # pull was dropped    
                event = self.gamedata[pos_team.pop(0)] # pop
                self.table.loc[self.ind, 'drop_pull'] = 1
                self.table.loc[self.ind, 'receiver'] = event['receiver']
                self.table.loc[self.ind, 'X'] = event['receiverX']
                self.table.loc[self.ind, 'Y'] = event['receiverY']
                pos_team = pos_change(pos_team)
                self.ind += 1 # new event
            
            event = self.gamedata[pos_team][0]
            while event['type'] != 19 or event['type'] > 27: # score or end of period
                
   
            
            # events until turnover
            # ...
    # turnover keys, score keys, callahan keys
    # 11, 13, 14, 20, 22, 24
    # 15, 19
    # 12, 23, 
    
    # period stoppage, timeout, other
    # 28,29,30,31,32,33
    # 3,4,5,6
    # 34,35
            # goal
            # restart loop

    
    def write_record(self):
        return

# %%
        
    # def event_classifier(event_type):
    #     match event_type:
    #         case in [1,2]:
    #             # OLine/Dline
    #                 # logic for Line Starts
    #                 # include pull 7-8, offsides 9-10
    #                 # dropped pull covered in turnovers 21
    #         case 18: 
    #             # Completed Pass
    #                 # logic for a completed pass
    #         case in [15,19]:
    #             # Score_opp, Goal
    #                 # logic for score
    #         case in [11,13,14,20,21,22,24]:
    #             # block, throwaway, stall, drop
    #                 # turnover logic
    #         case in [16,17]:
    #             # penalty
    #         case >= 28:
    #             # quarter ends and special delays
    #         case in [3,4,5,6,25]:
    #             # timeout or injury
    #         case in [12,23]:
    #             # callahan
    #         case in [26,27]:
    #             # special foul

# %%
URL = 'https://www.backend.audlstats.com/api/v1/gameEvents?'
gamedata = None

for game in games['data'][1:2]:
    # request game events
    parameters = 'gameID=2023-05-19-OAK-POR'

    URL = f'{URL}gameID={game["gameID"]}'
    r = requests.get(URL)
    if r.status_code == 200:
        gamedata = r.json()
        gamedata = gamedata.get('data')
    if not gamedata:
        print('error for', game['gameID'])
        break
        
    testgame = Parser(game, gamedata)

# %%
testgame.gamedata
# Out:
# {'POR': [{'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'tdoi'],
#    'time': 0},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -16.1,
#    'throwerY': 7.22,
#    'receiver': 'jjohnson1',
#    'receiverX': -1.46,
#    'receiverY': 15.54},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -1.46,
#    'throwerY': 15.54,
#    'receiver': 'efriedman',
#    'receiverX': -17.13,
#    'receiverY': 21.22},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -17.13,
#    'throwerY': 21.22,
#    'receiver': 'jsnyder',
#    'receiverX': -17.45,
#    'receiverY': 94.7},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -17.45,
#    'throwerY': 94.7,
#    'receiver': 'rhayes',
#    'receiverX': -17.39,
#    'receiverY': 86.83},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -17.39,
#    'throwerY': 86.83,
#    'receiver': 'sfraner',
#    'receiverX': -17.06,
#    'receiverY': 74.83},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -17.06,
#    'throwerY': 74.83,
#    'receiver': 'efriedman',
#    'receiverX': 0.35,
#    'receiverY': 63.8},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 0.35,
#    'throwerY': 63.8,
#    'receiver': 'isweeney',
#    'receiverX': -19.19,
#    'receiverY': 80.25},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -19.19,
#    'throwerY': 80.25,
#    'receiver': 'efriedman',
#    'receiverX': 2.67,
#    'receiverY': 74.58},
#   {'type': 22,
#    'thrower': 'efriedman',
#    'throwerX': 2.67,
#    'throwerY': 74.58,
#    'turnoverX': -13.71,
#    'turnoverY': 86.06},
#   {'type': 13},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -4.68,
#    'throwerY': 20,
#    'receiver': 'jjohnson1',
#    'receiverX': 17.12,
#    'receiverY': 18.12},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 17.12,
#    'throwerY': 18.12,
#    'receiver': 'isweeney',
#    'receiverX': -14.81,
#    'receiverY': 16.32},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -14.81,
#    'throwerY': 16.32,
#    'receiver': 'sfraner',
#    'receiverX': -23,
#    'receiverY': 34.96},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -23,
#    'throwerY': 34.96,
#    'receiver': 'rhayes',
#    'receiverX': -11.07,
#    'receiverY': 36},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -11.07,
#    'throwerY': 36,
#    'receiver': 'efriedman',
#    'receiverX': 2.03,
#    'receiverY': 36.32},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 2.03,
#    'throwerY': 36.32,
#    'receiver': 'tdoi',
#    'receiverX': 18.15,
#    'receiverY': 34.38},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 18.15,
#    'throwerY': 34.38,
#    'receiver': 'efriedman',
#    'receiverX': 9.31,
#    'receiverY': 30.9},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 9.31,
#    'throwerY': 30.9,
#    'receiver': 'isweeney',
#    'receiverX': -11.26,
#    'receiverY': 24.38},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -11.26,
#    'throwerY': 24.38,
#    'receiver': 'efriedman',
#    'receiverX': 11.51,
#    'receiverY': 30.77},
#   {'type': 19,
#    'thrower': 'efriedman',
#    'throwerX': 11.51,
#    'throwerY': 30.77,
#    'receiver': 'tdoi',
#    'receiverX': 10.54,
#    'receiverY': 108.45},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'llavoie',
#     'jlee',
#     'arueda',
#     'bstout',
#     'apetersch'],
#    'time': 115},
#   {'type': 7,
#    'puller': 'sradlauer',
#    'pullX': 0.87,
#    'pullY': 94.96,
#    'pullMs': 3080},
#   {'type': 11, 'defender': 'sradlauer'},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': 25.63,
#    'throwerY': 67.29,
#    'receiver': 'jlee',
#    'receiverX': 6.54,
#    'receiverY': 58.64},
#   {'type': 18,
#    'thrower': 'jlee',
#    'throwerX': 6.54,
#    'throwerY': 58.64,
#    'receiver': 'jmoore1',
#    'receiverX': -18.67,
#    'receiverY': 53.61},
#   {'type': 18,
#    'thrower': 'jmoore1',
#    'throwerX': -18.67,
#    'throwerY': 53.61,
#    'receiver': 'llavoie',
#    'receiverX': 11.18,
#    'receiverY': 59.93},
#   {'type': 22,
#    'thrower': 'llavoie',
#    'throwerX': 11.18,
#    'throwerY': 59.93,
#    'turnoverX': 20.79,
#    'turnoverY': 104.06},
#   {'type': 13},
#   {'type': 18,
#    'thrower': 'llavoie',
#    'throwerX': 24.86,
#    'throwerY': 45.03,
#    'receiver': 'jlee',
#    'receiverX': 22.47,
#    'receiverY': 30.32},
#   {'type': 22,
#    'thrower': 'jlee',
#    'throwerX': 22.47,
#    'throwerY': 30.32,
#    'turnoverX': 24.02,
#    'turnoverY': 50.64},
#   {'type': 13},
#   {'type': 18,
#    'thrower': 'jlee',
#    'throwerX': 14.92,
#    'throwerY': 39.41,
#    'receiver': 'llavoie',
#    'receiverX': -0.42,
#    'receiverY': 46.51},
#   {'type': 18,
#    'thrower': 'llavoie',
#    'throwerX': -0.42,
#    'throwerY': 46.51,
#    'receiver': 'jmoore1',
#    'receiverX': -18.74,
#    'receiverY': 56.45},
#   {'type': 22,
#    'thrower': 'jmoore1',
#    'throwerX': -18.74,
#    'throwerY': 56.45,
#    'turnoverX': -10.42,
#    'turnoverY': 106.64},
#   {'type': 15},
#   {'type': 2,
#    'line': ['efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'tdoi',
#     'isweeney',
#     'qbuermeye'],
#    'time': 256},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -0.04,
#    'throwerY': 14.32,
#    'receiver': 'isweeney',
#    'receiverX': -6.1,
#    'receiverY': 19.35},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -6.1,
#    'throwerY': 19.35,
#    'receiver': 'efriedman',
#    'receiverX': -16.48,
#    'receiverY': 32.45},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -16.48,
#    'throwerY': 32.45,
#    'receiver': 'qbuermeye',
#    'receiverX': -22.74,
#    'receiverY': 41.93},
#   {'type': 18,
#    'thrower': 'qbuermeye',
#    'throwerX': -22.74,
#    'throwerY': 41.93,
#    'receiver': 'sfraner',
#    'receiverX': -16.93,
#    'receiverY': 51.09},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -16.93,
#    'throwerY': 51.09,
#    'receiver': 'rhayes',
#    'receiverX': -23.19,
#    'receiverY': 60.77},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -23.19,
#    'throwerY': 60.77,
#    'receiver': 'efriedman',
#    'receiverX': -13.45,
#    'receiverY': 66.38},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -13.45,
#    'throwerY': 66.38,
#    'receiver': 'rhayes',
#    'receiverX': -25.58,
#    'receiverY': 72.58},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -25.58,
#    'throwerY': 72.58,
#    'receiver': 'efriedman',
#    'receiverX': -5.71,
#    'receiverY': 63.87},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -5.71,
#    'throwerY': 63.87,
#    'receiver': 'sfraner',
#    'receiverX': -17.84,
#    'receiverY': 80.06},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -17.84,
#    'throwerY': 80.06,
#    'receiver': 'jsnyder',
#    'receiverX': 0.93,
#    'receiverY': 70.9},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 0.93,
#    'throwerY': 70.9,
#    'receiver': 'rhayes',
#    'receiverX': 15.5,
#    'receiverY': 90.7},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': 15.5,
#    'throwerY': 90.7,
#    'receiver': 'qbuermeye',
#    'receiverX': 14.28,
#    'receiverY': 104.58},
#   {'type': 1,
#    'line': ['jmoore1',
#     'apetersch',
#     'arueda',
#     'gnakano',
#     'bstout',
#     'slatarski',
#     'jlee'],
#    'time': 316},
#   {'type': 7,
#    'puller': 'bstout',
#    'pullX': 25.57,
#    'pullY': 105.54,
#    'pullMs': 6164},
#   {'type': 13},
#   {'type': 18,
#    'thrower': 'slatarski',
#    'throwerX': 15.57,
#    'throwerY': 20,
#    'receiver': 'apetersch',
#    'receiverX': 18.41,
#    'receiverY': 32.06},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': 18.41,
#    'throwerY': 32.06,
#    'receiver': 'gnakano',
#    'receiverX': 20.02,
#    'receiverY': 56.12},
#   {'type': 18,
#    'thrower': 'gnakano',
#    'throwerX': 20.02,
#    'throwerY': 56.12,
#    'receiver': 'slatarski',
#    'receiverX': 9.12,
#    'receiverY': 59.74},
#   {'type': 18,
#    'thrower': 'slatarski',
#    'throwerX': 9.12,
#    'throwerY': 59.74,
#    'receiver': 'apetersch',
#    'receiverX': -10.1,
#    'receiverY': 57.93},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': -10.1,
#    'throwerY': 57.93,
#    'receiver': 'jlee',
#    'receiverX': -8.81,
#    'receiverY': 72.64},
#   {'type': 18,
#    'thrower': 'jlee',
#    'throwerX': -8.81,
#    'throwerY': 72.64,
#    'receiver': 'apetersch',
#    'receiverX': -1.39,
#    'receiverY': 74.64},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': -1.39,
#    'throwerY': 74.64,
#    'receiver': 'bstout',
#    'receiverX': 4.54,
#    'receiverY': 79.8},
#   {'type': 18,
#    'thrower': 'bstout',
#    'throwerX': 4.54,
#    'throwerY': 79.8,
#    'receiver': 'slatarski',
#    'receiverX': 0.09,
#    'receiverY': 70.7},
#   {'type': 18,
#    'thrower': 'slatarski',
#    'throwerX': 0.09,
#    'throwerY': 70.7,
#    'receiver': 'jlee',
#    'receiverX': -16.35,
#    'receiverY': 71.67},
#   {'type': 18,
#    'thrower': 'jlee',
#    'throwerX': -16.35,
#    'throwerY': 71.67,
#    'receiver': 'apetersch',
#    'receiverX': -2.04,
#    'receiverY': 61.87},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': -2.04,
#    'throwerY': 61.87,
#    'receiver': 'slatarski',
#    'receiverX': -18.16,
#    'receiverY': 78.9},
#   {'type': 18,
#    'thrower': 'slatarski',
#    'throwerX': -18.16,
#    'throwerY': 78.9,
#    'receiver': 'jlee',
#    'receiverX': -4.36,
#    'receiverY': 73.74},
#   {'type': 18,
#    'thrower': 'jlee',
#    'throwerX': -4.36,
#    'throwerY': 73.74,
#    'receiver': 'jmoore1',
#    'receiverX': 14.28,
#    'receiverY': 79.8},
#   {'type': 18,
#    'thrower': 'jmoore1',
#    'throwerX': 14.28,
#    'throwerY': 79.8,
#    'receiver': 'jlee',
#    'receiverX': -1.59,
#    'receiverY': 74.96},
#   {'type': 18,
#    'thrower': 'jlee',
#    'throwerX': -1.59,
#    'throwerY': 74.96,
#    'receiver': 'jmoore1',
#    'receiverX': 8.22,
#    'receiverY': 75.09},
#   {'type': 3,
#    'line': ['bstout',
#     'rhayes',
#     'qbuermeye',
#     'apetersch',
#     'jlee',
#     'isweeney',
#     'jmoore1'],
#    'time': 403},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 15.7,
#    'throwerY': 84.25,
#    'receiver': 'rhayes',
#    'receiverX': 1.9,
#    'receiverY': 94.38},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': 1.9,
#    'throwerY': 94.38,
#    'receiver': 'isweeney',
#    'receiverX': 24.15,
#    'receiverY': 104.38},
#   {'type': 1,
#    'line': ['cstillwel',
#     'ceustis',
#     'llavoie',
#     'sradlauer',
#     'slatarski',
#     'gnakano',
#     'jlee'],
#    'time': 411},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': 1.7,
#    'pullY': 118.58,
#    'pullMs': 7161},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'tdoi',
#     'isweeney'],
#    'time': 453},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 25.69,
#    'throwerY': 42.77,
#    'receiver': 'sfraner',
#    'receiverX': 11.57,
#    'receiverY': 47.09},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 11.57,
#    'throwerY': 47.09,
#    'receiver': 'isweeney',
#    'receiverX': 6.22,
#    'receiverY': 39.8},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 6.22,
#    'throwerY': 39.8,
#    'receiver': 'efriedman',
#    'receiverX': -1.46,
#    'receiverY': 95.03},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -1.46,
#    'throwerY': 95.03,
#    'receiver': 'sfraner',
#    'receiverX': -1.39,
#    'receiverY': 89.74},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -1.39,
#    'throwerY': 89.74,
#    'receiver': 'jsnyder',
#    'receiverX': -4.75,
#    'receiverY': 72.32},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -4.75,
#    'throwerY': 72.32,
#    'receiver': 'sfraner',
#    'receiverX': -2.23,
#    'receiverY': 81.48},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -2.23,
#    'throwerY': 81.48,
#    'receiver': 'rhayes',
#    'receiverX': 11.44,
#    'receiverY': 95.93},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 11.44,
#    'throwerY': 95.93,
#    'receiver': 'jsnyder',
#    'receiverX': 11.76,
#    'receiverY': 85.29},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 11.76,
#    'throwerY': 85.29,
#    'receiver': 'rhayes',
#    'receiverX': 15.31,
#    'receiverY': 94.77},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': 15.31,
#    'throwerY': 94.77,
#    'receiver': 'efriedman',
#    'receiverX': 20.28,
#    'receiverY': 116},
#   {'type': 1,
#    'line': ['bstout',
#     'sradlauer',
#     'arueda',
#     'apetersch',
#     'qbuermeye',
#     'ceustis',
#     'llavoie'],
#    'time': 521},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': -3.33,
#    'pullY': 116.19,
#    'pullMs': 6895},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'tdoi',
#     'isweeney',
#     'cstillwel'],
#    'time': 568},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 13.31,
#    'throwerY': 25.61,
#    'receiver': 'rhayes',
#    'receiverX': 19.25,
#    'receiverY': 36.51},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 19.25,
#    'throwerY': 36.51,
#    'receiver': 'sfraner',
#    'receiverX': 26.21,
#    'receiverY': 50.77},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 26.21,
#    'throwerY': 50.77,
#    'receiver': 'cstillwel',
#    'receiverX': 24.79,
#    'receiverY': 66.7},
#   {'type': 18,
#    'thrower': 'cstillwel',
#    'throwerX': 24.79,
#    'throwerY': 66.7,
#    'receiver': 'isweeney',
#    'receiverX': 13.05,
#    'receiverY': 70.32},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 13.05,
#    'throwerY': 70.32,
#    'receiver': 'rhayes',
#    'receiverX': -13.58,
#    'receiverY': 69.67},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -13.58,
#    'throwerY': 69.67,
#    'receiver': 'sfraner',
#    'receiverX': 1.7,
#    'receiverY': 68.96},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 1.7,
#    'throwerY': 68.96,
#    'receiver': 'jjohnson1',
#    'receiverX': 24.66,
#    'receiverY': 85.67},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 24.66,
#    'throwerY': 85.67,
#    'receiver': 'sfraner',
#    'receiverX': 2.61,
#    'receiverY': 72.45},
#   {'type': 22,
#    'thrower': 'sfraner',
#    'throwerX': 2.61,
#    'throwerY': 72.45,
#    'turnoverX': 25.89,
#    'turnoverY': 89.8},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'tdoi',
#     'jmoore1',
#     'qbuermeye'],
#    'time': 625},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -8.81,
#    'throwerY': 21.87,
#    'receiver': 'efriedman',
#    'receiverX': 4.35,
#    'receiverY': 23.41},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 4.35,
#    'throwerY': 23.41,
#    'receiver': 'jsnyder',
#    'receiverX': -7.71,
#    'receiverY': 27.87},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -7.71,
#    'throwerY': 27.87,
#    'receiver': 'efriedman',
#    'receiverX': 0.93,
#    'receiverY': 19.48},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 0.93,
#    'throwerY': 19.48,
#    'receiver': 'rhayes',
#    'receiverX': -1.71,
#    'receiverY': 92.45},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': -1.71,
#    'throwerY': 92.45,
#    'receiver': 'jmoore1',
#    'receiverX': -9.58,
#    'receiverY': 105.29},
#   {'type': 1,
#    'line': ['jlee',
#     'gnakano',
#     'sradlauer',
#     'slatarski',
#     'apetersch',
#     'isweeney',
#     'jmoore1'],
#    'time': 652},
#   {'type': 7,
#    'puller': 'sradlauer',
#    'pullX': -25.77,
#    'pullY': 72.32,
#    'pullMs': 4212},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'isweeney',
#     'bstout',
#     'cstillwel'],
#    'time': 697},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 18.92,
#    'throwerY': 26.25,
#    'receiver': 'efriedman',
#    'receiverX': 0.8,
#    'receiverY': 22.58},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 0.8,
#    'throwerY': 22.58,
#    'receiver': 'isweeney',
#    'receiverX': -16.55,
#    'receiverY': 29.67},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -16.55,
#    'throwerY': 29.67,
#    'receiver': 'cstillwel',
#    'receiverX': -22.74,
#    'receiverY': 59.29},
#   {'type': 17},
#   {'type': 18,
#    'thrower': 'cstillwel',
#    'throwerX': -22.74,
#    'throwerY': 69.28999999999999,
#    'receiver': 'rhayes',
#    'receiverX': -20.67,
#    'receiverY': 82.06},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': -20.67,
#    'throwerY': 82.06,
#    'receiver': 'bstout',
#    'receiverX': 4.22,
#    'receiverY': 108.25},
#   {'type': 28},
#   {'type': 1,
#    'line': ['sradlauer',
#     'slatarski',
#     'jmoore1',
#     'jlee',
#     'gnakano',
#     'apetersch',
#     'bstout'],
#    'time': 0},
#   {'type': 7,
#    'puller': 'sradlauer',
#    'pullX': -26.03,
#    'pullY': 70.19,
#    'pullMs': 19341},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'tdoi'],
#    'time': 45},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -9.19,
#    'throwerY': 14.9,
#    'receiver': 'sfraner',
#    'receiverX': -22.74,
#    'receiverY': 41.35},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -22.74,
#    'throwerY': 41.35,
#    'receiver': 'rhayes',
#    'receiverX': 17.96,
#    'receiverY': 82.12},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': 17.96,
#    'throwerY': 82.12,
#    'receiver': 'tdoi',
#    'receiverX': 12.93,
#    'receiverY': 119.22},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jlee',
#     'gnakano',
#     'apetersch',
#     'ceustis',
#     'llavoie',
#     'arueda'],
#    'time': 67},
#   {'type': 7, 'puller': 'llavoie', 'pullX': 0, 'pullY': 80, 'pullMs': 5412},
#   {'type': 13},
#   {'type': 17},
#   {'type': 22,
#    'thrower': 'apetersch',
#    'throwerX': 0.16,
#    'throwerY': 96.25,
#    'turnoverX': 4.54,
#    'turnoverY': 82.77},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'qbuermeye'],
#    'time': 186},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -0.3,
#    'throwerY': 9.48,
#    'receiver': 'efriedman',
#    'receiverX': 1.38,
#    'receiverY': 17.48},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 1.38,
#    'throwerY': 17.48,
#    'receiver': 'jsnyder',
#    'receiverX': -5.84,
#    'receiverY': 20},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -5.84,
#    'throwerY': 20,
#    'receiver': 'efriedman',
#    'receiverX': 2.67,
#    'receiverY': 20},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 2.67,
#    'throwerY': 20,
#    'receiver': 'qbuermeye',
#    'receiverX': 18.34,
#    'receiverY': 20},
#   {'type': 17},
#   {'type': 18,
#    'thrower': 'qbuermeye',
#    'throwerX': 18.34,
#    'throwerY': 30,
#    'receiver': 'jjohnson1',
#    'receiverX': -4.75,
#    'receiverY': 30.51},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -4.75,
#    'throwerY': 30.51,
#    'receiver': 'rhayes',
#    'receiverX': 7.96,
#    'receiverY': 40.7},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 7.96,
#    'throwerY': 40.7,
#    'receiver': 'jjohnson1',
#    'receiverX': -10.48,
#    'receiverY': 42},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -10.48,
#    'throwerY': 42,
#    'receiver': 'sfraner',
#    'receiverX': 1.7,
#    'receiverY': 45.54},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 1.7,
#    'throwerY': 45.54,
#    'receiver': 'rhayes',
#    'receiverX': 19.76,
#    'receiverY': 48.32},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 19.76,
#    'throwerY': 48.32,
#    'receiver': 'jsnyder',
#    'receiverX': 23.05,
#    'receiverY': 63.16},
#   {'type': 16},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 23.05,
#    'throwerY': 53.16,
#    'receiver': 'sfraner',
#    'receiverX': 7.83,
#    'receiverY': 39.35},
#   {'type': 22,
#    'thrower': 'sfraner',
#    'throwerX': 7.83,
#    'throwerY': 39.35,
#    'turnoverX': -3.26,
#    'turnoverY': 69.16},
#   {'type': 15},
#   {'type': 2,
#    'line': ['efriedman',
#     'rhayes',
#     'sfraner',
#     'qbuermeye',
#     'tdoi',
#     'cstillwel',
#     'isweeney'],
#    'time': 285},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -0.17,
#    'throwerY': 65.48,
#    'receiver': 'rhayes',
#    'receiverX': -18.67,
#    'receiverY': 79.41},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -18.67,
#    'throwerY': 79.41,
#    'receiver': 'isweeney',
#    'receiverX': -3,
#    'receiverY': 71.29},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -3,
#    'throwerY': 71.29,
#    'receiver': 'sfraner',
#    'receiverX': -18.42,
#    'receiverY': 75.16},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -18.42,
#    'throwerY': 75.16,
#    'receiver': 'isweeney',
#    'receiverX': -9.65,
#    'receiverY': 70.64},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -9.65,
#    'throwerY': 70.64,
#    'receiver': 'rhayes',
#    'receiverX': -16.61,
#    'receiverY': 79.74},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -16.61,
#    'throwerY': 79.74,
#    'receiver': 'efriedman',
#    'receiverX': 3.83,
#    'receiverY': 88.51},
#   {'type': 19,
#    'thrower': 'efriedman',
#    'throwerX': 3.83,
#    'throwerY': 88.51,
#    'receiver': 'tdoi',
#    'receiverX': 17.31,
#    'receiverY': 104.06},
#   {'type': 1,
#    'line': ['sradlauer',
#     'slatarski',
#     'jmoore1',
#     'apetersch',
#     'bstout',
#     'llavoie',
#     'arueda'],
#    'time': 347},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': -26.41,
#    'pullY': 71.8,
#    'pullMs': 17575},
#   {'type': 11, 'defender': 'sradlauer'},
#   {'type': 18,
#    'thrower': 'slatarski',
#    'throwerX': 15.38,
#    'throwerY': 69.16,
#    'receiver': 'apetersch',
#    'receiverX': 7.7,
#    'receiverY': 65.54},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': 7.7,
#    'throwerY': 65.54,
#    'receiver': 'sradlauer',
#    'receiverX': 15.25,
#    'receiverY': 75.67},
#   {'type': 22,
#    'thrower': 'sradlauer',
#    'throwerX': 15.25,
#    'throwerY': 75.67,
#    'turnoverX': -17.58,
#    'turnoverY': 89.67},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'qbuermeye',
#     'isweeney'],
#    'time': 402},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 0,
#    'throwerY': 40,
#    'receiver': 'rhayes',
#    'receiverX': -21.51,
#    'receiverY': 52.7},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -21.51,
#    'throwerY': 52.7,
#    'receiver': 'efriedman',
#    'receiverX': -11.13,
#    'receiverY': 45.22},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -11.13,
#    'throwerY': 45.22,
#    'receiver': 'jjohnson1',
#    'receiverX': 3.19,
#    'receiverY': 47.67},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 3.19,
#    'throwerY': 47.67,
#    'receiver': 'rhayes',
#    'receiverX': 11.44,
#    'receiverY': 54.25},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 11.44,
#    'throwerY': 54.25,
#    'receiver': 'jsnyder',
#    'receiverX': 0.16,
#    'receiverY': 45.67},
#   {'type': 22,
#    'thrower': 'jsnyder',
#    'throwerX': 0.16,
#    'throwerY': 45.67,
#    'turnoverX': -7.39,
#    'turnoverY': 109.61},
#   {'type': 13},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -0.23,
#    'throwerY': 29.8,
#    'receiver': 'isweeney',
#    'receiverX': -18.16,
#    'receiverY': 38.38},
#   {'type': 20,
#    'thrower': 'isweeney',
#    'throwerX': -18.16,
#    'throwerY': 38.38,
#    'receiver': 'efriedman',
#    'receiverX': 3.06,
#    'receiverY': 42.64},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'rhayes',
#     'sfraner',
#     'tdoi',
#     'cstillwel',
#     'llavoie',
#     'isweeney'],
#    'time': 550},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 16.6,
#    'throwerY': 66.64,
#    'receiver': 'tdoi',
#    'receiverX': 17.25,
#    'receiverY': 90},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 17.25,
#    'throwerY': 90,
#    'receiver': 'sfraner',
#    'receiverX': 19.18,
#    'receiverY': 79.16},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 19.18,
#    'throwerY': 79.16,
#    'receiver': 'llavoie',
#    'receiverX': -4.1,
#    'receiverY': 83.48},
#   {'type': 18,
#    'thrower': 'llavoie',
#    'throwerX': -4.1,
#    'throwerY': 83.48,
#    'receiver': 'sfraner',
#    'receiverX': 12.02,
#    'receiverY': 81.41},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 12.02,
#    'throwerY': 81.41,
#    'receiver': 'isweeney',
#    'receiverX': -5,
#    'receiverY': 82},
#   {'type': 22,
#    'thrower': 'isweeney',
#    'throwerX': -5,
#    'throwerY': 82,
#    'turnoverX': -21.45,
#    'turnoverY': 96.7},
#   {'type': 5,
#    'line': ['sradlauer',
#     'jmoore1',
#     'jlee',
#     'gnakano',
#     'bstout',
#     'apetersch',
#     'qbuermeye'],
#    'time': 610},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'tdoi',
#     'isweeney'],
#    'time': 642},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 10.99,
#    'throwerY': 4.19,
#    'receiver': 'jjohnson1',
#    'receiverX': -16.35,
#    'receiverY': 14.38},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -16.35,
#    'throwerY': 14.38,
#    'receiver': 'rhayes',
#    'receiverX': -19,
#    'receiverY': 27.67},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -19,
#    'throwerY': 27.67,
#    'receiver': 'efriedman',
#    'receiverX': -18.42,
#    'receiverY': 21.41},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -18.42,
#    'throwerY': 21.41,
#    'receiver': 'jjohnson1',
#    'receiverX': 10.22,
#    'receiverY': 16.64},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 10.22,
#    'throwerY': 16.64,
#    'receiver': 'jsnyder',
#    'receiverX': 19.25,
#    'receiverY': 18.51},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 19.25,
#    'throwerY': 18.51,
#    'receiver': 'sfraner',
#    'receiverX': -18.93,
#    'receiverY': 16.06},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -18.93,
#    'throwerY': 16.06,
#    'receiver': 'jjohnson1',
#    'receiverX': 2.99,
#    'receiverY': 14.51},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 2.99,
#    'throwerY': 14.51,
#    'receiver': 'isweeney',
#    'receiverX': 0.99,
#    'receiverY': 6},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 0.99,
#    'throwerY': 6,
#    'receiver': 'rhayes',
#    'receiverX': 13.44,
#    'receiverY': 13.48},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 13.44,
#    'throwerY': 13.48,
#    'receiver': 'tdoi',
#    'receiverX': 0.09,
#    'receiverY': 32.25},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 0.09,
#    'throwerY': 32.25,
#    'receiver': 'efriedman',
#    'receiverX': -17.77,
#    'receiverY': 45.41},
#   {'type': 19,
#    'thrower': 'efriedman',
#    'throwerX': -17.77,
#    'throwerY': 45.41,
#    'receiver': 'sfraner',
#    'receiverX': -11.97,
#    'receiverY': 113.16},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'rhayes',
#     'bstout',
#     'apetersch',
#     'ceustis',
#     'llavoie'],
#    'time': 697},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': -6.1,
#    'pullY': 115.61,
#    'pullMs': 6812},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'isweeney',
#     'bstout',
#     'cstillwel'],
#    'time': 717},
#   {'type': 22,
#    'thrower': 'isweeney',
#    'throwerX': -9.97,
#    'throwerY': 12.7,
#    'turnoverX': 2.8,
#    'turnoverY': 94.7},
#   {'type': 29},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'tdoi'],
#    'time': 0},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 11.44,
#    'throwerY': 3.54,
#    'receiver': 'efriedman',
#    'receiverX': -5.33,
#    'receiverY': 12.45},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -5.33,
#    'throwerY': 12.45,
#    'receiver': 'jsnyder',
#    'receiverX': 15.25,
#    'receiverY': 18},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 15.25,
#    'throwerY': 18,
#    'receiver': 'rhayes',
#    'receiverX': -0.88,
#    'receiverY': 29.74},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -0.88,
#    'throwerY': 29.74,
#    'receiver': 'tdoi',
#    'receiverX': -9.52,
#    'receiverY': 73.03},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': -9.52,
#    'throwerY': 73.03,
#    'receiver': 'efriedman',
#    'receiverX': -19.06,
#    'receiverY': 71.61},
#   {'type': 19,
#    'thrower': 'efriedman',
#    'throwerX': -19.06,
#    'throwerY': 71.61,
#    'receiver': 'rhayes',
#    'receiverX': -18.67,
#    'receiverY': 111.87},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'jlee',
#     'apetersch',
#     'bstout',
#     'llavoie',
#     'ceustis'],
#    'time': 33},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': 22.53,
#    'pullY': 109.8,
#    'pullMs': 6744},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'rhayes',
#     'sfraner',
#     'qbuermeye',
#     'tdoi',
#     'isweeney'],
#    'time': 59},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 0,
#    'throwerY': 40,
#    'receiver': 'rhayes',
#    'receiverX': -20.16,
#    'receiverY': 61.41},
#   {'type': 22,
#    'thrower': 'rhayes',
#    'throwerX': -20.16,
#    'throwerY': 61.41,
#    'turnoverX': -2.75,
#    'turnoverY': 113.29},
#   {'type': 17},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'sfraner',
#     'cstillwel',
#     'llavoie',
#     'tdoi'],
#    'time': 166},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -0.36,
#    'throwerY': 62.64,
#    'receiver': 'jsnyder',
#    'receiverX': -14.16,
#    'receiverY': 60.77},
#   {'type': 17},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -14.16,
#    'throwerY': 70.77000000000001,
#    'receiver': 'llavoie',
#    'receiverX': -2.36,
#    'receiverY': 100},
#   {'type': 17},
#   {'type': 18,
#    'thrower': 'llavoie',
#    'throwerX': 0,
#    'throwerY': 100,
#    'receiver': 'jsnyder',
#    'receiverX': -4.68,
#    'receiverY': 88.64},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -4.68,
#    'throwerY': 88.64,
#    'receiver': 'llavoie',
#    'receiverX': 17.63,
#    'receiverY': 84.9},
#   {'type': 18,
#    'thrower': 'llavoie',
#    'throwerX': 17.63,
#    'throwerY': 84.9,
#    'receiver': 'tdoi',
#    'receiverX': 0.35,
#    'receiverY': 89.8},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 0.35,
#    'throwerY': 89.8,
#    'receiver': 'sfraner',
#    'receiverX': 6.15,
#    'receiverY': 84.77},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 6.15,
#    'throwerY': 84.77,
#    'receiver': 'tdoi',
#    'receiverX': 21.76,
#    'receiverY': 89.09},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 21.76,
#    'throwerY': 89.09,
#    'receiver': 'sfraner',
#    'receiverX': 21.82,
#    'receiverY': 84.7},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 21.82,
#    'throwerY': 84.7,
#    'receiver': 'llavoie',
#    'receiverX': 0.54,
#    'receiverY': 90.32},
#   {'type': 19,
#    'thrower': 'llavoie',
#    'throwerX': 0.54,
#    'throwerY': 90.32,
#    'receiver': 'efriedman',
#    'receiverX': 25.24,
#    'receiverY': 113.93},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'jlee',
#     'gnakano',
#     'apetersch',
#     'arueda',
#     'bstout'],
#    'time': 259},
#   {'type': 7,
#    'puller': 'sradlauer',
#    'pullX': -25.19,
#    'pullY': 80.58,
#    'pullMs': 11693},
#   {'type': 25,
#    'line': ['sradlauer',
#     'jmoore1',
#     'jlee',
#     'gnakano',
#     'apetersch',
#     'arueda',
#     'bstout'],
#    'time': 291},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'qbuermeye',
#     'tdoi',
#     'isweeney'],
#    'time': 295},
#   {'type': 22,
#    'thrower': 'efriedman',
#    'throwerX': 0.8,
#    'throwerY': 1.22,
#    'turnoverX': -26.03,
#    'turnoverY': 31.48},
#   {'type': 13},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -17.9,
#    'throwerY': 19.8,
#    'receiver': 'efriedman',
#    'receiverX': -21.32,
#    'receiverY': 37.87},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -21.32,
#    'throwerY': 37.87,
#    'receiver': 'rhayes',
#    'receiverX': -10.81,
#    'receiverY': 50.51},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -10.81,
#    'throwerY': 50.51,
#    'receiver': 'efriedman',
#    'receiverX': -19.32,
#    'receiverY': 48.45},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -19.32,
#    'throwerY': 48.45,
#    'receiver': 'tdoi',
#    'receiverX': 9.12,
#    'receiverY': 92.7},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 9.12,
#    'throwerY': 92.7,
#    'receiver': 'jsnyder',
#    'receiverX': 1.83,
#    'receiverY': 80.83},
#   {'type': 19,
#    'thrower': 'jsnyder',
#    'throwerX': 1.83,
#    'throwerY': 80.83,
#    'receiver': 'tdoi',
#    'receiverX': -24.41,
#    'receiverY': 105.61},
#   {'type': 1,
#    'line': ['sradlauer',
#     'slatarski',
#     'jmoore1',
#     'gnakano',
#     'apetersch',
#     'llavoie',
#     'arueda'],
#    'time': 353},
#   {'type': 7,
#    'puller': 'slatarski',
#    'pullX': 6.73,
#    'pullY': 92.77,
#    'pullMs': 7543},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'cstillwel'],
#    'time': 394},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -9.39,
#    'throwerY': 7.61,
#    'receiver': 'jsnyder',
#    'receiverX': 0.54,
#    'receiverY': 14.38},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 0.54,
#    'throwerY': 14.38,
#    'receiver': 'rhayes',
#    'receiverX': 10.15,
#    'receiverY': 22.06},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 10.15,
#    'throwerY': 22.06,
#    'receiver': 'sfraner',
#    'receiverX': 3.83,
#    'receiverY': 30.96},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 3.83,
#    'throwerY': 30.96,
#    'receiver': 'jjohnson1',
#    'receiverX': -17.71,
#    'receiverY': 32.51},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -17.71,
#    'throwerY': 32.51,
#    'receiver': 'jsnyder',
#    'receiverX': -19.06,
#    'receiverY': 52.32},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -19.06,
#    'throwerY': 52.32,
#    'receiver': 'isweeney',
#    'receiverX': -11.19,
#    'receiverY': 63.03},
#   {'type': 22,
#    'thrower': 'isweeney',
#    'throwerX': -11.19,
#    'throwerY': 63.03,
#    'turnoverX': -18.35,
#    'turnoverY': 110.9},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'rhayes',
#     'qbuermeye',
#     'llavoie',
#     'tdoi',
#     'isweeney'],
#    'time': 471},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -22.67,
#    'throwerY': 10.12,
#    'receiver': 'efriedman',
#    'receiverX': -13.39,
#    'receiverY': 24.38},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -13.39,
#    'throwerY': 24.38,
#    'receiver': 'qbuermeye',
#    'receiverX': -9.9,
#    'receiverY': 91.48},
#   {'type': 22,
#    'thrower': 'qbuermeye',
#    'throwerX': -9.9,
#    'throwerY': 91.48,
#    'turnoverX': -4.29,
#    'turnoverY': 85.61},
#   {'type': 11, 'defender': 'rhayes'},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': -24.67,
#    'throwerY': 63.09,
#    'receiver': 'jjohnson1',
#    'receiverX': -23.51,
#    'receiverY': 45.48},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -23.51,
#    'throwerY': 45.48,
#    'receiver': 'isweeney',
#    'receiverX': -9.58,
#    'receiverY': 49.22},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -9.58,
#    'throwerY': 49.22,
#    'receiver': 'tdoi',
#    'receiverX': 8.86,
#    'receiverY': 56.45},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 8.86,
#    'throwerY': 56.45,
#    'receiver': 'isweeney',
#    'receiverX': -7,
#    'receiverY': 54.7},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -7,
#    'throwerY': 54.7,
#    'receiver': 'rhayes',
#    'receiverX': 14.86,
#    'receiverY': 60.77},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 14.86,
#    'throwerY': 60.77,
#    'receiver': 'qbuermeye',
#    'receiverX': 24.47,
#    'receiverY': 76.06},
#   {'type': 18,
#    'thrower': 'qbuermeye',
#    'throwerX': 24.47,
#    'throwerY': 76.06,
#    'receiver': 'rhayes',
#    'receiverX': 4.74,
#    'receiverY': 74.51},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': 4.74,
#    'throwerY': 74.51,
#    'receiver': 'qbuermeye',
#    'receiverX': 25.18,
#    'receiverY': 111.61},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'jlee',
#     'gnakano',
#     'apetersch',
#     'bstout',
#     'ceustis'],
#    'time': 545},
#   {'type': 8, 'puller': 'jmoore1'},
#   {'type': 11, 'defender': 'gnakano'},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': -4.55,
#    'throwerY': 69.74,
#    'receiver': 'jlee',
#    'receiverX': 13.51,
#    'receiverY': 77.09},
#   {'type': 18,
#    'thrower': 'jlee',
#    'throwerX': 13.51,
#    'throwerY': 77.09,
#    'receiver': 'bstout',
#    'receiverX': 24.53,
#    'receiverY': 87.16},
#   {'type': 18,
#    'thrower': 'bstout',
#    'throwerX': 24.53,
#    'throwerY': 87.16,
#    'receiver': 'jmoore1',
#    'receiverX': -6.55,
#    'receiverY': 80.32},
#   {'type': 18,
#    'thrower': 'jmoore1',
#    'throwerX': -6.55,
#    'throwerY': 80.32,
#    'receiver': 'apetersch',
#    'receiverX': -25.7,
#    'receiverY': 91.67},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': -25.7,
#    'throwerY': 91.67,
#    'receiver': 'ceustis',
#    'receiverX': -11.26,
#    'receiverY': 97.41},
#   {'type': 19,
#    'thrower': 'ceustis',
#    'throwerX': -11.26,
#    'throwerY': 97.41,
#    'receiver': 'sradlauer',
#    'receiverX': -3.71,
#    'receiverY': 104.77},
#   {'type': 1,
#    'line': ['slatarski',
#     'jmoore1',
#     'gnakano',
#     'apetersch',
#     'ceustis',
#     'arueda',
#     'llavoie'],
#    'time': 618},
#   {'type': 7, 'puller': 'llavoie', 'pullX': 0.87, 'pullY': 116.7, 'pullMs': 0},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'tdoi'],
#    'time': 651},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -20.29,
#    'throwerY': 22.96,
#    'receiver': 'sfraner',
#    'receiverX': -12.23,
#    'receiverY': 29.41},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': -12.23,
#    'throwerY': 29.41,
#    'receiver': 'jjohnson1',
#    'receiverX': 5.9,
#    'receiverY': 27.41},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 5.9,
#    'throwerY': 27.41,
#    'receiver': 'tdoi',
#    'receiverX': 11.89,
#    'receiverY': 40.19},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 11.89,
#    'throwerY': 40.19,
#    'receiver': 'rhayes',
#    'receiverX': 6.15,
#    'receiverY': 52.7},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 6.15,
#    'throwerY': 52.7,
#    'receiver': 'sfraner',
#    'receiverX': 14.54,
#    'receiverY': 63.67},
#   {'type': 18,
#    'thrower': 'sfraner',
#    'throwerX': 14.54,
#    'throwerY': 63.67,
#    'receiver': 'jjohnson1',
#    'receiverX': 19.89,
#    'receiverY': 98.96},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 19.89,
#    'throwerY': 98.96,
#    'receiver': 'efriedman',
#    'receiverX': 15.5,
#    'receiverY': 98.32},
#   {'type': 3,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'qbuermeye'],
#    'time': 698},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 15.5,
#    'throwerY': 98.32,
#    'receiver': 'rhayes',
#    'receiverX': 16.79,
#    'receiverY': 89.8},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 16.79,
#    'throwerY': 89.8,
#    'receiver': 'isweeney',
#    'receiverX': 24.66,
#    'receiverY': 92.77},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 24.66,
#    'throwerY': 92.77,
#    'receiver': 'rhayes',
#    'receiverX': 6.41,
#    'receiverY': 85.22},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': 6.41,
#    'throwerY': 85.22,
#    'receiver': 'jjohnson1',
#    'receiverX': 23.18,
#    'receiverY': 110.25},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'rhayes',
#     'bstout',
#     'apetersch',
#     'cstillwel',
#     'llavoie'],
#    'time': 712},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': -0.88,
#    'pullY': 116.12,
#    'pullMs': 7877},
#   {'type': 30},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jlee',
#     'gnakano',
#     'apetersch',
#     'llavoie',
#     'arueda',
#     'ceustis'],
#    'time': 0},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': -26.22,
#    'pullY': 67.8,
#    'pullMs': 16025},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'qbuermeye'],
#    'time': 45},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 12.02,
#    'throwerY': 20,
#    'receiver': 'jsnyder',
#    'receiverX': -2.87,
#    'receiverY': 23.16},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': -2.87,
#    'throwerY': 23.16,
#    'receiver': 'isweeney',
#    'receiverX': -17.77,
#    'receiverY': 30.38},
#   {'type': 22,
#    'thrower': 'isweeney',
#    'throwerX': -17.77,
#    'throwerY': 30.38,
#    'turnoverX': -17,
#    'turnoverY': 100.58},
#   {'type': 11, 'defender': 'efriedman'},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 14.99,
#    'throwerY': 74.77,
#    'receiver': 'jsnyder',
#    'receiverX': 4.28,
#    'receiverY': 84.64},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 4.28,
#    'throwerY': 84.64,
#    'receiver': 'efriedman',
#    'receiverX': -5.45,
#    'receiverY': 76.51},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -5.45,
#    'throwerY': 76.51,
#    'receiver': 'jsnyder',
#    'receiverX': 12.28,
#    'receiverY': 69.61},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 12.28,
#    'throwerY': 69.61,
#    'receiver': 'sfraner',
#    'receiverX': 13.96,
#    'receiverY': 85.67},
#   {'type': 25,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'isweeney',
#     'qbuermeye',
#     'tdoi'],
#    'time': 121},
#   {'type': 19,
#    'thrower': 'efriedman',
#    'throwerX': 0.41,
#    'throwerY': 98.32,
#    'receiver': 'tdoi',
#    'receiverX': -4.04,
#    'receiverY': 102},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'gnakano',
#     'apetersch',
#     'llavoie',
#     'bstout',
#     'arueda'],
#    'time': 126},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': -23.51,
#    'pullY': 78.58,
#    'pullMs': 18591},
#   {'type': 11, 'defender': 'sradlauer'},
#   {'type': 18,
#    'thrower': 'gnakano',
#    'throwerX': 11.44,
#    'throwerY': 83.74,
#    'receiver': 'arueda',
#    'receiverX': 12.22,
#    'receiverY': 76.83},
#   {'type': 18,
#    'thrower': 'arueda',
#    'throwerX': 12.22,
#    'throwerY': 76.83,
#    'receiver': 'llavoie',
#    'receiverX': -3.52,
#    'receiverY': 74.51},
#   {'type': 18,
#    'thrower': 'llavoie',
#    'throwerX': -3.52,
#    'throwerY': 74.51,
#    'receiver': 'arueda',
#    'receiverX': 12.73,
#    'receiverY': 68.9},
#   {'type': 18,
#    'thrower': 'arueda',
#    'throwerX': 12.73,
#    'throwerY': 68.9,
#    'receiver': 'apetersch',
#    'receiverX': 24.15,
#    'receiverY': 78.7},
#   {'type': 18,
#    'thrower': 'apetersch',
#    'throwerX': 24.15,
#    'throwerY': 78.7,
#    'receiver': 'sradlauer',
#    'receiverX': 9.25,
#    'receiverY': 93.41},
#   {'type': 17},
#   {'type': 17},
#   {'type': 18,
#    'thrower': 'sradlauer',
#    'throwerX': 0,
#    'throwerY': 100,
#    'receiver': 'arueda',
#    'receiverX': -1.2,
#    'receiverY': 90.9},
#   {'type': 18,
#    'thrower': 'arueda',
#    'throwerX': -1.2,
#    'throwerY': 90.9,
#    'receiver': 'sradlauer',
#    'receiverX': -8.03,
#    'receiverY': 97.03},
#   {'type': 18,
#    'thrower': 'sradlauer',
#    'throwerX': -8.03,
#    'throwerY': 97.03,
#    'receiver': 'arueda',
#    'receiverX': 2.8,
#    'receiverY': 90.77},
#   {'type': 18,
#    'thrower': 'arueda',
#    'throwerX': 2.8,
#    'throwerY': 90.77,
#    'receiver': 'jmoore1',
#    'receiverX': -9.39,
#    'receiverY': 90.06},
#   {'type': 18,
#    'thrower': 'jmoore1',
#    'throwerX': -9.39,
#    'throwerY': 90.06,
#    'receiver': 'arueda',
#    'receiverX': -11,
#    'receiverY': 97.54},
#   {'type': 19,
#    'thrower': 'arueda',
#    'throwerX': -11,
#    'throwerY': 97.54,
#    'receiver': 'gnakano',
#    'receiverX': -12.1,
#    'receiverY': 103.87},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'ceustis',
#     'llavoie',
#     'jlee',
#     'apetersch',
#     'qbuermeye'],
#    'time': 170},
#   {'type': 7,
#    'puller': 'jmoore1',
#    'pullX': -25.32,
#    'pullY': 75.93,
#    'pullMs': 11413},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'sfraner',
#     'isweeney',
#     'tdoi'],
#    'time': 221},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 3.64,
#    'throwerY': 13.67,
#    'receiver': 'isweeney',
#    'receiverX': 1.12,
#    'receiverY': 25.54},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 1.12,
#    'throwerY': 25.54,
#    'receiver': 'jjohnson1',
#    'receiverX': 20.54,
#    'receiverY': 28.12},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 20.54,
#    'throwerY': 28.12,
#    'receiver': 'rhayes',
#    'receiverX': 4.28,
#    'receiverY': 36.12},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 4.28,
#    'throwerY': 36.12,
#    'receiver': 'isweeney',
#    'receiverX': 8.09,
#    'receiverY': 28.96},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 8.09,
#    'throwerY': 28.96,
#    'receiver': 'efriedman',
#    'receiverX': -19.06,
#    'receiverY': 39.74},
#   {'type': 17},
#   {'type': 16},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -19.06,
#    'throwerY': 39.74,
#    'receiver': 'isweeney',
#    'receiverX': -24.22,
#    'receiverY': 60.32},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': -24.22,
#    'throwerY': 60.32,
#    'receiver': 'jjohnson1',
#    'receiverX': 17.25,
#    'receiverY': 62.25},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': 17.25,
#    'throwerY': 62.25,
#    'receiver': 'rhayes',
#    'receiverX': 7.12,
#    'receiverY': 79.48},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 7.12,
#    'throwerY': 79.48,
#    'receiver': 'tdoi',
#    'receiverX': 18.15,
#    'receiverY': 92.19},
#   {'type': 18,
#    'thrower': 'tdoi',
#    'throwerX': 18.15,
#    'throwerY': 92.19,
#    'receiver': 'isweeney',
#    'receiverX': 0.8,
#    'receiverY': 82.19},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 0.8,
#    'throwerY': 82.19,
#    'receiver': 'rhayes',
#    'receiverX': 17.96,
#    'receiverY': 91.67},
#   {'type': 19,
#    'thrower': 'rhayes',
#    'throwerX': 17.96,
#    'throwerY': 91.67,
#    'receiver': 'jjohnson1',
#    'receiverX': 24.79,
#    'receiverY': 114.19},
#   {'type': 1,
#    'line': ['sradlauer',
#     'jmoore1',
#     'jlee',
#     'apetersch',
#     'llavoie',
#     'arueda',
#     'ceustis'],
#    'time': 299},
#   {'type': 7,
#    'puller': 'llavoie',
#    'pullX': 10.15,
#    'pullY': 112.25,
#    'pullMs': 7662},
#   {'type': 16},
#   {'type': 11, 'defender': 'llavoie'},
#   {'type': 18,
#    'thrower': 'llavoie',
#    'throwerX': -8.1,
#    'throwerY': 43.03,
#    'receiver': 'jlee',
#    'receiverX': 11.31,
#    'receiverY': 50},
#   {'type': 22,
#    'thrower': 'jlee',
#    'throwerX': 11.31,
#    'throwerY': 50,
#    'turnoverX': 12.34,
#    'turnoverY': 82.06},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'isweeney',
#     'cstillwel',
#     'tdoi'],
#    'time': 377},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 10.22,
#    'throwerY': 17.93,
#    'receiver': 'efriedman',
#    'receiverX': 0.03,
#    'receiverY': 32.64},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': 0.03,
#    'throwerY': 32.64,
#    'receiver': 'rhayes',
#    'receiverX': 3.64,
#    'receiverY': 48.38},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 3.64,
#    'throwerY': 48.38,
#    'receiver': 'isweeney',
#    'receiverX': 25.5,
#    'receiverY': 96.83},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 25.5,
#    'throwerY': 96.83,
#    'receiver': 'jsnyder',
#    'receiverX': 23.24,
#    'receiverY': 79.61},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 23.24,
#    'throwerY': 79.61,
#    'receiver': 'efriedman',
#    'receiverX': -11.77,
#    'receiverY': 75.16},
#   {'type': 18,
#    'thrower': 'efriedman',
#    'throwerX': -11.77,
#    'throwerY': 75.16,
#    'receiver': 'isweeney',
#    'receiverX': -5.84,
#    'receiverY': 89.09},
#   {'type': 19,
#    'thrower': 'isweeney',
#    'throwerX': -5.84,
#    'throwerY': 89.09,
#    'receiver': 'jjohnson1',
#    'receiverX': 18.47,
#    'receiverY': 110.58},
#   {'type': 1,
#    'line': ['bstout',
#     'jmoore1',
#     'arueda',
#     'ceustis',
#     'gnakano',
#     'slatarski',
#     'sradlauer'],
#    'time': 413},
#   {'type': 7,
#    'puller': 'slatarski',
#    'pullX': 11.89,
#    'pullY': 106,
#    'pullMs': 0},
#   {'type': 16},
#   {'type': 15},
#   {'type': 2,
#    'line': ['jjohnson1',
#     'efriedman',
#     'jsnyder',
#     'rhayes',
#     'isweeney',
#     'qbuermeye',
#     'tdoi'],
#    'time': 478},
#   {'type': 18,
#    'thrower': 'jjohnson1',
#    'throwerX': -7.52,
#    'throwerY': 6.12,
#    'receiver': 'jsnyder',
#    'receiverX': 7.38,
#    'receiverY': 14.25},
#   {'type': 18,
#    'thrower': 'jsnyder',
#    'throwerX': 7.38,
#    'throwerY': 14.25,
#    'receiver': 'rhayes',
#    'receiverX': 19.89,
#    'receiverY': 21.74},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 19.89,
#    'throwerY': 21.74,
#    'receiver': 'qbuermeye',
#    'receiverX': 18.86,
#    'receiverY': 40.12},
#   {'type': 18,
#    'thrower': 'qbuermeye',
#    'throwerX': 18.86,
#    'throwerY': 40.12,
#    'receiver': 'rhayes',
#    'receiverX': 13.57,
#    'receiverY': 30.19},
#   {'type': 18,
#    'thrower': 'rhayes',
#    'throwerX': 13.57,
#    'throwerY': 30.19,
#    'receiver': 'isweeney',
#    'receiverX': 0.87,
#    'receiverY': 30.32},
#   {'type': 18,
#    'thrower': 'isweeney',
#    'throwerX': 0.87,
#    'throwerY': 30.32,
# ...
#    'thrower': 'clung',
#    'throwerX': 9.47,
#    'throwerY': 59.86,
#    'receiver': 'wfrankenb',
#    'receiverX': 22.5,
#    'receiverY': 66.75},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': 22.5,
#    'throwerY': 66.75,
#    'receiver': 'klaurence',
#    'receiverX': 23.52,
#    'receiverY': 91.36},
#   {'type': 19,
#    'thrower': 'klaurence',
#    'throwerX': 23.52,
#    'throwerY': 91.36,
#    'receiver': 'mhecht',
#    'receiverX': 7.36,
#    'receiverY': 105.2},
#   {'type': 1,
#    'line': ['gmay',
#     'rcastro',
#     'mcrawford',
#     'kkhangaon',
#     'msommer',
#     'mkissmann',
#     'wberreman'],
#    'time': 45},
#   {'type': 7, 'puller': 'unknown', 'pullX': -25.17, 'pullY': 100, 'pullMs': 0},
#   {'type': 11, 'defender': 'mcrawford'},
#   {'type': 18,
#    'thrower': 'mcrawford',
#    'throwerX': -9.83,
#    'throwerY': 21,
#    'receiver': 'mkissmann',
#    'receiverX': 7.29,
#    'receiverY': 21.47},
#   {'type': 18,
#    'thrower': 'mkissmann',
#    'throwerX': 7.29,
#    'throwerY': 21.47,
#    'receiver': 'wberreman',
#    'receiverX': 0.06,
#    'receiverY': 26.59},
#   {'type': 18,
#    'thrower': 'wberreman',
#    'throwerX': 0.06,
#    'throwerY': 26.59,
#    'receiver': 'gmay',
#    'receiverX': -18.28,
#    'receiverY': 31.22},
#   {'type': 18,
#    'thrower': 'gmay',
#    'throwerX': -18.28,
#    'throwerY': 31.22,
#    'receiver': 'mcrawford',
#    'receiverX': 3.81,
#    'receiverY': 30.81},
#   {'type': 18,
#    'thrower': 'mcrawford',
#    'throwerX': 3.81,
#    'throwerY': 30.81,
#    'receiver': 'gmay',
#    'receiverX': -2.05,
#    'receiverY': 28.77},
#   {'type': 22,
#    'thrower': 'gmay',
#    'throwerX': -2.05,
#    'throwerY': 28.77,
#    'turnoverX': 16.3,
#    'turnoverY': 37.15},
#   {'type': 16},
#   {'type': 25,
#    'line': ['gmay',
#     'mcrawford',
#     'kkhangaon',
#     'msommer',
#     'mkissmann',
#     'wberreman',
#     'rmendoza'],
#    'time': 121},
#   {'type': 15},
#   {'type': 2,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 126},
#   {'type': 20,
#    'thrower': 'mhecht',
#    'throwerX': 25.98,
#    'throwerY': 53.72,
#    'receiver': 'dclyburn',
#    'receiverX': 1.09,
#    'receiverY': 50.59},
#   {'type': 15},
#   {'type': 2,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 170},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': -26.67,
#    'throwerY': 41.59,
#    'receiver': 'wfrankenb',
#    'receiverX': -19.31,
#    'receiverY': 32.45},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': -19.31,
#    'throwerY': 32.45,
#    'receiver': 'emagsig',
#    'receiverX': 0.54,
#    'receiverY': 30.95},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': 0.54,
#    'throwerY': 30.95,
#    'receiver': 'wfrankenb',
#    'receiverX': -21.62,
#    'receiverY': 39.88},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': -21.62,
#    'throwerY': 39.88,
#    'receiver': 'emagsig',
#    'receiverX': -22.85,
#    'receiverY': 45.95},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': -22.85,
#    'throwerY': 45.95,
#    'receiver': 'mhecht',
#    'receiverX': 0.47,
#    'receiverY': 43.77},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 0.47,
#    'throwerY': 43.77,
#    'receiver': 'mwilliams',
#    'receiverX': 16.84,
#    'receiverY': 49.77},
#   {'type': 18,
#    'thrower': 'mwilliams',
#    'throwerX': 16.84,
#    'throwerY': 49.77,
#    'receiver': 'mhecht',
#    'receiverX': 23.05,
#    'receiverY': 48.61},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 23.05,
#    'throwerY': 48.61,
#    'receiver': 'klaurence',
#    'receiverX': 2.38,
#    'receiverY': 56.86},
#   {'type': 18,
#    'thrower': 'klaurence',
#    'throwerX': 2.38,
#    'throwerY': 56.86,
#    'receiver': 'mwilliams',
#    'receiverX': -19.1,
#    'receiverY': 56.79},
#   {'type': 18,
#    'thrower': 'mwilliams',
#    'throwerX': -19.1,
#    'throwerY': 56.79,
#    'receiver': 'klaurence',
#    'receiverX': -22.78,
#    'receiverY': 61.36},
#   {'type': 18,
#    'thrower': 'klaurence',
#    'throwerX': -22.78,
#    'throwerY': 61.36,
#    'receiver': 'wfrankenb',
#    'receiverX': -23.13,
#    'receiverY': 68.79},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': -23.13,
#    'throwerY': 68.79,
#    'receiver': 'dclyburn',
#    'receiverX': -20.87,
#    'receiverY': 74.04},
#   {'type': 18,
#    'thrower': 'dclyburn',
#    'throwerX': -20.87,
#    'throwerY': 74.04,
#    'receiver': 'mhecht',
#    'receiverX': -24.63,
#    'receiverY': 86.38},
#   {'type': 19,
#    'thrower': 'mhecht',
#    'throwerX': -24.63,
#    'throwerY': 86.38,
#    'receiver': 'clung',
#    'receiverX': -23.4,
#    'receiverY': 108.2},
#   {'type': 1,
#    'line': ['rvickersb',
#     'pxu',
#     'jdecampos',
#     'mburke1',
#     'cbauman',
#     'rmendoza',
#     'wberreman'],
#    'time': 221},
#   {'type': 7,
#    'puller': 'cbauman',
#    'pullX': -2.05,
#    'pullY': 110.59,
#    'pullMs': 0},
#   {'type': 16},
#   {'type': 17},
#   {'type': 15},
#   {'type': 2,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 289},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': -22.37,
#    'throwerY': 18.06,
#    'receiver': 'clung',
#    'receiverX': 2.59,
#    'receiverY': 23.59},
#   {'type': 17},
#   {'type': 18,
#    'thrower': 'clung',
#    'throwerX': 2.59,
#    'throwerY': 33.59,
#    'receiver': 'wfrankenb',
#    'receiverX': 19.5,
#    'receiverY': 34.84},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': 19.5,
#    'throwerY': 34.84,
#    'receiver': 'clung',
#    'receiverX': 11.18,
#    'receiverY': 37.77},
#   {'type': 22,
#    'thrower': 'clung',
#    'throwerX': 11.18,
#    'throwerY': 37.77,
#    'turnoverX': -21.9,
#    'turnoverY': 75.68},
#   {'type': 11, 'defender': 'klaurence'},
#   {'type': 18,
#    'thrower': 'dclyburn',
#    'throwerX': 0,
#    'throwerY': 40,
#    'receiver': 'wfrankenb',
#    'receiverX': -17.87,
#    'receiverY': 52.36},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': -17.87,
#    'throwerY': 52.36,
#    'receiver': 'klaurence',
#    'receiverX': -14.74,
#    'receiverY': 58.63},
#   {'type': 18,
#    'thrower': 'klaurence',
#    'throwerX': -14.74,
#    'throwerY': 58.63,
#    'receiver': 'wfrankenb',
#    'receiverX': -21.35,
#    'receiverY': 71.31},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': -21.35,
#    'throwerY': 71.31,
#    'receiver': 'klaurence',
#    'receiverX': 1.22,
#    'receiverY': 64.9},
#   {'type': 18,
#    'thrower': 'klaurence',
#    'throwerX': 1.22,
#    'throwerY': 64.9,
#    'receiver': 'dclyburn',
#    'receiverX': 18.89,
#    'receiverY': 80.31},
#   {'type': 18,
#    'thrower': 'dclyburn',
#    'throwerX': 18.89,
#    'throwerY': 80.31,
#    'receiver': 'mwilliams',
#    'receiverX': 23.46,
#    'receiverY': 89.52},
#   {'type': 18,
#    'thrower': 'mwilliams',
#    'throwerX': 23.46,
#    'throwerY': 89.52,
#    'receiver': 'mhecht',
#    'receiverX': 22.77,
#    'receiverY': 81.27},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 22.77,
#    'throwerY': 81.27,
#    'receiver': 'emagsig',
#    'receiverX': -1.51,
#    'receiverY': 79.22},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': -1.51,
#    'throwerY': 79.22,
#    'receiver': 'mhecht',
#    'receiverX': -14.33,
#    'receiverY': 84.27},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': -14.33,
#    'throwerY': 84.27,
#    'receiver': 'emagsig',
#    'receiverX': -0.21,
#    'receiverY': 79.29},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': -0.21,
#    'throwerY': 79.29,
#    'receiver': 'mhecht',
#    'receiverX': 12,
#    'receiverY': 81},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 12,
#    'throwerY': 81,
#    'receiver': 'emagsig',
#    'receiverX': 0.75,
#    'receiverY': 81.68},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': 0.75,
#    'throwerY': 81.68,
#    'receiver': 'dclyburn',
#    'receiverX': -21.56,
#    'receiverY': 90.13},
#   {'type': 19,
#    'thrower': 'dclyburn',
#    'throwerX': -21.56,
#    'throwerY': 90.13,
#    'receiver': 'emagsig',
#    'receiverX': -18.01,
#    'receiverY': 109.97},
#   {'type': 1,
#    'line': ['gmay',
#     'rcastro',
#     'mcrawford',
#     'kkhangaon',
#     'msommer',
#     'mkissmann',
#     'mburke1'],
#    'time': 377},
#   {'type': 7,
#    'puller': 'mkissmann',
#    'pullX': 2.25,
#    'pullY': 107.38,
#    'pullMs': 6913},
#   {'type': 15},
#   {'type': 2,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 413},
#   {'type': 18,
#    'thrower': 'dclyburn',
#    'throwerX': -6.14,
#    'throwerY': 11.52,
#    'receiver': 'wfrankenb',
#    'receiverX': 2.52,
#    'receiverY': 19.9},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': 2.52,
#    'throwerY': 19.9,
#    'receiver': 'clung',
#    'receiverX': 19.16,
#    'receiverY': 28.43},
#   {'type': 18,
#    'thrower': 'clung',
#    'throwerX': 19.16,
#    'throwerY': 28.43,
#    'receiver': 'wfrankenb',
#    'receiverX': 23.32,
#    'receiverY': 35.04},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': 23.32,
#    'throwerY': 35.04,
#    'receiver': 'clung',
#    'receiverX': 23.93,
#    'receiverY': 40.15},
#   {'type': 18,
#    'thrower': 'clung',
#    'throwerX': 23.93,
#    'throwerY': 40.15,
#    'receiver': 'dclyburn',
#    'receiverX': 24.68,
#    'receiverY': 49.36},
#   {'type': 18,
#    'thrower': 'dclyburn',
#    'throwerX': 24.68,
#    'throwerY': 49.36,
#    'receiver': 'clung',
#    'receiverX': 15.48,
#    'receiverY': 53.86},
#   {'type': 18,
#    'thrower': 'clung',
#    'throwerX': 15.48,
#    'throwerY': 53.86,
#    'receiver': 'dclyburn',
#    'receiverX': 20.8,
#    'receiverY': 64.56},
#   {'type': 18,
#    'thrower': 'dclyburn',
#    'throwerX': 20.8,
#    'throwerY': 64.56,
#    'receiver': 'clung',
#    'receiverX': 17.59,
#    'receiverY': 74.11},
#   {'type': 18,
#    'thrower': 'clung',
#    'throwerX': 17.59,
#    'throwerY': 74.11,
#    'receiver': 'mhecht',
#    'receiverX': 3.27,
#    'receiverY': 82.77},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 3.27,
#    'throwerY': 82.77,
#    'receiver': 'emagsig',
#    'receiverX': 21.96,
#    'receiverY': 91.15},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': 21.96,
#    'throwerY': 91.15,
#    'receiver': 'mhecht',
#    'receiverX': 24.48,
#    'receiverY': 94.7},
#   {'type': 17},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 24.48,
#    'throwerY': 100,
#    'receiver': 'wfrankenb',
#    'receiverX': 19.98,
#    'receiverY': 98.11},
#   {'type': 19,
#    'thrower': 'wfrankenb',
#    'throwerX': 19.98,
#    'throwerY': 98.11,
#    'receiver': 'dclyburn',
#    'receiverX': 7.36,
#    'receiverY': 104.72},
#   {'type': 1,
#    'line': ['rvickersb',
#     'pxu',
#     'jdecampos',
#     'mburke1',
#     'cbauman',
#     'rmendoza',
#     'wberreman'],
#    'time': 478},
#   {'type': 7,
#    'puller': 'cbauman',
#    'pullX': 0.13,
#    'pullY': 106.09,
#    'pullMs': 3832},
#   {'type': 15},
#   {'type': 2,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 507},
#   {'type': 18,
#    'thrower': 'clung',
#    'throwerX': 0,
#    'throwerY': 40,
#    'receiver': 'emagsig',
#    'receiverX': -3.35,
#    'receiverY': 38.86},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': -3.35,
#    'throwerY': 38.86,
#    'receiver': 'klaurence',
#    'receiverX': -16.71,
#    'receiverY': 43.09},
#   {'type': 18,
#    'thrower': 'klaurence',
#    'throwerX': -16.71,
#    'throwerY': 43.09,
#    'receiver': 'mhecht',
#    'receiverX': -17.26,
#    'receiverY': 57.54},
#   {'type': 22,
#    'thrower': 'mhecht',
#    'throwerX': -17.26,
#    'throwerY': 57.54,
#    'turnoverX': -14.8,
#    'turnoverY': 63.75},
#   {'type': 15},
#   {'type': 2,
#    'line': ['gmay',
#     'rcastro',
#     'mcrawford',
#     'kkhangaon',
#     'msommer',
#     'mkissmann',
#     'mhecht'],
#    'time': 545},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 26.66,
#    'throwerY': 49.22,
#    'receiver': 'kkhangaon',
#    'receiverX': 19.84,
#    'receiverY': 63.88},
#   {'type': 18,
#    'thrower': 'kkhangaon',
#    'throwerX': 19.84,
#    'throwerY': 63.88,
#    'receiver': 'mcrawford',
#    'receiverX': 1.09,
#    'receiverY': 56.38},
#   {'type': 18,
#    'thrower': 'mcrawford',
#    'throwerX': 1.09,
#    'throwerY': 56.38,
#    'receiver': 'mhecht',
#    'receiverX': 7.91,
#    'receiverY': 55.36},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 7.91,
#    'throwerY': 55.36,
#    'receiver': 'mkissmann',
#    'receiverX': 22.71,
#    'receiverY': 66.34},
#   {'type': 18,
#    'thrower': 'mkissmann',
#    'throwerX': 22.71,
#    'throwerY': 66.34,
#    'receiver': 'mhecht',
#    'receiverX': 4.5,
#    'receiverY': 72.06},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 4.5,
#    'throwerY': 72.06,
#    'receiver': 'mcrawford',
#    'receiverX': -16.65,
#    'receiverY': 77.86},
#   {'type': 18,
#    'thrower': 'mcrawford',
#    'throwerX': -16.65,
#    'throwerY': 77.86,
#    'receiver': 'msommer',
#    'receiverX': -23.19,
#    'receiverY': 92.86},
#   {'type': 18,
#    'thrower': 'msommer',
#    'throwerX': -23.19,
#    'throwerY': 92.86,
#    'receiver': 'mhecht',
#    'receiverX': -4.44,
#    'receiverY': 90.27},
#   {'type': 19,
#    'thrower': 'mhecht',
#    'throwerX': -4.44,
#    'throwerY': 90.27,
#    'receiver': 'msommer',
#    'receiverX': -0.69,
#    'receiverY': 104.04},
#   {'type': 1,
#    'line': ['rvickersb',
#     'pxu',
#     'jdecampos',
#     'mburke1',
#     'cbauman',
#     'rmendoza',
#     'wberreman'],
#    'time': 584},
#   {'type': 7,
#    'puller': 'cbauman',
#    'pullX': 22.84,
#    'pullY': 112.97,
#    'pullMs': 6245},
#   {'type': 15},
#   {'type': 2,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 608},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 26.66,
#    'throwerY': 54.61,
#    'receiver': 'dclyburn',
#    'receiverX': 4.5,
#    'receiverY': 38.45},
#   {'type': 18,
#    'thrower': 'dclyburn',
#    'throwerX': 4.5,
#    'throwerY': 38.45,
#    'receiver': 'wfrankenb',
#    'receiverX': 12.48,
#    'receiverY': 40.97},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': 12.48,
#    'throwerY': 40.97,
#    'receiver': 'mhecht',
#    'receiverX': 2.11,
#    'receiverY': 36.95},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 2.11,
#    'throwerY': 36.95,
#    'receiver': 'klaurence',
#    'receiverX': -17.74,
#    'receiverY': 38.11},
#   {'type': 22,
#    'thrower': 'klaurence',
#    'throwerX': -17.74,
#    'throwerY': 38.11,
#    'turnoverX': -4.85,
#    'turnoverY': 29.38},
#   {'type': 15},
#   {'type': 2,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 659},
#   {'type': 18,
#    'thrower': 'mhecht',
#    'throwerX': 25.5,
#    'throwerY': 55.09,
#    'receiver': 'klaurence',
#    'receiverX': -7.64,
#    'receiverY': 66.2},
#   {'type': 18,
#    'thrower': 'klaurence',
#    'throwerX': -7.64,
#    'throwerY': 66.2,
#    'receiver': 'emagsig',
#    'receiverX': -4.37,
#    'receiverY': 71.25},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': -4.37,
#    'throwerY': 71.25,
#    'receiver': 'klaurence',
#    'receiverX': -13.71,
#    'receiverY': 71.18},
#   {'type': 18,
#    'thrower': 'klaurence',
#    'throwerX': -13.71,
#    'throwerY': 71.18,
#    'receiver': 'wfrankenb',
#    'receiverX': -23.74,
#    'receiverY': 82.36},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': -23.74,
#    'throwerY': 82.36,
#    'receiver': 'emagsig',
#    'receiverX': -24.08,
#    'receiverY': 91.43},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': -24.08,
#    'throwerY': 91.43,
#    'receiver': 'wfrankenb',
#    'receiverX': -6.42,
#    'receiverY': 86.86},
#   {'type': 18,
#    'thrower': 'wfrankenb',
#    'throwerX': -6.42,
#    'throwerY': 86.86,
#    'receiver': 'emagsig',
#    'receiverX': 5.66,
#    'receiverY': 91.09},
#   {'type': 18,
#    'thrower': 'emagsig',
#    'throwerX': 5.66,
#    'throwerY': 91.09,
#    'receiver': 'mhecht',
#    'receiverX': -4.92,
#    'receiverY': 95.31},
#   {'type': 19,
#    'thrower': 'mhecht',
#    'throwerX': -4.92,
#    'throwerY': 95.31,
#    'receiver': 'clung',
#    'receiverX': 5.59,
#    'receiverY': 103.7},
#   {'type': 1,
#    'line': ['gmay',
#     'wberreman',
#     'emagsig',
#     'dclyburn',
#     'rmendoza',
#     'rvickersb',
#     'mburke1'],
#    'time': 687},
#   {'type': 8, 'puller': 'emagsig'},
#   {'type': 13},
#   {'type': 3,
#    'line': ['wfrankenb',
#     'dclyburn',
#     'clung',
#     'emagsig',
#     'klaurence',
#     'mhecht',
#     'mwilliams'],
#    'time': 718},
#   {'type': 31}]}

# %%
testgame.table.head()
# Out:
#                gameID                           date week home_team away_team  \
# 0  2023-05-19-OAK-POR  2023-05-19T19:30:00-07:00_PDT    4       POR       OAK
# 1  2023-05-19-OAK-POR  2023-05-19T19:30:00-07:00_PDT    4       POR       OAK
# 2  2023-05-19-OAK-POR  2023-05-19T19:30:00-07:00_PDT    4       POR       OAK
# 3  2023-05-19-OAK-POR  2023-05-19T19:30:00-07:00_PDT    4       POR       OAK
# 4  2023-05-19-OAK-POR  2023-05-19T19:30:00-07:00_PDT    4       POR       OAK
#
#   home_score away_score quarter time point  ... team_score team_penalty  \
# 0          0          0       1  720     1  ...        NaN          NaN
# 1        NaN        NaN     NaN  NaN   NaN  ...        NaN          NaN
# 2        NaN        NaN     NaN  NaN   NaN  ...        NaN          NaN
# 3        NaN        NaN     NaN  NaN   NaN  ...        NaN          NaN
# 4        NaN        NaN     NaN  NaN   NaN  ...        NaN          NaN
#
#   team_timeout penalty_player thrower receiver defender pullMs deltaX deltaY
# 0          NaN            NaN     NaN      NaN      NaN    NaN    NaN    NaN
# 1          NaN            NaN     NaN      NaN      NaN    NaN    NaN    NaN
# 2          NaN            NaN     NaN      NaN      NaN    NaN    NaN    NaN
# 3          NaN            NaN     NaN      NaN      NaN    NaN    NaN    NaN
# 4          NaN            NaN     NaN      NaN      NaN    NaN    NaN    NaN
#
# [5 rows x 46 columns]

# %% [markdown]
# Most common events: [game stats](https://theaudl.com/stats/game/2023-05-19-OAK-POR)
#  - throw
#  - point starts
#  - pull, score, goal
#  - throwaway, block
#  - rest

# %%
# count each event, make match classifer more efficient by trying most common first
event_counts = {}
for i,event in enumerate(data['homeEvents']):
    if f"{event['type']}, {event_keys[event['type']]}" in event_counts.keys():
        event_counts[f"{event['type']}, {event_keys[event['type']]}"] += 1
    else:
        event_counts[f"{event['type']}, {event_keys[event['type']]}"] = 1
for i,event in enumerate(data['awayEvents']):
    if f"{event['type']}, {event_keys[event['type']]}" in event_counts.keys():
        event_counts[f"{event['type']}, {event_keys[event['type']]}"] += 1
    else:
        event_counts[f"{event['type']}, {event_keys[event['type']]}"] = 1

# %%
sorted(event_counts.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('18, Pass', 464),
#  ('2, O_line', 50),
#  ('1, D_line', 50),
#  ('19, Goal', 47),
#  ('15, Score_opp', 47),
#  ('7, Pull_in', 46),
#  ('22, Throwaway_own', 31),
#  ('11, Block', 21),
#  ('17, Penalty_opp', 15),
#  ('13, Throwaway_opp', 14),
#  ('16, Penalty_own', 10),
#  ('5, Timeout_opp_line', 5),
#  ('3, Timeout_own_line', 4),
#  ('20, Drop', 4),
#  ('25, Injury_line', 4),
#  ('8, Pull_out', 4),
#  ('28, End_Q1', 2),
#  ('29, End_Q2', 2),
#  ('30, End_Q3', 2),
#  ('31, End_Q4', 2)]

# %%
# investigate various events
for i,event in enumerate(data['homeEvents']):
    if event['type'] in [11,14,24]:
        print(i,event_keys[event['type']],event)
for i,event in enumerate(data['awayEvents']):
    if event['type'] in [11,14,24]:
        print(i,event_keys[event['type']],event)
# Out:
# 23 Block {'type': 11, 'defender': 'sradlauer'}
# 154 Block {'type': 11, 'defender': 'sradlauer'}
# 255 Block {'type': 11, 'defender': 'rhayes'}
# 266 Block {'type': 11, 'defender': 'gnakano'}
# 299 Block {'type': 11, 'defender': 'efriedman'}
# 308 Block {'type': 11, 'defender': 'sradlauer'}
# 343 Block {'type': 11, 'defender': 'llavoie'}
# 369 Block {'type': 11, 'defender': 'arueda'}
# 387 Block {'type': 11, 'defender': 'jmoore1'}
# 2 Block {'type': 11, 'defender': 'rvickersb'}
# 14 Block {'type': 11, 'defender': 'emagsig'}
# 18 Block {'type': 11, 'defender': 'dclyburn'}
# 21 Block {'type': 11, 'defender': 'emagsig'}
# 128 Block {'type': 11, 'defender': 'rmendoza'}
# 140 Block {'type': 11, 'defender': 'mhecht'}
# 145 Block {'type': 11, 'defender': 'wberreman'}
# 151 Block {'type': 11, 'defender': 'rvickersb'}
# 158 Block {'type': 11, 'defender': 'rvickersb'}
# 184 Block {'type': 11, 'defender': 'rmendoza'}
# 302 Block {'type': 11, 'defender': 'mcrawford'}
# 341 Block {'type': 11, 'defender': 'klaurence'}
