# %%
import requests
import json

# %% [markdown]
#  - query API to get list of relevant gameIDs in date range
#  - `https://www.backend.audlstats.com/api/v1/games`
#    - add date range parameter, `?date=<...>`
#
# > An inclusive date range. The full format is YYYY-MM-DD:YYYY-MM-DD, but you can exclude months or days and it will infer them. Examples:
# - > 2021-06:2021-07 => All games during June or July
# - > 2021 => All games during 2021
# - > 2021-07-10: => All games on or after July 10th, 2021
# - > :2012-05 => All games during or before May, 2012

# %%
URL = 'https://www.backend.audlstats.com/api/v1/games?'
parameters = 'date=2023-04:2023-05' # April and May 2023 games

# %%
URL = f'{URL}{parameters}'
r = requests.get(URL)
if r.status_code == 200:
    data = r.json()

# %%
data['data']
# Out:
# [{'gameID': '2023-05-19-LA-SLC',
#   'awayTeamID': 'aviators',
#   'homeTeamID': 'shred',
#   'awayScore': 13,
#   'homeScore': 25,
#   'status': 'Final',
#   'startTimestamp': '2023-05-19T19:00:00-06:00',
#   'startTimezone': 'MDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/los-angeles-at-salt-lake-5-19-2023',
#   'updateTimestamp': '2023-05-21T20:13:21.805Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-06-DAL-ATX',
#   'awayTeamID': 'legion',
#   'homeTeamID': 'sol',
#   'awayScore': 17,
#   'homeScore': 31,
#   'status': 'Final',
#   'startTimestamp': '2023-05-06T19:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/dallas-at-austin-5-6-2023',
#   'updateTimestamp': '2023-05-10T05:30:26.666Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-06-COL-LA',
#   'awayTeamID': 'summit',
#   'homeTeamID': 'aviators',
#   'awayScore': 18,
#   'homeScore': 15,
#   'status': 'Final',
#   'startTimestamp': '2023-05-06T18:00:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/colorado-at-los-angeles-5-6-2023',
#   'updateTimestamp': '2023-05-13T03:12:30.377Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-20-BOS-MTL',
#   'awayTeamID': 'glory',
#   'homeTeamID': 'royal',
#   'awayScore': 17,
#   'homeScore': 15,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T12:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/boston-at-montreal-5-20-2023',
#   'updateTimestamp': '2023-05-24T20:23:15.249Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-20-DC-TOR',
#   'awayTeamID': 'breeze',
#   'homeTeamID': 'rush',
#   'awayScore': 20,
#   'homeScore': 13,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T18:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/dc-at-toronto-5-20-2023',
#   'updateTimestamp': '2023-05-22T19:43:14.907Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-13-PHI-BOS',
#   'awayTeamID': 'phoenix',
#   'homeTeamID': 'glory',
#   'awayScore': 16,
#   'homeScore': 19,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T13:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/philadelphia-at-boston-5-13-2023',
#   'updateTimestamp': '2023-05-20T03:02:28.235Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-27-CHI-MAD',
#   'awayTeamID': 'union',
#   'homeTeamID': 'radicals',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-27T18:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/chicago-at-madison-5-27-2023',
#   'updateTimestamp': '2023-03-04T21:59:13.540Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-27-PHI-PIT',
#   'awayTeamID': 'phoenix',
#   'homeTeamID': 'thunderbirds',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-27T18:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/philadelphia-at-pittsburgh-5-27-2023',
#   'updateTimestamp': '2023-03-04T22:03:33.565Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-27-MIN-DET',
#   'awayTeamID': 'windchill',
#   'homeTeamID': 'mechanix',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-27T17:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/minnesota-at-detroit-5-27-2023',
#   'updateTimestamp': '2023-03-04T21:57:30.134Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-28-ATX-DAL',
#   'awayTeamID': 'sol',
#   'homeTeamID': 'legion',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-28T15:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/austin-at-dallas-5-28-2023',
#   'updateTimestamp': '2023-03-04T21:56:39.826Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-19-SD-HTX',
#   'awayTeamID': 'growlers',
#   'homeTeamID': 'havoc',
#   'awayScore': 23,
#   'homeScore': 17,
#   'status': 'Final',
#   'startTimestamp': '2023-05-19T20:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/san-diego-at-houston-5-19-2023',
#   'updateTimestamp': '2023-05-24T02:37:51.337Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-26-HTX-CAR',
#   'awayTeamID': 'havoc',
#   'homeTeamID': 'flyers',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-26T19:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/houston-at-carolina-5-26-2023',
#   'updateTimestamp': '2023-03-04T21:53:29.169Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-27-HTX-ATL',
#   'awayTeamID': 'havoc',
#   'homeTeamID': 'hustle',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-27T19:30:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/houston-at-atlanta-5-27-2023',
#   'updateTimestamp': '2023-03-04T21:56:16.670Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-21-ATL-CAR',
#   'awayTeamID': 'hustle',
#   'homeTeamID': 'flyers',
#   'awayScore': 15,
#   'homeScore': 21,
#   'status': 'Final',
#   'startTimestamp': '2023-05-21T13:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/atlanta-at-carolina-5-21-2023',
#   'updateTimestamp': '2023-05-24T14:09:47.186Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-13-HTX-DAL',
#   'awayTeamID': 'havoc',
#   'homeTeamID': 'legion',
#   'awayScore': 28,
#   'homeScore': 17,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T18:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/houston-at-dallas-5-13-2023',
#   'updateTimestamp': '2023-05-20T00:38:36.948Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-19-OAK-POR',
#   'awayTeamID': 'spiders',
#   'homeTeamID': 'nitro',
#   'awayScore': 24,
#   'homeScore': 23,
#   'status': 'Final',
#   'startTimestamp': '2023-05-19T19:30:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/oakland-at-portland-5-19-2023',
#   'updateTimestamp': '2023-05-23T18:42:42.617Z',
#   'week': 'week-4'},
#  {'gameID': '2023-04-29-SEA-OAK',
#   'awayTeamID': 'cascades',
#   'homeTeamID': 'spiders',
#   'awayScore': 23,
#   'homeScore': 24,
#   'status': 'Final',
#   'startTimestamp': '2023-04-29T14:00:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/seattle-at-oakland-4-29-2023',
#   'updateTimestamp': '2023-04-29T23:29:31.216Z',
#   'week': 'week-1'},
#  {'gameID': '2023-05-20-OAK-SEA',
#   'awayTeamID': 'spiders',
#   'homeTeamID': 'cascades',
#   'awayScore': 24,
#   'homeScore': 20,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T17:00:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/oakland-at-seattle-5-20-2023',
#   'updateTimestamp': '2023-05-21T02:09:29.054Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-12-ATX-ATL',
#   'awayTeamID': 'sol',
#   'homeTeamID': 'hustle',
#   'awayScore': 17,
#   'homeScore': 21,
#   'status': 'Final',
#   'startTimestamp': '2023-05-12T20:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/austin-at-atlanta-5-12-2023',
#   'updateTimestamp': '2023-05-15T02:04:53.612Z',
#   'week': 'week-3'},
#  {'gameID': '2023-04-28-SEA-SLC',
#   'awayTeamID': 'cascades',
#   'homeTeamID': 'shred',
#   'awayScore': 20,
#   'homeScore': 28,
#   'status': 'Final',
#   'startTimestamp': '2023-04-28T20:00:00-06:00',
#   'startTimezone': 'MDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/seattle-at-salt-lake-4-28-2023',
#   'updateTimestamp': '2023-05-08T04:09:53.749Z',
#   'week': 'week-1'},
#  {'gameID': '2023-05-20-MAD-IND',
#   'awayTeamID': 'radicals',
#   'homeTeamID': 'alleycats',
#   'awayScore': 21,
#   'homeScore': 22,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T19:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/madison-at-indianapolis-5-20-2023',
#   'updateTimestamp': '2023-05-21T00:57:48.872Z',
#   'week': 'week-4'},
#  {'gameID': '2023-04-29-IND-ATL',
#   'awayTeamID': 'alleycats',
#   'homeTeamID': 'hustle',
#   'awayScore': 14,
#   'homeScore': 23,
#   'status': 'Final',
#   'startTimestamp': '2023-04-29T19:30:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/indianapolis-at-atlanta-4-29-2023',
#   'updateTimestamp': '2023-05-11T13:04:09.222Z',
#   'week': 'week-1'},
#  {'gameID': '2023-05-05-SLC-POR',
#   'awayTeamID': 'shred',
#   'homeTeamID': 'nitro',
#   'awayScore': 22,
#   'homeScore': 20,
#   'status': 'Final',
#   'startTimestamp': '2023-05-05T20:00:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/salt-lake-at-portland-5-5-2023',
#   'updateTimestamp': '2023-05-11T20:46:32.142Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-12-POR-LA',
#   'awayTeamID': 'nitro',
#   'homeTeamID': 'aviators',
#   'awayScore': 13,
#   'homeScore': 20,
#   'status': 'Final',
#   'startTimestamp': '2023-05-12T19:30:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/portland-at-los-angeles-5-12-2023',
#   'updateTimestamp': '2023-05-17T23:52:58.470Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-20-PIT-MIN',
#   'awayTeamID': 'thunderbirds',
#   'homeTeamID': 'windchill',
#   'awayScore': 12,
#   'homeScore': 26,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T18:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/pittsburgh-at-minnesota-5-20-2023',
#   'updateTimestamp': '2023-05-22T00:06:24.324Z',
#   'week': 'week-4'},
#  {'gameID': '2023-04-29-PHI-NY',
#   'awayTeamID': 'phoenix',
#   'homeTeamID': 'empire',
#   'awayScore': 8,
#   'homeScore': 17,
#   'status': 'Final',
#   'startTimestamp': '2023-04-29T19:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/philadelphia-at-new-york-4-29-2023',
#   'updateTimestamp': '2023-05-02T02:30:29.109Z',
#   'week': 'week-1'},
#  {'gameID': '2023-04-29-ATX-HTX',
#   'awayTeamID': 'sol',
#   'homeTeamID': 'havoc',
#   'awayScore': 24,
#   'homeScore': 18,
#   'status': 'Final',
#   'startTimestamp': '2023-04-29T19:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/austin-at-houston-4-29-2023',
#   'updateTimestamp': '2023-05-13T16:37:52.556Z',
#   'week': 'week-1'},
#  {'gameID': '2023-04-29-MAD-PIT',
#   'awayTeamID': 'radicals',
#   'homeTeamID': 'thunderbirds',
#   'awayScore': 17,
#   'homeScore': 18,
#   'status': 'Final',
#   'startTimestamp': '2023-04-29T18:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/madison-at-pittsburgh-4-29-2023',
#   'updateTimestamp': '2023-05-13T19:09:46.753Z',
#   'week': 'week-1'},
#  {'gameID': '2023-05-13-MTL-TOR',
#   'awayTeamID': 'royal',
#   'homeTeamID': 'rush',
#   'awayScore': 20,
#   'homeScore': 25,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T16:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/montreal-at-toronto-5-13-2023',
#   'updateTimestamp': '2023-05-20T18:28:18.786Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-20-SD-ATX',
#   'awayTeamID': 'growlers',
#   'homeTeamID': 'sol',
#   'awayScore': 17,
#   'homeScore': 21,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T19:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/san-diego-at-austin-5-20-2023',
#   'updateTimestamp': '2023-05-21T15:43:15.401Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-20-LA-COL',
#   'awayTeamID': 'aviators',
#   'homeTeamID': 'summit',
#   'awayScore': 14,
#   'homeScore': 18,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T18:00:00-06:00',
#   'startTimezone': 'MDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/los-angeles-at-colorado-5-20-2023',
#   'updateTimestamp': '2023-05-22T03:21:33.105Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-06-TOR-BOS',
#   'awayTeamID': 'rush',
#   'homeTeamID': 'glory',
#   'awayScore': 14,
#   'homeScore': 25,
#   'status': 'Final',
#   'startTimestamp': '2023-05-06T17:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/toronto-at-boston-5-6-2023',
#   'updateTimestamp': '2023-05-09T02:00:17.993Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-13-PIT-DET',
#   'awayTeamID': 'thunderbirds',
#   'homeTeamID': 'mechanix',
#   'awayScore': 29,
#   'homeScore': 13,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T17:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/pittsburgh-at-detroit-5-13-2023',
#   'updateTimestamp': '2023-05-13T22:57:30.105Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-07-PHI-DC',
#   'awayTeamID': 'phoenix',
#   'homeTeamID': 'breeze',
#   'awayScore': 19,
#   'homeScore': 20,
#   'status': 'Final',
#   'startTimestamp': '2023-05-07T17:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/philadelphia-at-dc-5-7-2023',
#   'updateTimestamp': '2023-05-07T22:59:27.359Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-13-ATX-CAR',
#   'awayTeamID': 'sol',
#   'homeTeamID': 'flyers',
#   'awayScore': 19,
#   'homeScore': 26,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T18:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/austin-at-carolina-5-13-2023',
#   'updateTimestamp': '2023-05-21T15:12:24.119Z',
#   'week': 'week-3'},
#  {'gameID': '2023-04-29-DC-CAR',
#   'awayTeamID': 'breeze',
#   'homeTeamID': 'flyers',
#   'awayScore': 21,
#   'homeScore': 16,
#   'status': 'Final',
#   'startTimestamp': '2023-04-29T18:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/dc-at-carolina-4-29-2023',
#   'updateTimestamp': '2023-05-03T21:05:51.133Z',
#   'week': 'week-1'},
#  {'gameID': '2023-05-13-SLC-OAK',
#   'awayTeamID': 'shred',
#   'homeTeamID': 'spiders',
#   'awayScore': 27,
#   'homeScore': 25,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T17:00:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/salt-lake-at-oakland-5-13-2023',
#   'updateTimestamp': '2023-05-20T21:22:05.319Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-05-CAR-ATL',
#   'awayTeamID': 'flyers',
#   'homeTeamID': 'hustle',
#   'awayScore': 19,
#   'homeScore': 24,
#   'status': 'Final',
#   'startTimestamp': '2023-05-05T20:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/carolina-at-atlanta-5-5-2023',
#   'updateTimestamp': '2023-05-06T10:11:07.358Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-13-SEA-COL',
#   'awayTeamID': 'cascades',
#   'homeTeamID': 'summit',
#   'awayScore': 14,
#   'homeScore': 26,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T18:30:00-06:00',
#   'startTimezone': 'MDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/seattle-at-colorado-5-13-2023',
#   'updateTimestamp': '2023-05-20T14:00:11.342Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-13-NY-DC',
#   'awayTeamID': 'empire',
#   'homeTeamID': 'breeze',
#   'awayScore': 18,
#   'homeScore': 17,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T19:30:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/new-york-at-dc-5-13-2023',
#   'updateTimestamp': '2023-05-14T01:36:17.415Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-05-TOR-NY',
#   'awayTeamID': 'rush',
#   'homeTeamID': 'empire',
#   'awayScore': 11,
#   'homeScore': 24,
#   'status': 'Final',
#   'startTimestamp': '2023-05-05T19:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/toronto-at-new-york-5-5-2023',
#   'updateTimestamp': '2023-05-07T23:24:00.555Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-20-NY-PHI',
#   'awayTeamID': 'empire',
#   'homeTeamID': 'phoenix',
#   'awayScore': 18,
#   'homeScore': 16,
#   'status': 'Final',
#   'startTimestamp': '2023-05-20T19:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/new-york-at-philadelphia-5-20-2023',
#   'updateTimestamp': '2023-05-25T03:22:14.417Z',
#   'week': 'week-4'},
#  {'gameID': '2023-05-13-POR-SD',
#   'awayTeamID': 'nitro',
#   'homeTeamID': 'growlers',
#   'awayScore': 19,
#   'homeScore': 22,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T18:15:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/portland-at-san-diego-5-13-2023',
#   'updateTimestamp': '2023-05-17T23:58:33.515Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-05-COL-SD',
#   'awayTeamID': 'summit',
#   'homeTeamID': 'growlers',
#   'awayScore': 23,
#   'homeScore': 16,
#   'status': 'Final',
#   'startTimestamp': '2023-05-05T19:00:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/colorado-at-san-diego-5-5-2023',
#   'updateTimestamp': '2023-05-12T22:48:32.280Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-27-TOR-MTL',
#   'awayTeamID': 'rush',
#   'homeTeamID': 'royal',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-27T13:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/toronto-at-montreal-5-27-2023',
#   'updateTimestamp': '2023-03-04T21:59:47.714Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-13-IND-CHI',
#   'awayTeamID': 'alleycats',
#   'homeTeamID': 'union',
#   'awayScore': 19,
#   'homeScore': 16,
#   'status': 'Final',
#   'startTimestamp': '2023-05-13T18:30:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/indianapolis-at-chicago-5-13-2023',
#   'updateTimestamp': '2023-05-18T21:35:43.971Z',
#   'week': 'week-3'},
#  {'gameID': '2023-05-28-MIN-CHI',
#   'awayTeamID': 'windchill',
#   'homeTeamID': 'union',
#   'awayScore': 0,
#   'homeScore': 0,
#   'status': 'Upcoming',
#   'startTimestamp': '2023-05-28T16:00:00-05:00',
#   'startTimezone': 'CDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/minnesota-at-chicago-5-28-2023',
#   'updateTimestamp': '2023-03-04T22:04:05.649Z',
#   'week': 'week-5'},
#  {'gameID': '2023-05-06-SLC-SEA',
#   'awayTeamID': 'shred',
#   'homeTeamID': 'cascades',
#   'awayScore': 25,
#   'homeScore': 19,
#   'status': 'Final',
#   'startTimestamp': '2023-05-06T15:00:00-07:00',
#   'startTimezone': 'PDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/salt-lake-at-seattle-5-6-2023',
#   'updateTimestamp': '2023-05-11T20:47:58.639Z',
#   'week': 'week-2'},
#  {'gameID': '2023-05-06-MIN-IND',
#   'awayTeamID': 'windchill',
#   'homeTeamID': 'alleycats',
#   'awayScore': 23,
#   'homeScore': 21,
#   'status': 'Final',
#   'startTimestamp': '2023-05-06T19:00:00-04:00',
#   'startTimezone': 'EDT',
#   'streamingURL': 'https://audltv.vhx.tv/videos/minnesota-at-indianapolis-5-6-2023',
#   'updateTimestamp': '2023-05-07T22:22:51.082Z',
#   'week': 'week-2'}]

# %% [markdown]
# **Pick game and develop method to unpack events**
#
#  - do stats derived from events match game reported stats?

# %%
URL = 'https://www.backend.audlstats.com/api/v1/gameEvents?'
parameters = 'gameID=2023-05-19-OAK-POR'

# %%
URL = f'{URL}{parameters}'
r = requests.get(URL)
if r.status_code == 200:
    data = r.json()

# %%
len(data['data']['homeEvents'])
# Out:
# 406

# %%
len(data['data']['awayEvents'])
# Out:
# 418

# %%
data.keys()
# Out:
# dict_keys(['object', 'data'])

# %%
data['data']['homeEvents'][0:50]
# Out:
# [{'type': 2,
#   'line': ['jjohnson1',
#    'efriedman',
#    'jsnyder',
#    'rhayes',
#    'sfraner',
#    'isweeney',
#    'tdoi'],
#   'time': 0,
#   'desc': 'O_line'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -16.1,
#   'throwerY': 7.22,
#   'receiver': 'jjohnson1',
#   'receiverX': -1.46,
#   'receiverY': 15.54,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': -1.46,
#   'throwerY': 15.54,
#   'receiver': 'efriedman',
#   'receiverX': -17.13,
#   'receiverY': 21.22,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -17.13,
#   'throwerY': 21.22,
#   'receiver': 'jsnyder',
#   'receiverX': -17.45,
#   'receiverY': 94.7,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': -17.45,
#   'throwerY': 94.7,
#   'receiver': 'rhayes',
#   'receiverX': -17.39,
#   'receiverY': 86.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -17.39,
#   'throwerY': 86.83,
#   'receiver': 'sfraner',
#   'receiverX': -17.06,
#   'receiverY': 74.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -17.06,
#   'throwerY': 74.83,
#   'receiver': 'efriedman',
#   'receiverX': 0.35,
#   'receiverY': 63.8,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 0.35,
#   'throwerY': 63.8,
#   'receiver': 'isweeney',
#   'receiverX': -19.19,
#   'receiverY': 80.25,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -19.19,
#   'throwerY': 80.25,
#   'receiver': 'efriedman',
#   'receiverX': 2.67,
#   'receiverY': 74.58,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'efriedman',
#   'throwerX': 2.67,
#   'throwerY': 74.58,
#   'turnoverX': -13.71,
#   'turnoverY': 86.06,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -4.68,
#   'throwerY': 20,
#   'receiver': 'jjohnson1',
#   'receiverX': 17.12,
#   'receiverY': 18.12,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': 17.12,
#   'throwerY': 18.12,
#   'receiver': 'isweeney',
#   'receiverX': -14.81,
#   'receiverY': 16.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -14.81,
#   'throwerY': 16.32,
#   'receiver': 'sfraner',
#   'receiverX': -23,
#   'receiverY': 34.96,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -23,
#   'throwerY': 34.96,
#   'receiver': 'rhayes',
#   'receiverX': -11.07,
#   'receiverY': 36,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -11.07,
#   'throwerY': 36,
#   'receiver': 'efriedman',
#   'receiverX': 2.03,
#   'receiverY': 36.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 2.03,
#   'throwerY': 36.32,
#   'receiver': 'tdoi',
#   'receiverX': 18.15,
#   'receiverY': 34.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'tdoi',
#   'throwerX': 18.15,
#   'throwerY': 34.38,
#   'receiver': 'efriedman',
#   'receiverX': 9.31,
#   'receiverY': 30.9,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 9.31,
#   'throwerY': 30.9,
#   'receiver': 'isweeney',
#   'receiverX': -11.26,
#   'receiverY': 24.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -11.26,
#   'throwerY': 24.38,
#   'receiver': 'efriedman',
#   'receiverX': 11.51,
#   'receiverY': 30.77,
#   'desc': 'Pass'},
#  {'type': 19,
#   'thrower': 'efriedman',
#   'throwerX': 11.51,
#   'throwerY': 30.77,
#   'receiver': 'tdoi',
#   'receiverX': 10.54,
#   'receiverY': 108.45,
#   'desc': 'Goal'},
#  {'type': 1,
#   'line': ['sradlauer',
#    'jmoore1',
#    'llavoie',
#    'jlee',
#    'arueda',
#    'bstout',
#    'apetersch'],
#   'time': 115,
#   'desc': 'D_line'},
#  {'type': 7,
#   'puller': 'sradlauer',
#   'pullX': 0.87,
#   'pullY': 94.96,
#   'pullMs': 3080,
#   'desc': 'Pull_in'},
#  {'type': 11, 'defender': 'sradlauer', 'desc': 'Block'},
#  {'type': 18,
#   'thrower': 'apetersch',
#   'throwerX': 25.63,
#   'throwerY': 67.29,
#   'receiver': 'jlee',
#   'receiverX': 6.54,
#   'receiverY': 58.64,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jlee',
#   'throwerX': 6.54,
#   'throwerY': 58.64,
#   'receiver': 'jmoore1',
#   'receiverX': -18.67,
#   'receiverY': 53.61,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jmoore1',
#   'throwerX': -18.67,
#   'throwerY': 53.61,
#   'receiver': 'llavoie',
#   'receiverX': 11.18,
#   'receiverY': 59.93,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'llavoie',
#   'throwerX': 11.18,
#   'throwerY': 59.93,
#   'turnoverX': 20.79,
#   'turnoverY': 104.06,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'llavoie',
#   'throwerX': 24.86,
#   'throwerY': 45.03,
#   'receiver': 'jlee',
#   'receiverX': 22.47,
#   'receiverY': 30.32,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'jlee',
#   'throwerX': 22.47,
#   'throwerY': 30.32,
#   'turnoverX': 24.02,
#   'turnoverY': 50.64,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'jlee',
#   'throwerX': 14.92,
#   'throwerY': 39.41,
#   'receiver': 'llavoie',
#   'receiverX': -0.42,
#   'receiverY': 46.51,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'llavoie',
#   'throwerX': -0.42,
#   'throwerY': 46.51,
#   'receiver': 'jmoore1',
#   'receiverX': -18.74,
#   'receiverY': 56.45,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'jmoore1',
#   'throwerX': -18.74,
#   'throwerY': 56.45,
#   'turnoverX': -10.42,
#   'turnoverY': 106.64,
#   'desc': 'Throwaway_own'},
#  {'type': 15, 'desc': 'Score_opp'},
#  {'type': 2,
#   'line': ['efriedman',
#    'jsnyder',
#    'rhayes',
#    'sfraner',
#    'tdoi',
#    'isweeney',
#    'qbuermeye'],
#   'time': 256,
#   'desc': 'O_line'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': -0.04,
#   'throwerY': 14.32,
#   'receiver': 'isweeney',
#   'receiverX': -6.1,
#   'receiverY': 19.35,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -6.1,
#   'throwerY': 19.35,
#   'receiver': 'efriedman',
#   'receiverX': -16.48,
#   'receiverY': 32.45,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -16.48,
#   'throwerY': 32.45,
#   'receiver': 'qbuermeye',
#   'receiverX': -22.74,
#   'receiverY': 41.93,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'qbuermeye',
#   'throwerX': -22.74,
#   'throwerY': 41.93,
#   'receiver': 'sfraner',
#   'receiverX': -16.93,
#   'receiverY': 51.09,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -16.93,
#   'throwerY': 51.09,
#   'receiver': 'rhayes',
#   'receiverX': -23.19,
#   'receiverY': 60.77,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -23.19,
#   'throwerY': 60.77,
#   'receiver': 'efriedman',
#   'receiverX': -13.45,
#   'receiverY': 66.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -13.45,
#   'throwerY': 66.38,
#   'receiver': 'rhayes',
#   'receiverX': -25.58,
#   'receiverY': 72.58,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -25.58,
#   'throwerY': 72.58,
#   'receiver': 'efriedman',
#   'receiverX': -5.71,
#   'receiverY': 63.87,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -5.71,
#   'throwerY': 63.87,
#   'receiver': 'sfraner',
#   'receiverX': -17.84,
#   'receiverY': 80.06,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -17.84,
#   'throwerY': 80.06,
#   'receiver': 'jsnyder',
#   'receiverX': 0.93,
#   'receiverY': 70.9,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': 0.93,
#   'throwerY': 70.9,
#   'receiver': 'rhayes',
#   'receiverX': 15.5,
#   'receiverY': 90.7,
#   'desc': 'Pass'},
#  {'type': 19,
#   'thrower': 'rhayes',
#   'throwerX': 15.5,
#   'throwerY': 90.7,
#   'receiver': 'qbuermeye',
#   'receiverX': 14.28,
#   'receiverY': 104.58,
#   'desc': 'Goal'},
#  {'type': 1,
#   'line': ['jmoore1',
#    'apetersch',
#    'arueda',
#    'gnakano',
#    'bstout',
#    'slatarski',
#    'jlee'],
#   'time': 316,
#   'desc': 'D_line'}]

# %%
# https://www.docs.audlstats.com/events

events = [
    'D_line',
    'O_line',
    'Timeout_own_line',
    'Timeout_own',
    'Timeout_opp_line',
    'Timeout_opp',
    'Pull_in',
    'Pull_out',
    'Offsides_own',
    'Offsides_opp',
    'Block',
    'Callahan_opp',
    'Throwaway_opp',
    'Stall_opp',
    'Score_opp',
    'Penalty_own',
    'Penalty_opp',
    'Pass',
    'Goal',
    'Drop',
    'Drop_pull',
    'Throwaway_own',
    'Callahan_own',
    'Stall_own',
    'Injury_line',
    'Player_misconduct',
    'Player_ejection',
    'End_Q1',
    'End_Q2',
    'End_Q3',
    'End_Q4',
    'End_OT1',
    'End_OT2',
    'Delayed',
    'Postponed',
]

# %%
event_keys = {}
for i,val in enumerate(events):
    event_keys[i+1]=val

# %%
for etype in ['homeEvents','awayEvents']:
    for event in data['data'][etype]:
        event['desc'] = event_keys[event['type']]

# %%
event_keys
# Out:
# {1: 'D_line',
#  2: 'O_line',
#  3: 'Timeout_own_line',
#  4: 'Timeout_own',
#  5: 'Timeout_opp_line',
#  6: 'Timeout_opp',
#  7: 'Pull_in',
#  8: 'Pull_out',
#  9: 'Offsides_own',
#  10: 'Offsides_opp',
#  11: 'Block',
#  12: 'Callahan_opp',
#  13: 'Throwaway_opp',
#  14: 'Stall_opp',
#  15: 'Score_opp',
#  16: 'Penalty_own',
#  17: 'Penalty_opp',
#  18: 'Pass',
#  19: 'Goal',
#  20: 'Drop',
#  21: 'Drop_pull',
#  22: 'Throwaway_own',
#  23: 'Callahan_own',
#  24: 'Stall_own',
#  25: 'Injury_line',
#  26: 'Player_misconduct',
#  27: 'Player_ejection',
#  28: 'End_Q1',
#  29: 'End_Q2',
#  30: 'End_Q3',
#  31: 'End_Q4',
#  32: 'End_OT1',
#  33: 'End_OT2',
#  34: 'Delayed',
#  35: 'Postponed'}

# %% [markdown]
# **Go through home or away events, see if I can split by each score/timeout/injury**
#
#  - should probably characterize by O/D eventually
#  - would have to cross reference home/away events to get complete information about turnovers
#
# Possible Data's
#
#  - line info
#  - time, starts at 0 every quarter up to 720s (12 mins)
#  - playerID (line arrays, puller, thrower, receiver, defender, misconduct foul, ejected)
#  - pull info (`X`,`Y` for where it was brought into play, hangtime `Ms`)
#  - player coordinates (thrower, receiver, turnover)

# %%
# line substitutions within a point, injury or timeout
for i,event in enumerate(data['data']['homeEvents']):
    if event['type'] in [3,5,25]:
        print(i,event_keys[event['type']],event)
for i,event in enumerate(data['data']['awayEvents']):
    if event['type'] in [3,5,25]:
        print(i,event_keys[event['type']],event)
# Out:
# 67 Timeout_own_line {'type': 3, 'line': ['bstout', 'rhayes', 'qbuermeye', 'apetersch', 'jlee', 'isweeney', 'jmoore1'], 'time': 403}
# 177 Timeout_opp_line {'type': 5, 'line': ['sradlauer', 'jmoore1', 'jlee', 'gnakano', 'bstout', 'apetersch', 'qbuermeye'], 'time': 610}
# 228 Injury_line {'type': 25, 'line': ['sradlauer', 'jmoore1', 'jlee', 'gnakano', 'apetersch', 'arueda', 'bstout'], 'time': 291}
# 284 Timeout_own_line {'type': 3, 'line': ['jjohnson1', 'efriedman', 'jsnyder', 'rhayes', 'sfraner', 'isweeney', 'qbuermeye'], 'time': 698}
# 304 Injury_line {'type': 25, 'line': ['jjohnson1', 'efriedman', 'jsnyder', 'rhayes', 'isweeney', 'qbuermeye', 'tdoi'], 'time': 121}
# 404 Timeout_opp_line {'type': 5, 'line': ['sradlauer', 'rhayes', 'cstillwel', 'isweeney', 'bstout', 'jsnyder', 'slatarski'], 'time': 718}
# 36 Timeout_opp_line {'type': 5, 'line': ['rvickersb', 'pxu', 'jdecampos', 'mburke1', 'cbauman', 'rmendoza', 'wberreman'], 'time': 403}
# 157 Timeout_opp_line {'type': 5, 'line': ['gmay', 'rcastro', 'rvickersb', 'kkhangaon', 'jdecampos', 'mburke1', 'wberreman'], 'time': 576}
# 159 Timeout_own_line {'type': 3, 'line': ['wfrankenb', 'dclyburn', 'clung', 'emagsig', 'klaurence', 'mhecht', 'mwilliams'], 'time': 611}
# 225 Injury_line {'type': 25, 'line': ['wfrankenb', 'dclyburn', 'emagsig', 'klaurence', 'mhecht', 'mwilliams', 'gmay'], 'time': 291}
# 283 Timeout_opp_line {'type': 5, 'line': ['rvickersb', 'pxu', 'jdecampos', 'mburke1', 'cbauman', 'rmendoza', 'wberreman'], 'time': 699}
# 310 Injury_line {'type': 25, 'line': ['gmay', 'mcrawford', 'kkhangaon', 'msommer', 'mkissmann', 'wberreman', 'rmendoza'], 'time': 121}
# 416 Timeout_own_line {'type': 3, 'line': ['wfrankenb', 'dclyburn', 'clung', 'emagsig', 'klaurence', 'mhecht', 'mwilliams'], 'time': 718}

# %% [markdown]
# ### Flow of a Point
#
# *can always use point start to split points*
#
#  1. Start point with `O_line` or `D_line`, note players on the field.
#    a. adjustments needed if event type in 3,5,25. All players can be subbed on timeouts.
#  2. Series of events from 7-27 (excepting Callahans), starting with 7 or 8 `Pull_in` or `Pull_out`
#  3. Point ends with quarter (28-33) or some type of score (

# %%
# count points for home and away to check
pointcounter = {'homeEvents':{'O':0,'D':0},
                'awayEvents':{'O':0,'D':0}
               }

for etype in ['homeEvents','awayEvents']:
    for event in data['data'][etype]:
        if event['type'] < 3:
            if event['type'] == 2:
                pointcounter[etype]['O'] += 1 
            else:
                pointcounter[etype]['D'] += 1

# %%
pointcounter
# Out:
# {'homeEvents': {'O': 26, 'D': 24}, 'awayEvents': {'O': 24, 'D': 26}}

# %%
# attempt to number the groups of events by points for cross referencing

from collections import defaultdict

# %%
home_points = defaultdict(list)
k = 0

for event in data['data']['homeEvents']:
    if event['type'] < 3:
        k+=1
    home_points[k].append(event)

# %%
away_points = defaultdict(list)
k = 0

for event in data['data']['awayEvents']:
    if event['type'] < 3:
        k+=1
    away_points[k].append(event)

# %%
k
# Out:
# 50

# %% [markdown]
# ### Flow of Point, considering everything
#
#  1. Start with D, pull
#  2. Then go to O,
#  3. Switch teams with any kind of turnover
#    - turnovers (offensive perspective): 20,21,22,23\*,24
#    - Drop, Dropped pull, throwaway, Callahan\*, Stall
#    - How to handle "Blocks", 11?

# %%
home_points[1]
# Out:
# [{'type': 2,
#   'line': ['jjohnson1',
#    'efriedman',
#    'jsnyder',
#    'rhayes',
#    'sfraner',
#    'isweeney',
#    'tdoi'],
#   'time': 0,
#   'desc': 'O_line'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -16.1,
#   'throwerY': 7.22,
#   'receiver': 'jjohnson1',
#   'receiverX': -1.46,
#   'receiverY': 15.54,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': -1.46,
#   'throwerY': 15.54,
#   'receiver': 'efriedman',
#   'receiverX': -17.13,
#   'receiverY': 21.22,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -17.13,
#   'throwerY': 21.22,
#   'receiver': 'jsnyder',
#   'receiverX': -17.45,
#   'receiverY': 94.7,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jsnyder',
#   'throwerX': -17.45,
#   'throwerY': 94.7,
#   'receiver': 'rhayes',
#   'receiverX': -17.39,
#   'receiverY': 86.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -17.39,
#   'throwerY': 86.83,
#   'receiver': 'sfraner',
#   'receiverX': -17.06,
#   'receiverY': 74.83,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -17.06,
#   'throwerY': 74.83,
#   'receiver': 'efriedman',
#   'receiverX': 0.35,
#   'receiverY': 63.8,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 0.35,
#   'throwerY': 63.8,
#   'receiver': 'isweeney',
#   'receiverX': -19.19,
#   'receiverY': 80.25,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -19.19,
#   'throwerY': 80.25,
#   'receiver': 'efriedman',
#   'receiverX': 2.67,
#   'receiverY': 74.58,
#   'desc': 'Pass'},
#  {'type': 22,
#   'thrower': 'efriedman',
#   'throwerX': 2.67,
#   'throwerY': 74.58,
#   'turnoverX': -13.71,
#   'turnoverY': 86.06,
#   'desc': 'Throwaway_own'},
#  {'type': 13, 'desc': 'Throwaway_opp'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': -4.68,
#   'throwerY': 20,
#   'receiver': 'jjohnson1',
#   'receiverX': 17.12,
#   'receiverY': 18.12,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'jjohnson1',
#   'throwerX': 17.12,
#   'throwerY': 18.12,
#   'receiver': 'isweeney',
#   'receiverX': -14.81,
#   'receiverY': 16.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -14.81,
#   'throwerY': 16.32,
#   'receiver': 'sfraner',
#   'receiverX': -23,
#   'receiverY': 34.96,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'sfraner',
#   'throwerX': -23,
#   'throwerY': 34.96,
#   'receiver': 'rhayes',
#   'receiverX': -11.07,
#   'receiverY': 36,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'rhayes',
#   'throwerX': -11.07,
#   'throwerY': 36,
#   'receiver': 'efriedman',
#   'receiverX': 2.03,
#   'receiverY': 36.32,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 2.03,
#   'throwerY': 36.32,
#   'receiver': 'tdoi',
#   'receiverX': 18.15,
#   'receiverY': 34.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'tdoi',
#   'throwerX': 18.15,
#   'throwerY': 34.38,
#   'receiver': 'efriedman',
#   'receiverX': 9.31,
#   'receiverY': 30.9,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'efriedman',
#   'throwerX': 9.31,
#   'throwerY': 30.9,
#   'receiver': 'isweeney',
#   'receiverX': -11.26,
#   'receiverY': 24.38,
#   'desc': 'Pass'},
#  {'type': 18,
#   'thrower': 'isweeney',
#   'throwerX': -11.26,
#   'throwerY': 24.38,
#   'receiver': 'efriedman',
#   'receiverX': 11.51,
#   'receiverY': 30.77,
#   'desc': 'Pass'},
#  {'type': 19,
#   'thrower': 'efriedman',
#   'throwerX': 11.51,
#   'throwerY': 30.77,
#   'receiver': 'tdoi',
#   'receiverX': 10.54,
#   'receiverY': 108.45,
#   'desc': 'Goal'}]
